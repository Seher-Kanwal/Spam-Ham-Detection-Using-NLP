# %%
# importing the Dataset

import pandas as pd

df = pd.read_csv('smsspamcollection/SMSSpamCollection', sep='\t',
                           names=["label", "message"])

# %%
df.head(3)
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %%
import re
from nltk.corpus import stopwords

# %% [markdown]
# ### download it to perform lemmatization on the data
# import nltk
#
# nltk.download('wordnet')
#
# nltk.download('omw-1.4')

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
corpus = []
for i in range(0, len(df.message)):
    review = re.sub('[^a-zA-z]', " ", df.message[i])
    review = review.lower()
    review = review.split()
    
    review = [lemmatizer.lemmatize(words) for words in review if not words in stopwords.words('english')]
    review = " ".join(review)
    corpus.append(review)

# %% [markdown]
# ### map function is used to apply a fn on the whole list as in our case we are applying the len fn on corpus to get len of each sentence and map fn return us an obj, so to display it's result we need to convert it into list
#
# ### Zip fn is used to iterate through the 2 or more list at a time in our case we pass 3 lists
# #### first is : len of tense (zip fn)
# #### sec is : corpus itself
# #### third is: the df column
#
# #### in the print statement it first display the len, corpus tense and the actuall message from df

# %%
print([[i, j, k]for i, j,k in zip(list(map(len,corpus)),corpus, df.message) if i<1])
# Out:
# [[0, '', 'What you doing?how are you?'], [0, '', 'Where @'], [0, '', '645'], [0, '', 'Can a not?'], [0, '', ':) '], [0, '', 'What you doing?how are you?'], [0, '', ':( but your not here....'], [0, '', ':-) :-)']]

# %%
corpus[0]
# Out:
# 'go jurong point crazy available bugis n great world la e buffet cine got amore wat'

# %%
corpus
# Out:
# ['go jurong point crazy available bugis n great world la e buffet cine got amore wat',
#  'ok lar joking wif u oni',
#  'free entry wkly comp win fa cup final tkts st may text fa receive entry question std txt rate c apply',
#  'u dun say early hor u c already say',
#  'nah think go usf life around though',
#  'freemsg hey darling week word back like fun still tb ok xxx std chgs send rcv',
#  'even brother like speak treat like aid patent',
#  'per request melle melle oru minnaminunginte nurungu vettam set callertune caller press copy friend callertune',
#  'winner valued network customer selected receivea prize reward claim call claim code kl valid hour',
#  'mobile month u r entitled update latest colour mobile camera free call mobile update co free',
#  'gonna home soon want talk stuff anymore tonight k cried enough today',
#  'six chance win cash pound txt csh send cost p day day tsandcs apply reply hl info',
#  'urgent week free membership prize jackpot txt word claim c www dbuk net lccltd pobox ldnw rw',
#  'searching right word thank breather promise wont take help granted fulfil promise wonderful blessing time',
#  'date sunday',
#  'xxxmobilemovieclub use credit click wap link next txt message click http wap xxxmobilemovieclub com n qjkgighjjgcbl',
#  'oh k watching',
#  'eh u remember spell name yes v naughty make v wet',
#  'fine way u feel way gota b',
#  'england v macedonia dont miss goal team news txt ur national team eg england try wale scotland txt poboxox w wq',
#  'seriously spell name',
#  'going try month ha ha joking',
#  'pay first lar da stock comin',
#  'aft finish lunch go str lor ard smth lor u finish ur lunch already',
#  'ffffffffff alright way meet sooner',
#  'forced eat slice really hungry tho suck mark getting worried know sick turn pizza lol',
#  'lol always convincing',
#  'catch bus frying egg make tea eating mom left dinner feel love',
#  'back amp packing car let know room',
#  'ahhh work vaguely remember feel like lol',
#  'wait still clear sure sarcastic x want live u',
#  'yeah got v apologetic n fallen actin like spoilt child got caught till go badly cheer',
#  'k tell anything',
#  'fear fainting housework quick cuppa',
#  'thanks subscription ringtone uk mobile charged month please confirm replying yes reply charged',
#  'yup ok go home look timing msg xuhui going learn nd may lesson',
#  'oops let know roommate done',
#  'see letter b car',
#  'anything lor u decide',
#  'hello saturday go texting see decided anything tomo trying invite anything',
#  'pls go ahead watt wanted sure great weekend abiola',
#  'forget tell want need crave love sweet arabian steed mmmmmm yummy',
#  'rodger burn msg tried call reply sm free nokia mobile free camcorder please call delivery tomorrow',
#  'seeing',
#  'great hope like man well endowed lt gt inch',
#  'call message missed call',
#  'get hep b immunisation nigeria',
#  'fair enough anything going',
#  'yeah hopefully tyler could maybe ask around bit',
#  'u know stubborn even want go hospital kept telling mark weak sucker hospital weak sucker',
#  'thinked first time saw class',
#  'gram usually run like lt gt half eighth smarter though get almost whole second gram lt gt',
#  'k fyi x ride early tomorrow morning crashing place tonight',
#  'wow never realized embarassed accomodations thought liked since best could always seemed happy cave sorry give sorry offered sorry room embarassing',
#  'sm ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end reply end sptv',
#  'know mallika sherawat yesterday find lt url gt',
#  'congrats year special cinema pas call c suprman v matrix starwars etc free bx ip pm dont miss',
#  'sorry call later meeting',
#  'tell reached',
#  'yes gauti sehwag odi series',
#  'gonna pick burger way home even move pain killing',
#  'ha ha ha good joke girl situation seeker',
#  'part checking iq',
#  'sorry roommate took forever ok come',
#  'ok lar double check wif da hair dresser already said wun cut v short said cut look nice',
#  'valued customer pleased advise following recent review mob awarded bonus prize call',
#  'today song dedicated day song u dedicate send ur valuable frnds first rply',
#  'urgent ur awarded complimentary trip eurodisinc trav aco entry claim txt dis morefrmmob shracomorsglsuplt l aj',
#  'hear new divorce barbie come ken stuff',
#  'plane give month end',
#  'wah lucky man save money hee',
#  'finished class',
#  'hi babe im home wanna something xx',
#  'k k performed',
#  'u call',
#  'waiting machan call free',
#  'thats cool gentleman treat dignity respect',
#  'like people much shy pa',
#  'operate lt gt',
#  'still looking job much ta earn',
#  'sorry call later',
#  'k call ah',
#  'ok way home hi hi',
#  'place man',
#  'yup next stop',
#  'call later network urgnt sm',
#  'real u getting yo need ticket one jacket done already used multis',
#  'yes started send request make pain came back back bed double coin factory gotta cash nitros',
#  'really still tonight babe',
#  'ela kano il download come wen ur free',
#  'yeah stand close tho catch something',
#  'sorry pain ok meet another night spent late afternoon casualty mean done stuff moro includes time sheet sorry',
#  'smile pleasure smile pain smile trouble pours like rain smile sum hurt u smile becoz someone still love see u smiling',
#  'please call customer service representative pm guaranteed cash prize',
#  'havent planning buy later check already lido got show e afternoon u finish work already',
#  'free ringtone waiting collected simply text password mix verify get usher britney fml po box mk h ppw',
#  'watching telugu movie wat abt u',
#  'see finish load loan pay',
#  'hi wk ok hols yes bit run forgot hairdresser appointment four need get home n shower beforehand cause prob u',
#  'see cup coffee animation',
#  'please text anymore nothing else say',
#  'okay name ur price long legal wen pick u ave x am xx',
#  'still looking car buy gone driving test yet',
#  'per request melle melle oru minnaminunginte nurungu vettam set callertune caller press copy friend callertune',
#  'wow right mean guess gave boston men changed search location nyc something changed cuz signin page still say boston',
#  'umma life vava umma love lot dear',
#  'thanks lot wish birthday thanks making birthday truly memorable',
#  'aight hit get cash',
#  'would ip address test considering computer minecraft server',
#  'know grumpy old people mom like better lying always one play joke',
#  'dont worry guess busy',
#  'plural noun research',
#  'going dinner msg',
#  'ok wif co like try new thing scared u dun like mah co u said loud',
#  'gent trying contact last weekend draw show prize guaranteed call claim code k valid hr ppm',
#  'wa ur openin sentence formal anyway fine juz tt eatin much n puttin weight haha anythin special happened',
#  'entered cabin pa said happy b day bos felt special askd lunch lunch invited apartment went',
#  'winner u specially selected receive holiday flight inc speak live operator claim p min',
#  'goodo yes must speak friday egg potato ratio tortilla needed',
#  'hmm uncle informed paying school directly pls buy food',
#  'private account statement show unredeemed bonus point claim call identifier code expires',
#  'urgent mobile awarded bonus caller prize final try contact u call landline box wr c ppm',
#  'new address apple pair malarky',
#  'today voda number ending selected receive award match please call quoting claim code standard rate app',
#  'going sao mu today done',
#  'predict wat time finish buying',
#  'good stuff',
#  'know yetunde sent money yet sent text bother sending dont involve anything imposed anything first place apologise',
#  'room',
#  'hey girl r u hope u r well del r bak long time c give call sum time lucyxx',
#  'k k much cost',
#  'home',
#  'dear call tmorrow pls accomodate',
#  'first answer question',
#  'sunshine quiz wkly q win top sony dvd player u know country algarve txt ansr sp tyrone',
#  'want get laid tonight want real dogging location sent direct ur mob join uk largest dogging network bt txting gravel nt ec p msg p',
#  'haf msn yijue hotmail com',
#  'call meet',
#  'check room befor activity',
#  'rcv msg chat svc free hardcore service text go u get nothing u must age verify yr network try',
#  'got c lazy type forgot lect saw pouch like v nice',
#  'k text way',
#  'sir waiting mail',
#  'swt thought nver get tired little thing lovable person coz somtimes little thing occupy biggest part heart gud ni',
#  'know pls open back',
#  'yes see ya dot',
#  'whats staff name taking class u',
#  'freemsg replied text randy sexy female live local luv hear u netcollex ltd p per msg reply stop end',
#  'ummma call check life begin qatar pls pray hard',
#  'k deleted contact',
#  'sindu got job birla soft',
#  'wine flowing nevering',
#  'yup thk cine better co need go plaza mah',
#  'ok ur typical reply',
#  'per request melle melle oru minnaminunginte nurungu vettam set callertune caller press copy friend callertune',
#  'everywhere dirt floor window even shirt sometimes open mouth come flowing dream world without half chore time joy lot tv show see guess like thing must exist like rain hail mist time done become one',
#  'aaooooright work',
#  'leaving house',
#  'hello love get interview today happy good boy think missing',
#  'customer service annoncement new year delivery waiting please call arrange delivery',
#  'winner u specially selected receive cash holiday flight inc speak live operator claim',
#  'keep safe need miss already envy everyone see real life',
#  'new car house parent new job hand',
#  'love excited day spend make happy',
#  'pls stop bootydelious f inviting friend reply yes see www sm ac u bootydelious stop send stop frnd',
#  'bangbabes ur order way u receive service msg download ur content u goto wap bangb tv ur mobile internet service menu',
#  'place ur point e culture module already',
#  'urgent trying contact last weekend draw show prize guaranteed call claim code valid hr',
#  'hi frnd best way avoid missunderstding wit beloved one',
#  'great escape fancy bridge need lager see tomo',
#  'yes completely form clark also utter waste',
#  'sir need axis bank account bank address',
#  'hmmm thk sure got time hop ard ya go free abt muz call u discus liao',
#  'time coming later',
#  'bloody hell cant believe forgot surname mr ill give u clue spanish begin',
#  'well gonna finish bath good fine night',
#  'let know got money carlos make call',
#  'u still going mall',
#  'turn friend staying whole show back til lt gt feel free go ahead smoke lt gt worth',
#  'text doesnt reply let know log',
#  'hi spoke maneesha v like know satisfied experience reply toll free yes',
#  'lifted hope offer money need especially end month approach hurt studying anyways gr weekend',
#  'lol u trust',
#  'ok gentleman treat dignity respect',
#  'guy close',
#  'going nothing great bye',
#  'hello handsome finding job lazy working towards getting back net mummy boytoy miss',
#  'haha awesome minute',
#  'please call customer service representative freephone pm guaranteed cash prize',
#  'got xmas radio time get',
#  'jus reached home go bathe first si using net tell u finish k',
#  'unique enough find th august www areyouunique co uk',
#  'sorry joined league people dont keep touch mean great deal friend time even great personal cost great week',
#  'hi finally completed course',
#  'stop however suggest stay someone able give or every stool',
#  'hope settled new school year wishin gr day',
#  'gud mrng dear hav nice day',
#  'u got person story',
#  'hamster dead hey tmr meet pm orchard mrt',
#  'hi kate evening hope see tomorrow bit bloody babyjontet txt back u xxx',
#  'found enc lt gt',
#  'sent lt gt buck',
#  'hello darlin ive finished college txt u finish u love kate xxx',
#  'account refilled successfully inr lt decimal gt keralacircle prepaid account balance r lt decimal gt transaction id kr lt gt',
#  'goodmorning sleeping ga',
#  'u call alter ok',
#  'say like dat dun buy ericsson oso cannot oredi lar',
#  'entered cabin pa said happy b day bos felt special askd lunch lunch invited apartment went',
#  'aight yo dat straight dogg',
#  'please give u connection today lt decimal gt refund bill',
#  'shoot big load get ready',
#  'bruv hope great break rewarding semester',
#  'home always chat',
#  'k k good study well',
#  'yup noe leh',
#  'sound great home',
#  'finally match heading towards draw prediction',
#  'tired slept well past night',
#  'easy ah sen got selected mean good',
#  'take exam march',
#  'yeah think use gt atm register sure anyway help let know sure ready',
#  'ok prob take ur time',
#  'o called ubandu run without installing hard disk use o copy important file system give repair shop',
#  'sorry call later',
#  'u say leh course nothing happen lar say v romantic jus bit lor thk e nite scenery nice leh',
#  'new mobile must go txt nokia collect today www tc biz optout gbp mtmsg',
#  'would really appreciate call need someone talk',
#  'u meet ur dream partner soon ur career flyng start find free txt horo followed ur star sign e g horo aries',
#  'hey company elama po mudyadhu',
#  'life strict teacher bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lesson happy morning',
#  'dear good morning',
#  'get gandhipuram walk cross cut road right side lt gt street road turn first right',
#  'dear going rubber place',
#  'sorry battery died yeah',
#  'yes tv always available work place',
#  'text meet someone sexy today u find date even flirt u join p reply name age eg sam msg recd thirtyeight penny',
#  'printed oh lt gt come upstairs',
#  'ill little closer like bus stop street',
#  'wil reach',
#  'new theory argument win situation loses person dont argue ur friend kick amp say always correct',
#  'u secret admirer looking make contact u find r reveal think ur special call',
#  'tomarrow final hearing laptop case cant',
#  'pleassssssseeeeee tel v avent done sportsx',
#  'okay shining meant signing sound better',
#  'although told u dat baig face watch really like e watch u gave co fr u thanx everything dat u done today touched',
#  'u remember old commercial',
#  'late said website dont slipper',
#  'asked call ok',
#  'kallis wont bat nd inning',
#  'didnt work oh ok goodnight fix ready time wake dearly missed good night sleep',
#  'congratulation ur awarded cd voucher gift guaranteed free entry wkly draw txt music tncs www ldew com win ppmx age',
#  'ranjith cal drpd deeraj deepak min hold',
#  'wen ur lovable bcums angry wid u dnt take seriously coz angry childish n true way showing deep affection care n luv kettoda manda nice day da',
#  '',
#  'ups day also shipping company take wks way usps take week get lag may bribe nipost get stuff',
#  'back lemme know ready',
#  'necessarily expect done get back though headin',
#  'mmm yummy babe nice jolt suzy',
#  'lover need',
#  'tried contact reply offer video handset anytime network min unlimited text camcorder reply call',
#  'parked next mini coming today think',
#  'yup',
#  'anyway going shopping co si done yet dun disturb u liao',
#  'luton ring ur around h',
#  'hey really horny want chat see naked text hot text charged pm unsubscribe text stop',
#  'dint come u',
#  'wana plan trip sometme',
#  'sure yet still trying get hold',
#  'ur ringtone service changed free credit go club mobile com choose content stop txt club stop p wk club po box mk wt',
#  'evo download flash jealous',
#  'ringtone club get uk single chart mobile week choose top quality ringtone message free charge',
#  'come mu sorting narcotic situation',
#  'night ended another day morning come special way may smile like sunny ray leaf worry blue blue bay',
#  'hmv bonus special pound genuine hmv voucher answer easy question play send hmv info www percent real com',
#  'usf guess might well take car',
#  'objection bf coming',
#  'thanx',
#  'tell rob mack gf theater',
#  'awesome see bit',
#  'sent type food like',
#  'done handed celebration full swing yet',
#  'got called tool',
#  'wen u miss someone person definitely special u person special miss keep touch gdeve',
#  'ok asked money far',
#  'okie',
#  'yeah think usual guy still passed last night get ahold anybody let know throw',
#  'k might come tonight class let early',
#  'ok',
#  'hi baby im cruisin girl friend r u give call hour home thats alright fone fone love jenny xxx',
#  'life mean lot love life love people life world call friend call world ge',
#  'dear shall mail tonite busy street shall update tonite thing looking ok varunnathu edukkukayee raksha ollu good one real sense',
#  'hey told name gautham ah',
#  'haf u found feel stupid da v cam working',
#  'oops got bit',
#  'much buzy',
#  'accidentally deleted message resend please',
#  'mobile customer may claim free camera phone upgrade pay go sim card loyalty call offer end thfeb c apply',
#  'unless situation go gurl would appropriate',
#  'hurt tease make cry end life die plz keep one rose grave say stupid miss u nice day bslvyl',
#  'cant pick phone right pls send message',
#  'need coffee run tomo believe time week already',
#  'awesome remember last time got somebody high first time diesel v',
#  'shit really shocking scary cant imagine second def night u think somewhere could crash night save taxi',
#  'oh way food fridge want go meal tonight',
#  'womdarfull actor',
#  'sm ac blind date u rodds aberdeen united kingdom check http img sm ac w icmb cktz r blind date send hide',
#  'yup remb think book',
#  'jos ask u wana meet',
#  'lol yes friendship hanging thread cause u buy stuff',
#  'themob check newest selection content game tone gossip babe sport keep mobile fit funky text wap',
#  'garage key bookshelf',
#  'today accept day u accept brother sister lover dear best clos lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rply mean enemy',
#  'think ur smart win week weekly quiz text play c winnersclub po box uz gbp week',
#  'say give call friend got money definitely buying end week',
#  'hi way u day normal way real ur unique hope know u rest mylife hope u find wot lost',
#  'made day great day',
#  'k k advance happy pongal',
#  'hmmm guess go kb n power yoga haha dunno tahan power yoga anot thk got lo oso forgot liao',
#  'really dude friend afraid',
#  'december mobile mths entitled update latest colour camera mobile free call mobile update co free',
#  'coffee cake guess',
#  'merry christmas babe love ya kiss',
#  'hey dont go watch x men lunch haha',
#  'cud u tell ppl im gona b bit l co bus hav gon past co full im still waitin pete x',
#  'would great guild could meet bristol road somewhere get touch weekend plan take flight good week',
#  'problem',
#  'call message missed call',
#  'hi da today class',
#  'say good sign well know track record reading woman',
#  'cool text parked',
#  'reading text sent meant joke read light',
#  'k k apo k good movie',
#  'maybe could get book tomo return immediately something',
#  'call germany penny per minute call fixed line via access number prepayment direct access',
#  'chance might evaporated soon violated privacy stealing phone number employer paperwork cool please contact report supervisor',
#  'valentine day special win quiz take partner trip lifetime send go p msg rcvd custcare',
#  'ta daaaaa home babe still',
#  'cool come havent wined dined',
#  'sleeping surfing',
#  'sorry call later',
#  'u calling right call hand phone',
#  'ok great thanx lot',
#  'take post come must text happy reading one wiv hello caroline end favourite bless',
#  'u hiding stranger',
#  'interested like',
#  'sister cleared two round birla soft yesterday',
#  'gudnite tc practice going',
#  'dis yijue jus saw ur mail case huiming havent sent u num dis num',
#  'one small prestige problem',
#  'fancy shag interested sextextuk com txt xxuk suzy txts cost per msg tncs website x',
#  'checking really miss seeing jeremiah great month',
#  'nah help never iphone',
#  'car hour half going apeshit',
#  'today sorry day ever angry ever misbehaved hurt plz plz slap urself bcoz ur fault basically good',
#  'yo guy ever figure much need alcohol jay trying figure much safely spend weed',
#  'lt gt ish minute minute ago wtf',
#  'thank calling forgot say happy onam sirji fine remembered met insurance person meet qatar insha allah rakhesh ex tata aig joined tissco tayseer',
#  'congratulation ur awarded cd voucher gift guaranteed free entry wkly draw txt music tncs www ldew com win ppmx age',
#  'ur cash balance currently pound maximize ur cash send cash p msg cc hg suite land row w j hl',
#  'actor work work evening sleep late since unemployed moment always sleep late unemployed every day saturday',
#  'hello got st andrew boy long way cold keep posted',
#  'ha ha cool cool chikku chikku db',
#  'oh ok prob',
#  'check audrey status right',
#  'busy trying finish new year looking forward finally meeting',
#  'good afternoon sunshine dawn day refreshed happy alive breathe air smile think love always',
#  'well know z take care worry',
#  'update_now xmas offer latest motorola sonyericsson nokia free bluetooth double min txt orange call mobileupd call optout f q',
#  'discount code rp stop message reply stop www regalportfolio co uk customer service',
#  'wat uniform get',
#  'cool text ready',
#  'hello boytoy geeee miss already woke wish bed cuddling love',
#  'spoil bed well',
#  'going bath msg next lt gt min',
#  'cant keep talking people sure pay agree price pls tell want really buy much willing pay',
#  'thanks ringtone order reference charged gbp per week unsubscribe anytime calling customer service',
#  'say happen',
#  'could seen recognise face',
#  'well lot thing happening lindsay new year sigh bar ptbo blue heron something going',
#  'keep payasam rinu brings',
#  'taught ranjith sir called sm like becaus he verifying project prabu told today pa dont mistake',
#  'guess worried must know way body repair quite sure worry take slow first test guide ovulation relax nothing said reason worry keep followin',
#  'yeah sure give couple minute track wallet',
#  'hey leave big deal take care',
#  'hey late ah meet',
#  'double min txts month free bluetooth orange available sony nokia motorola phone call mobileupd call optout n dx',
#  'took mr owl lick',
#  'customer place call',
#  'mm time dont like fun',
#  'mths half price orange line rental latest camera phone free phone mths call mobilesdirect free update stoptxt',
#  'yup lunch buffet u eat already',
#  'huh late fr dinner',
#  'hey sat going intro pilate kickboxing',
#  'morning ok',
#  'yes think office lap room think thats last day didnt shut',
#  'pick bout ish time going',
#  'performance award calculated every two month current one month period',
#  'actually sleeping still might u call back text gr rock si send u text wen wake',
#  'always putting business put picture as facebook one open people ever met would think picture room would hurt make feel violated',
#  'good evening sir al salam wahleykkum sharing happy news grace god got offer tayseer tissco joined hope fine inshah allah meet sometime rakhesh visitor india',
#  'hmmm k want change field quickly da wanna get system administrator network administrator',
#  'free ringtone text first poly text get true tone help st free tone x pw e nd txt stop',
#  'dear chechi talk',
#  'hair cream shipped',
#  'none happening til get though',
#  'yep great loxahatchee xmas tree burning lt gt start hour',
#  'haha get used driving usf man know lot stoner',
#  'well slightly disastrous class pm fav darling hope day ok coffee wld good stay late tomorrow time place always',
#  'hello good week fancy drink something later',
#  'headin towards busetop',
#  'message text missing sender name missing number missing sent date missing missing u lot thats everything missing sent via fullonsms com',
#  'come room point iron plan weekend',
#  'co want thing',
#  'okies go yan jiu skip ard oso go cine den go mrt one blah blah blah',
#  'bring home wendy',
#  'dating service cal l box sk ch',
#  'whatsup dont u want sleep',
#  'alright new goal',
#  'free entry weekly competition text word win c www txttowin co uk',
#  'alright head minute text meet',
#  'send logo ur lover name joined heart txt love name name mobno eg love adam eve yahoo pobox w wq txtno ad p',
#  'yes last week taking live call',
#  'someone contacted dating service entered phone fancy find call landline pobox n tf p',
#  'siva hostel aha',
#  'urgent mobile number awarded prize guaranteed call land line claim valid hr',
#  'send ur friend receive something ur voice speaking expression childish naughty sentiment rowdy ful attitude romantic shy attractive funny lt gt irritating lt gt lovable reply',
#  'ok ok guess',
#  'aathi dear',
#  'pain urination thing else',
#  'esplanade mind giving lift co got car today',
#  'wnt buy bmw car urgently vry urgent hv shortage lt gt lac source arng dis amt lt gt lac thats prob',
#  'home watching tv lor',
#  'usually take fifteen fucking minute respond yes question',
#  'congrats nokia video camera phone call call cost ppm ave call min vary mobile close post bcm ldn wc n xx',
#  'booked ticket pongal',
#  'available like right around hillsborough amp lt gt th',
#  'message sent askin lt gt dollar shoul pay lt gt lt gt',
#  'ask g iouri told story like ten time already',
#  'long applebees fucking take',
#  'hi hope u get txt journey hasnt gd min late think',
#  'like love arrange',
#  'yes really great bhaji told kallis best cricketer sachin world tough get',
#  'supposed wake gt',
#  'oic saw tot din c found group liao',
#  'sorry call later',
#  'hey hey werethe monkeespeople say monkeyaround howdy gorgeous howu doin foundurself jobyet sausage love jen xxx',
#  'sorry battery died come getting gram place',
#  'well done blimey exercise yeah kinda remember wot hmm',
#  'wont get concentration dear know mind everything',
#  'lol made plan new year',
#  'min later k',
#  'hank lotsly',
#  'thanks hope good day today',
#  'k k detail want transfer acc enough',
#  'ok tell stay yeah tough optimistic thing improve month',
#  'loan purpose homeowner tenant welcome previously refused still help call free text back help',
#  'si si think ill go make oreo truffle',
#  'look amy ure beautiful intelligent woman like u lot know u like like worry',
#  'hope result consistently intelligent kind start asking practicum link keep ear open best ttyl',
#  'call cost guess isnt bad miss ya need ya want ya love ya',
#  'going thru different feeling wavering decision coping individual time heal everything believe',
#  'u go phone gonna die stay',
#  'great never better day give even reason thank god',
#  'upgrdcentre orange customer may claim free camera phone upgrade loyalty call offer end th july c apply opt available',
#  'sorry call later ok bye',
#  'ok way railway',
#  'great princess love giving receiving oral doggy style fave position enjoy making love lt gt time per night',
#  'put stuff road keep getting slippery',
#  'going ride bike',
#  'yup need jus wait e rain stop',
#  'many company tell language',
#  'okmail dear dave final notice collect tenerife holiday cash award call landline tc sae box cw wx ppm',
#  'long since screamed princess',
#  'nothing meant money enters account bank remove flat rate someone transfered lt gt account lt gt dollar got removed bank differ charge also differ sure trust ja person sending account detail co',
#  'want get laid tonight want real dogging location sent direct ur mob join uk largest dogging network txting moan nyt ec p msg p',
#  'nice line said broken heart plz cum time infront wise trust u good',
#  'ok gonna head usf like fifteen minute',
#  'love aathi love u lot',
#  'tension ah machi problem',
#  'k pick another th done',
#  'guy getting back g said thinking staying mcr',
#  'almost see u sec',
#  'yo carlos friend already asking working weekend',
#  'watching tv lor',
#  'thank baby cant wait taste real thing',
#  'change fb jaykwon thuglyfe falconerf',
#  'win really side long time',
#  'free message activate free text message replying message word free term condition visit www com',
#  'dear reached railway happen',
#  'depends quality want type sent boye faded glory want ralphs maybe',
#  'think fixed send test message',
#  'sorry man account dry would want could trade back half could buy shit credit card',
#  'congrats year special cinema pas call c suprman v matrix starwars etc free bx ip pm dont miss',
#  'sorry meeting call later',
#  'class lt gt reunion',
#  'free call',
#  'got meh',
#  'nope think go monday sorry replied late',
#  'told accenture confirm true',
#  'kate jackson rec center ish right',
#  'dear reache room',
#  'fighting world easy u either win lose bt fightng close u dificult u lose u lose u win u still lose',
#  'come',
#  'check nuerologist',
#  'lolnice went fish water',
#  'congratulation week competition draw u prize claim call b c stop sm ppm',
#  'waiting e car dat bored wat co wait outside got nothing home stuff watch tv wat',
#  'maybe westshore hyde park village place near house',
#  'know anthony bringing money school fee pay rent stuff like thats need help friend need',
#  'significance',
#  'opinion jada kusruthi lovable silent spl character matured stylish simple pls reply',
#  'latest g still scrounge ammo want give new ak try',
#  'prabha soryda realy frm heart sory',
#  'lol ok forgiven',
#  'jst change tat',
#  'guaranteed latest nokia phone gb ipod mp player prize txt word collect ibhltd ldnw h p mtmsgrcvd',
#  'competition',
#  'boltblue tone p reply poly mono eg poly cha cha slide yeah slow jamz toxic come stop tone txt',
#  'credit topped http www bubbletext com renewal pin tgxxrz',
#  'way transport le problematic sat night way u want ask n join bday feel free need know definite no booking fri',
#  'usually person unconscious child adult may behave abnormally call',
#  'ebay might le elsewhere',
#  'shall come get pickle',
#  'gonna go get taco',
#  'rude campus',
#  'urgent mobile awarded bonus caller prize nd attempt contact call box qu',
#  'hi b ard christmas enjoy n merry x ma',
#  'today offer claim ur worth discount voucher text yes savamob member offer mobile c sub unsub reply x',
#  'yes pretty lady like single',
#  'recieve tone within next hr term condition please see channel u teletext pg',
#  'jay say double faggot',
#  'private account statement show un redeemed point call identifier code expires',
#  'today sunday sunday holiday work',
#  'gudnite tc practice going',
#  'late',
#  'called hoping l r malaria know miss guy miss ban big pls give love especially great day',
#  'good afternoon love go day hope maybe got lead job think boytoy send passionate kiss across sea',
#  'probably gonna see later tonight lt',
#  'maybe fat finger press button know',
#  'ummmmmaah many many happy return day dear sweet heart happy birthday dear',
#  'tirupur da started office call',
#  'www applausestore com monthlysubscription p msg max month csc web age stop txt stop',
#  'famous quote develop ability listen anything unconditionally without losing temper self confidence mean married',
#  'going college pa else ill come self pa',
#  'oclock mine bash flat plan',
#  'girl stay bed girl need recovery time id rather pas fun cooped bed',
#  'special',
#  'know need get hotel got invitation apologise cali sweet come english bloke weddin',
#  'sorry took long omw',
#  'wait lt gt min',
#  'ok give minute think see btw alibi cutting hair whole time',
#  'imagine finally get sink bath put pace maybe even eat left also imagine feel cage cock surrounded bath water reminding always owns enjoy cuck',
#  'hurry weed deficient like three day',
#  'sure get acknowledgement astoundingly tactless generally faggy demand blood oath fo',
#  'ok every night take warm bath drink cup milk see work magic still need loose weight know',
#  'look frying pan case cheap book perhaps silly frying pan likely book',
#  'well uv cause mutation sunscreen like essential thesedays',
#  'lunch online',
#  'know friend already told',
#  'hi princess thank pic pretty',
#  'aiyo u always c ex one dunno abt mei reply first time u reply fast lucky workin huh got bao ur sugardad ah gee',
#  'hi msg office',
#  'thanx e brownie v nice',
#  'geeeee love much barely stand',
#  'gent trying contact last weekend draw show prize guaranteed call claim code k valid hr ppm',
#  'fuck babe miss already know let send money towards net need want crave',
#  'ill call u mrw ninish address icky american freek wont stop callin bad jen k eh',
#  'oooh bed ridden ey thinking',
#  'anyways go gym whatever love smile hope ok good day babe miss much already',
#  'love daddy make scream pleasure going slap as dick',
#  'wot u wanna missy',
#  'yar lor wait mum finish sch lunch lor whole morning stay home clean room room quite clean hee',
#  'know lab goggles went',
#  'open door',
#  'waiting call',
#  'nope waiting sch daddy',
#  'cash prize claim call',
#  'tired arguing week week want',
#  'wait sch finish ard',
#  'mobile number claim call u back ring claim hot line',
#  'arngd marriage u r walkin unfortuntly snake bite u bt love marriage dancing frnt snake amp sayin bite bite',
#  'huh early dinner outside izzit',
#  'ok anyway need change said',
#  'tried contact reply offer min textand new video phone call reply free delivery tomorrow',
#  'ex wife able kid want kid one day',
#  'scotland hope showing jjc tendency take care live dream',
#  'tell u headache want use hour sick time',
#  'dun thk quit yet hmmm go jazz yogasana oso go meet em lesson den',
#  'pete please ring meive hardly gotany credit',
#  'ya srsly better yi tho',
#  'meeting call later',
#  'ur chance win wkly shopping spree txt shop c www txt shop com custcare x p wk',
#  'specially selected receive pound award call line close cost ppm c apply ag promo',
#  'private account statement show un redeemed point call identifier code expires',
#  'still grand prix',
#  'met stranger choose friend long world stand friendship never end let friend forever gud nitz',
#  'great',
#  'gud mrng dear nice day',
#  'important customer service announcement call freephone',
#  'exhausted train morning much wine pie sleep well',
#  'going buy mum present ar',
#  'mind blastin tsunami occur rajnikant stopped swimming indian ocean',
#  'u sending home first ok lor ready yet',
#  'speaking cash yet',
#  'happy come noon',
#  'meet lunch la',
#  'take care n get well soon',
#  'xclusive clubsaisai morow soiree speciale zouk nichols paris free rose lady info',
#  'meant say cant wait see u getting bored bridgwater banter',
#  'neva mind ok',
#  'fine imma get drink somethin want come find',
#  'day kick euro u kept date latest news result daily removed send get txt stop',
#  'valentine game send dis msg ur friend answer r someone really love u ques colour suit best rply',
#  'many dependent',
#  'thanx today cer nice catch ave find time often oh well take care c u soon c',
#  'called said choose future',
#  'happy valentine day know early hundred handsomes beauty wish thought finish aunty uncle st',
#  'like v shock leh co telling shuhui like telling leona also like dat almost know liao got ask abt ur reaction lor',
#  'family happiness',
#  'come n pick come immediately aft ur lesson',
#  'let snow let snow kind weather brings ppl together friendship grow',
#  'dear got lt gt dollar hi hi',
#  'good word word may leave u dismay many time',
#  'make sure alex know birthday fifteen minute far concerned',
#  'sorry got thing may pub later',
#  'nah straight bring bud drink something actually little useful straight cash',
#  'haha good hear officially paid market th',
#  'many lick take get center tootsie pop',
#  'yup thk r e teacher said make face look longer darren ask cut short',
#  'new textbuddy chat horny guy ur area p free receive search postcode gaytextbuddy com txt one name',
#  'today vodafone number ending selected receive award number match call receive award',
#  'please dont say like hi hi hi',
#  'thank u',
#  'oh forwarded message thought send',
#  'got seventeen pound seven hundred ml hope ok',
#  'dear voucher holder claim week offer pc go http www e tlp co uk expressoffer t c apply stop text txt stop',
#  'n funny',
#  'sweetheart hope kind day one load reason smile biola',
#  'login dat time dad fetching home',
#  'shower baby',
#  'askd u question hour answer',
#  'well imma definitely need restock thanksgiving let know',
#  'said kiss kiss sound effect gorgeous man kind person need smile brighten day',
#  'probably gonna swing wee bit',
#  'ya nice ready thursday',
#  'allo braved bus taken train triumphed mean b ham jolly good rest week',
#  'watching cartoon listening music amp eve go temple amp church u',
#  'mind ask happened dont say uncomfortable',
#  'private account statement show un redeemed point call identifier code expires',
#  'prob send email',
#  'cash prize claim call c rstm sw s ppm',
#  'thats cool sometimes slow gentle sonetimes rough hard',
#  'gonna say sorry would normal starting panic time sorry seeing tuesday',
#  'wait know wesley town bet hella drug',
#  'fine miss much',
#  'u got person story',
#  'tell drug dealer getting impatient',
#  'sun cant come earth send luv ray cloud cant come river send luv rain cant come meet u send care msg u gud evng',
#  'place man',
#  'doesnt make sense take unless free need know wikipedia com',
#  'premium phone service call',
#  'sea lay rock rock envelope envelope paper paper word',
#  'mum repent',
#  'sorry going home first daddy come fetch later',
#  'leave de start prepare next',
#  'yes baby study position kama sutra',
#  'en chikku nange bakra msg kalstiya tea coffee',
#  'carlos minute still need buy',
#  'pay lt decimal gt lakh',
#  'good evening ttyl',
#  'u receive msg',
#  'ho ho big belly laugh see ya tomo',
#  'sm ac sun post hello seem cool wanted say hi hi stop send stop',
#  'get ur st ringtone free reply msg tone gr top tone phone every week per wk opt send stop',
#  'ditto worry saying anything anymore like said last night whatever want peace',
#  'got lt gt way could pick',
#  'dont knw pa drink milk',
#  'maybe say hi find got card great escape wetherspoons',
#  'piggy r u awake bet u still sleeping going lunch',
#  'cause freaky lol',
#  'missed call cause yelling scrappy miss u wait u come home lonely today',
#  'hex place talk explain',
#  'log wat sdryb',
#  'xy going e lunch',
#  'hi sue year old work lapdancer love sex text live bedroom text sue textoperator g da ppmsg',
#  'wanted ask wait finish lect co lect finish hour anyway',
#  'finished work yet',
#  'every king cry baby every great building map imprtant u r today u wil reach tomorw gud ni',
#  'dear cherthala case u r coming cochin pls call bfore u start shall also reach accordingly tell day u r coming tmorow engaged an holiday',
#  'thanks love torch bold',
#  'forwarded please call immediately urgent message waiting',
#  'farm open',
#  'sorry trouble u buy dad big small sat n sun thanx',
#  'sister law hope great month saying hey abiola',
#  'purchase stuff today mail po box number',
#  'ah poop look like ill prob send laptop get fixed cuz gpu problem',
#  'good good job like entrepreneur',
#  'aight close still around alex place',
#  'meet corporation st outside gap see mind working',
#  'mum ask buy food home',
#  'k u also dont msg reply msg',
#  'much r willing pay',
#  'sorry call later',
#  'important prevent dehydration giving enough fluid',
#  'thats bit weird even supposed happening good idea sure pub',
#  'true dear sat pray evening felt sm time',
#  'think get away trek long family town sorry',
#  'wanna gym harri',
#  'quite late lar ard anyway wun b drivin',
#  'review keep fantastic nokia n gage game deck club nokia go www cnupdates com newsletter unsubscribe alert reply word',
#  'mths half price orange line rental latest camera phone free phone mths call mobilesdirect free update stoptxt c',
#  'height confidence aeronautics professor wer calld amp wer askd sit aeroplane aftr sat wer told dat plane w made student dey hurried plane bt didnt move said made student wont even start datz confidence',
#  'seems like weird timing night g want come smoke day shitstorm attributed always coming making everyone smoke',
#  'pm cost p',
#  'save stress person dorm account send account detail money sent',
#  'also know lunch menu da know',
#  'stuff sell tell',
#  'urgent nd attempt contact u u call b csbcm wc n xx callcost ppm mobilesvary max',
#  'book lesson msg call work sth going get spec membership px',
#  'guaranteed cash prize claim yr prize call customer service representative pm',
#  'macha dont feel upset assume mindset believe one evening wonderful plan u let life begin call anytime',
#  'oh send address',
#  'fine anytime best',
#  'wondar full flim',
#  'ya even cooky jelly',
#  'world running still maybe feeling admit mad correction let call life keep running world may u r also running let run',
#  'got look scrumptious daddy want eat night long',
#  'co lar ba dao ok pm lor u never ask go ah said u would ask fri said u ask today',
#  'alright omw gotta change order half th',
#  'exactly anyways far jide study visiting',
#  'dunno u ask',
#  'email alertfrom jeri stewartsize kbsubject low cost prescripiton drvgsto listen email call',
#  'spring coming early yay',
#  'lol feel bad use money take steak dinner',
#  'even u dont get trouble convincing tel twice tel neglect msg dont c read dont reply',
#  'leaving qatar tonite search opportunity went fast pls add ur prayer dear rakhesh',
#  'one talking',
#  'thanks looking really appreciate',
#  'hi customer loyalty offer new nokia mobile txtauction txt word start get ctxt tc p mtmsg',
#  'wish',
#  'haha mayb u rite u know well da feeling liked someone gd lor u faster go find one gal group attached liao',
#  'yes glad made',
#  'well little time thing good time ahead',
#  'got room soon put clock back til shouted everyone get realised wahay another hour bed',
#  'ok may free gym',
#  'men like shorter lady gaze eye',
#  'dunno jus say go lido time',
#  'promise take good care princess run please send pic get chance ttyl',
#  'u subscribed best mobile content service uk per day send stop helpline',
#  'reason spoken year anyways great week best exam',
#  'monday next week give full gist',
#  'realize year thousand old lady running around tattoo',
#  'important customer service announcement premier',
#  'dont gimme lip caveboy',
#  'get library',
#  'realy sorry recognise number confused r u please',
#  'didnt holla',
#  'cant think anyone spare room top head',
#  'faith make thing possible hope make thing work love make thing beautiful may three christmas merry christmas',
#  'u made appointment',
#  'call carlos phone vibrate acting might hear text',
#  'romantic paris night flight book next year call t c apply',
#  'grandma oh dear u still ill felt shit morning think hungover another night leave sat',
#  'urgent ur guaranteed award still unclaimed call closingdate claimcode pmmorefrommobile bremoved mobypobox l yf',
#  'nothing jus tot u would ask co u ba gua went mt faber yest yest jus went already mah today going jus call lor',
#  'wishing family merry x ma happy new year advance',
#  'ur awarded city break could win summer shopping spree every wk txt store skilgme tscs winawk age perwksub',
#  'nt goin got somethin unless meetin dinner lor haha wonder go ti time',
#  'sorry call later',
#  'cant pick phone right pls send message',
#  'lol know dramatic school already closed tomorrow apparently drive inch snow supposed get',
#  'getting anywhere damn job hunting',
#  'lol u drunkard hair moment yeah still tonight wats plan',
#  'idc get weaseling way shit twice row',
#  'wil lt gt minute got space',
#  'sleeping surfing',
#  'thanks picking trash',
#  'go tell friend sure want live smoke much spend hour begging come smoke',
#  'hi kate lovely see tonight ill phone tomorrow got sing guy gave card xxx',
#  'happy new year dear brother really miss got number decided send text wishing happiness abiola',
#  'mean get door',
#  'opinion jada kusruthi lovable silent spl character matured stylish simple pls reply',
#  'hmmm thought said hour slave late punish',
#  'beerage',
#  'important customer service announcement premier call freephone',
#  'dont think turn like randomlly within min opening',
#  'supposed make still town though',
#  'time fix spelling sometimes get completely diff word go figure',
#  'ever thought living good life perfect partner txt back name age join mobile community p sm',
#  'free top polyphonic tone call national rate get toppoly tune sent every week text subpoly per pole unsub',
#  'gud mrng dear hav nice day',
#  'hoping enjoyed game yesterday sorry touch pls know fondly bein thot great week abiola',
#  'e best ur driving tmr',
#  'u dogbreath sounding like jan c al',
#  'omg want scream weighed lost weight woohoo',
#  'generally one uncountable noun u dictionary piece research',
#  'really getting hanging around',
#  'orange customer may claim free camera phone upgrade loyalty call offer end thmarch c apply opt availa',
#  'petey boy whereare friendsare thekingshead come canlove nic',
#  'ok msg u b leave house',
#  'gimme lt gt minute ago',
#  'last chance claim ur worth discount voucher today text shop savamob offer mobile c savamob pobox uz sub',
#  'appt lt time gt fault u listen told u twice',
#  'free st week nokia tone ur mobile every week txt nokia get txting tell ur mate www getzed co uk pobox w wq norm p tone',
#  'guaranteed award even cashto claim ur award call free stop getstop php rg jx',
#  'k',
#  'dled imp',
#  'sure make sure know smokin yet',
#  'boooo always work quit',
#  'taking half day leave bec well',
#  'ugh wanna get bed warm',
#  'nervous lt gt',
#  'ring come guy costume gift future yowifes hint hint',
#  'congratulation ur awarded either cd gift voucher free entry weekly draw txt music tncs www ldew com win ppmx age',
#  'borrow ur bag ok',
#  'u outbid simonwatson shinco dvd plyr bid visit sm ac smsrewards end bid notification reply end',
#  'boytoy miss happened',
#  'lot used one babe model help youi bring match',
#  'also bringing galileo dobby',
#  'responding',
#  'boo babe u enjoyin yourjob u seemed b gettin well hunny hope ure ok take care llspeak u soonlots loveme xxxx',
#  'good afternoon starshine boytoy crave yet ache fuck sip cappuccino miss babe teasing kiss',
#  'road cant txt',
#  'smsservices yourinclusive text credit pls goto www comuk net login qxj unsubscribe stop extra charge help comuk cm ae',
#  'p alfie moon child need song ur mob tell ur txt tone charity nokias poly charity polys zed profit charity',
#  'good evening ttyl',
#  'hmm bit piece lol sigh',
#  'hahaha use brain dear',
#  'hey got mail',
#  'sorry light turned green meant another friend wanted lt gt worth may around',
#  'thanks yesterday sir wonderful hope enjoyed burial mojibiola',
#  'u secret admirer reveal think u r special call opt reply reveal stop per msg recd cust care',
#  'hi mate rv u hav nice hol message say hello coz sent u age started driving stay road rvx',
#  'dear voucher holder claim week offer pc please go http www e tlp co uk expressoffer t c apply stop text txt stop',
#  'thank much skyped wit kz sura didnt get pleasure company hope good given ultimatum oh countin aburo enjoy message sent day ago',
#  'surely result offer',
#  'good morning dear great amp successful day',
#  'want anytime network min text new video phone five pound per week call reply delivery tomorrow',
#  'sir late paying rent past month pay lt gt charge felt would inconsiderate nag something give great cost didnt speak however recession wont able pay charge month hence askin well ahead month end please help thanks',
#  'tried contact offer new video phone anytime network min half price rental camcorder call reply delivery wed',
#  'last chance claim ur worth discount voucher text yes savamob member offer mobile c sub remove txt x stop',
#  'luv u soo much u understand special u r ring u morrow luv u xxx',
#  'pls send comprehensive mail paying much',
#  'prashanthettan mother passed away last night pray family',
#  'urgent call landline complimentary ibiza holiday cash await collection sae c po box sk wp ppm',
#  'k k going',
#  'meanwhile shit suite xavier decided give u lt gt second warning samantha coming playing jay guitar impress shit also think doug realizes live anymore',
#  'stomach thru much trauma swear eat better lose weight',
#  'office whats matter msg call break',
#  'yeah barely enough room two u x many fucking shoe sorry man see later',
#  'today offer claim ur worth discount voucher text yes savamob member offer mobile c sub unsub reply x',
#  'u reach orchard already u wan go buy ticket first',
#  'real baby want bring inner tigress',
#  'da run activate full version da',
#  'ah poor baby hope urfeeling bettersn luv probthat overdose work hey go careful spk u sn lot lovejen xxx',
#  'stop story told returned saying order',
#  'talk sexy make new friend fall love world discreet text dating service text vip see could meet',
#  'going take babe',
#  'hai ana tomarrow coming morning lt decimal gt ill sathy go rto office reply came home',
#  'spoon okay',
#  'say somebody named tampa',
#  'work going min',
#  'brother genius',
#  'sorry guess whenever get hold connection maybe hour two text',
#  'u find time bus coz need sort stuff',
#  'dude ive seeing lotta corvette lately',
#  'congratulation ur awarded either yr supply cd virgin record mystery gift guaranteed call t c www smsco net pm approx min',
#  'consider wall bunker shit important never play peaceful guess place high enough matter',
#  'private account statement xxxxxx show un redeemed point call identifier code expires',
#  'hello need posh bird chap user trial prod champneys put need address dob asap ta r',
#  'u want xmas free text message new video phone half price line rental call free find',
#  'well officially philosophical hole u wanna call home ready saved',
#  'going good problem still need little experience understand american customer voice',
#  'text drop x',
#  'ugh long day exhausted want cuddle take nap',
#  'talk atleast day otherwise miss best friend world shakespeare shesil lt gt',
#  'shop till u drop either k k cash travel voucher call ntt po box cr bt fixedline cost ppm mobile vary',
#  'castor need see something',
#  'sunshine quiz wkly q win top sony dvd player u know country liverpool played mid week txt ansr sp tyrone',
#  'u secret admirer looking make contact u find r reveal think ur special call',
#  'u secret admirer looking make contact u find r reveal think ur special call stopsms',
#  'reminder downloaded content already paid goto http doit mymoby tv collect content',
#  'see knew giving break time woul lead always wanting miss curfew gonna gibe til one midnight movie gonna get til need come home need getsleep anything need b studdying ear training',
#  'love give massage use lot baby oil fave position',
#  'dude go sup',
#  'yoyyooo u know change permission drive mac usb flash drive',
#  'gibbs unsold mike hussey',
#  'like talk pa able dont know',
#  'dun cut short leh u dun like ah failed quite sad',
#  'unbelievable faglord',
#  'wife knew time murder exactly',
#  'ask princess',
#  'great princess thinking',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie',
#  'ok noe u busy really bored msg u oso dunno wat colour choose one',
#  'g class early tomorrow thus trying smoke lt gt',
#  'superb thought grateful u dont everything u want mean u still opportunity happier tomorrow u today',
#  'hope good week checking',
#  'used hope agent drop since booked thing year whole boston nyc experiment',
#  'thursday night yeah sure thing work',
#  'free ringtone waiting collected simply text password mix verify get usher britney fml po box mk h ppw',
#  'probably money worry thing coming due several outstanding invoice work two three month ago',
#  'possible teach',
#  'wonder phone battery went dead tell love babe',
#  'lovely smell bus tobacco',
#  'getting worried derek taylor already assumed worst',
#  'hey charles sorry late reply',
#  'lastest stereophonics marley dizzee racal libertine stroke win nookii game flirt click themob wap bookmark text wap',
#  'give plus said grinule greet whenever speak',
#  'white fudge oreo store',
#  'january male sale hot gay chat cheaper call national rate p min cheap p min peak stop text call p min',
#  'love come took long leave zaher got word ym happy see sad left miss',
#  'sorry hurt',
#  'feel nauseous pissed eat sweet week cause today planning pig dieting week hungry',
#  'ok lor early still project meeting',
#  'call da waiting call',
#  'could ask carlos could get anybody else chip',
#  'actually send reminder today wonderful weekend',
#  'people see msg think iam addicted msging wrong bcoz don\\ know iam addicted sweet friend bslvyl',
#  'hey gave photo registered driving ah tmr wanna meet yck',
#  'dont talk ever ok word',
#  'u wana see',
#  'way school pls send ashley number',
#  'shall fine avalarr hollalater',
#  'went attend another two round today still reach home',
#  'actually deleted old website blogging magicalsongs blogspot com',
#  'k wait chikku il send aftr lt gt min',
#  'diet ate many slice pizza yesterday ugh always diet',
#  'k give kvb acc detail',
#  'oh come ah',
#  'money r lucky winner claim prize text money million give away ppt x normal text rate box w jy',
#  'really sorry b able friday hope u find alternative hope yr term going ok',
#  'congratulation ore mo owo wa enjoy wish many happy moment fro wherever go',
#  'samus shoulder yet',
#  'time think need know near campus',
#  'dear matthew please call landline complimentary lux tenerife holiday cash await collection ppm sae c box sk xh',
#  'dun wear jean lor',
#  'since side fever vomitin',
#  'k k college',
#  'urgent call landline complimentary tenerife holiday cash await collection sae c box hp yf ppm',
#  'better made friday stuffed like pig yesterday feel bleh least writhing pain kind bleh',
#  'sell ton coin sell coin someone thru paypal voila money back life pocket',
#  'theyre lot place hospital medical place safe',
#  'getting touch folk waiting company txt back name age opt enjoy community p sm',
#  'also sorta blown couple time recently id rather text blue looking weed',
#  'sent score sophas secondary application school think thinking applying research cost also contact joke ogunrinde school one le expensive one',
#  'cant wait see photo useful',
#  'ur cash balance currently pound maximize ur cash send go p msg cc po box tcr w',
#  'hey booked kb sat already lesson going ah keep sat night free need meet confirm lodging',
#  'chk ur belovd m dict',
#  'time want come',
#  'awesome lemme know whenever around',
#  'shb b ok lor thanx',
#  'beautiful truth gravity read carefully heart feel light someone feel heavy someone leaf good night',
#  'also remember get dobby bowl car',
#  'filthy story girl waiting',
#  'sorry c ur msg yar lor poor thing one night tmr u brand new room sleep',
#  'love decision feeling could decide love life would much simpler le magical',
#  'welp apparently retired',
#  'sort code acc bank natwest reply confirm sent right person',
#  '',
#  'u sure u take sick time',
#  'urgent trying contact u today draw show prize guaranteed call land line claim valid hr',
#  'watching cartoon listening music amp eve go temple amp church u',
#  'yo chad gymnastics class wanna take site say christian class full',
#  'much buzy',
#  'better still catch let ask sell lt gt',
#  'sure night menu know noon menu',
#  'u want come back beautiful necklace token heart thats give wife liking see one give dont call wait till come',
#  'willing go aptitude class',
#  'wont b trying sort house ok',
#  'yar lor wan go c horse racing today mah eat earlier lor ate chicken rice u',
#  'haha awesome omw back',
#  'yup thk e shop close lor',
#  'account number',
#  'eh u send wrongly lar',
#  'hey ad crap nite borin without ya boggy u boring biatch thanx u wait til nxt time il ave ya',
#  'ok shall talk',
#  'dont hesitate know second time weakness like keep notebook eat day anything changed day sure nothing',
#  'hey pay salary de lt gt',
#  'another month need chocolate weed alcohol',
#  'started searching get job day great potential talent',
#  'reckon need town eightish walk carpark',
#  'congrats mobile g videophones r call videochat wid mate play java game dload polyph music noline rentl',
#  'look fuckin time fuck think',
#  'yo guess dropped',
#  'carlos say mu lt gt minute',
#  'office call lt gt min',
#  'geeee miss already know think fuck wait till next year together loving kiss',
#  'yun ah ubi one say wan call tomorrow call look irene ere got bus ubi cres ubi tech park ph st wkg day n',
#  'ugh gotta drive back sd la butt sore',
#  'th july',
#  'hi im relaxing time ever get every day party good night get home tomorrow ish',
#  'wan come come lor din c stripe skirt',
#  'xmas story peace xmas msg love xmas miracle jesus hav blessed month ahead amp wish u merry xmas',
#  'number',
#  'change e one next escalator',
#  'yetunde class run water make ok pls',
#  'lot happened feel quiet beth aunt charlie working lot helen mo',
#  'wait bus stop aft ur lect lar dun c go get car come back n pick',
#  ...]

# %%
len(corpus)
# Out:
# 5572

# %% [markdown]
# #### Here we again use map fn we are only considering those elements where the len is greater than 0

# %%
y = df[list(map(lambda x : len(x) > 0, corpus))]

# %%
y = pd.get_dummies(y.label)

# %%
y.head()
# Out:
#    ham  spam
# 0    1     0
# 1    1     0
# 2    0     1
# 3    1     0
# 4    1     0

# %%
y = y.iloc[:,1]

# %%
y.shape
# Out:
# (5564,)

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 5567    1
# 5568    0
# 5569    0
# 5570    0
# 5571    0
# Name: spam, Length: 5564, dtype: uint8

# %%
import gensim 
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %% [markdown]
# ### In order to Create our Custom Model we need to pass words

# %%
data=[]
for sent in corpus:
    sent_token=sent_tokenize(sent)
    for sent in sent_token:
        data.append(simple_preprocess(sent))

# %%
data
# Out:
# [['go',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'wkly',
#   'comp',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply'],
#  ['dun', 'say', 'early', 'hor', 'already', 'say'],
#  ['nah', 'think', 'go', 'usf', 'life', 'around', 'though'],
#  ['freemsg',
#   'hey',
#   'darling',
#   'week',
#   'word',
#   'back',
#   'like',
#   'fun',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'send',
#   'rcv'],
#  ['even', 'brother', 'like', 'speak', 'treat', 'like', 'aid', 'patent'],
#  ['per',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertune',
#   'caller',
#   'press',
#   'copy',
#   'friend',
#   'callertune'],
#  ['winner',
#   'valued',
#   'network',
#   'customer',
#   'selected',
#   'receivea',
#   'prize',
#   'reward',
#   'claim',
#   'call',
#   'claim',
#   'code',
#   'kl',
#   'valid',
#   'hour'],
#  ['mobile',
#   'month',
#   'entitled',
#   'update',
#   'latest',
#   'colour',
#   'mobile',
#   'camera',
#   'free',
#   'call',
#   'mobile',
#   'update',
#   'co',
#   'free'],
#  ['gonna',
#   'home',
#   'soon',
#   'want',
#   'talk',
#   'stuff',
#   'anymore',
#   'tonight',
#   'cried',
#   'enough',
#   'today'],
#  ['six',
#   'chance',
#   'win',
#   'cash',
#   'pound',
#   'txt',
#   'csh',
#   'send',
#   'cost',
#   'day',
#   'day',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   'info'],
#  ['urgent',
#   'week',
#   'free',
#   'membership',
#   'prize',
#   'jackpot',
#   'txt',
#   'word',
#   'claim',
#   'www',
#   'dbuk',
#   'net',
#   'lccltd',
#   'pobox',
#   'ldnw',
#   'rw'],
#  ['searching',
#   'right',
#   'word',
#   'thank',
#   'breather',
#   'promise',
#   'wont',
#   'take',
#   'help',
#   'granted',
#   'fulfil',
#   'promise',
#   'wonderful',
#   'blessing',
#   'time'],
#  ['date', 'sunday'],
#  ['use',
#   'credit',
#   'click',
#   'wap',
#   'link',
#   'next',
#   'txt',
#   'message',
#   'click',
#   'http',
#   'wap',
#   'com',
#   'qjkgighjjgcbl'],
#  ['oh', 'watching'],
#  ['eh', 'remember', 'spell', 'name', 'yes', 'naughty', 'make', 'wet'],
#  ['fine', 'way', 'feel', 'way', 'gota'],
#  ['england',
#   'macedonia',
#   'dont',
#   'miss',
#   'goal',
#   'team',
#   'news',
#   'txt',
#   'ur',
#   'national',
#   'team',
#   'eg',
#   'england',
#   'try',
#   'wale',
#   'scotland',
#   'txt',
#   'poboxox',
#   'wq'],
#  ['seriously', 'spell', 'name'],
#  ['going', 'try', 'month', 'ha', 'ha', 'joking'],
#  ['pay', 'first', 'lar', 'da', 'stock', 'comin'],
#  ['aft',
#   'finish',
#   'lunch',
#   'go',
#   'str',
#   'lor',
#   'ard',
#   'smth',
#   'lor',
#   'finish',
#   'ur',
#   'lunch',
#   'already'],
#  ['ffffffffff', 'alright', 'way', 'meet', 'sooner'],
#  ['forced',
#   'eat',
#   'slice',
#   'really',
#   'hungry',
#   'tho',
#   'suck',
#   'mark',
#   'getting',
#   'worried',
#   'know',
#   'sick',
#   'turn',
#   'pizza',
#   'lol'],
#  ['lol', 'always', 'convincing'],
#  ['catch',
#   'bus',
#   'frying',
#   'egg',
#   'make',
#   'tea',
#   'eating',
#   'mom',
#   'left',
#   'dinner',
#   'feel',
#   'love'],
#  ['back', 'amp', 'packing', 'car', 'let', 'know', 'room'],
#  ['ahhh', 'work', 'vaguely', 'remember', 'feel', 'like', 'lol'],
#  ['wait', 'still', 'clear', 'sure', 'sarcastic', 'want', 'live'],
#  ['yeah',
#   'got',
#   'apologetic',
#   'fallen',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'got',
#   'caught',
#   'till',
#   'go',
#   'badly',
#   'cheer'],
#  ['tell', 'anything'],
#  ['fear', 'fainting', 'housework', 'quick', 'cuppa'],
#  ['thanks',
#   'subscription',
#   'ringtone',
#   'uk',
#   'mobile',
#   'charged',
#   'month',
#   'please',
#   'confirm',
#   'replying',
#   'yes',
#   'reply',
#   'charged'],
#  ['yup',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'timing',
#   'msg',
#   'xuhui',
#   'going',
#   'learn',
#   'nd',
#   'may',
#   'lesson'],
#  ['oops', 'let', 'know', 'roommate', 'done'],
#  ['see', 'letter', 'car'],
#  ['anything', 'lor', 'decide'],
#  ['hello',
#   'saturday',
#   'go',
#   'texting',
#   'see',
#   'decided',
#   'anything',
#   'tomo',
#   'trying',
#   'invite',
#   'anything'],
#  ['pls',
#   'go',
#   'ahead',
#   'watt',
#   'wanted',
#   'sure',
#   'great',
#   'weekend',
#   'abiola'],
#  ['forget',
#   'tell',
#   'want',
#   'need',
#   'crave',
#   'love',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['rodger',
#   'burn',
#   'msg',
#   'tried',
#   'call',
#   'reply',
#   'sm',
#   'free',
#   'nokia',
#   'mobile',
#   'free',
#   'camcorder',
#   'please',
#   'call',
#   'delivery',
#   'tomorrow'],
#  ['seeing'],
#  ['great', 'hope', 'like', 'man', 'well', 'endowed', 'lt', 'gt', 'inch'],
#  ['call', 'message', 'missed', 'call'],
#  ['get', 'hep', 'immunisation', 'nigeria'],
#  ['fair', 'enough', 'anything', 'going'],
#  ['yeah', 'hopefully', 'tyler', 'could', 'maybe', 'ask', 'around', 'bit'],
#  ['know',
#   'stubborn',
#   'even',
#   'want',
#   'go',
#   'hospital',
#   'kept',
#   'telling',
#   'mark',
#   'weak',
#   'sucker',
#   'hospital',
#   'weak',
#   'sucker'],
#  ['thinked', 'first', 'time', 'saw', 'class'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   'lt',
#   'gt',
#   'half',
#   'eighth',
#   'smarter',
#   'though',
#   'get',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'lt',
#   'gt'],
#  ['fyi',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   'crashing',
#   'place',
#   'tonight'],
#  ['wow',
#   'never',
#   'realized',
#   'embarassed',
#   'accomodations',
#   'thought',
#   'liked',
#   'since',
#   'best',
#   'could',
#   'always',
#   'seemed',
#   'happy',
#   'cave',
#   'sorry',
#   'give',
#   'sorry',
#   'offered',
#   'sorry',
#   'room',
#   'embarassing'],
#  ['sm',
#   'ac',
#   'sptv',
#   'new',
#   'jersey',
#   'devil',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey',
#   'correct',
#   'incorrect',
#   'end',
#   'reply',
#   'end',
#   'sptv'],
#  ['know', 'mallika', 'sherawat', 'yesterday', 'find', 'lt', 'url', 'gt'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'call',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'free',
#   'bx',
#   'ip',
#   'pm',
#   'dont',
#   'miss'],
#  ['sorry', 'call', 'later', 'meeting'],
#  ['tell', 'reached'],
#  ['yes', 'gauti', 'sehwag', 'odi', 'series'],
#  ['gonna', 'pick', 'burger', 'way', 'home', 'even', 'move', 'pain', 'killing'],
#  ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'situation', 'seeker'],
#  ['part', 'checking', 'iq'],
#  ['sorry', 'roommate', 'took', 'forever', 'ok', 'come'],
#  ['ok',
#   'lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'said',
#   'wun',
#   'cut',
#   'short',
#   'said',
#   'cut',
#   'look',
#   'nice'],
#  ['valued',
#   'customer',
#   'pleased',
#   'advise',
#   'following',
#   'recent',
#   'review',
#   'mob',
#   'awarded',
#   'bonus',
#   'prize',
#   'call'],
#  ['today',
#   'song',
#   'dedicated',
#   'day',
#   'song',
#   'dedicate',
#   'send',
#   'ur',
#   'valuable',
#   'frnds',
#   'first',
#   'rply'],
#  ['urgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'eurodisinc',
#   'trav',
#   'aco',
#   'entry',
#   'claim',
#   'txt',
#   'dis',
#   'morefrmmob',
#   'aj'],
#  ['hear', 'new', 'divorce', 'barbie', 'come', 'ken', 'stuff'],
#  ['plane', 'give', 'month', 'end'],
#  ['wah', 'lucky', 'man', 'save', 'money', 'hee'],
#  ['finished', 'class'],
#  ['hi', 'babe', 'im', 'home', 'wanna', 'something', 'xx'],
#  ['performed'],
#  ['call'],
#  ['waiting', 'machan', 'call', 'free'],
#  ['thats', 'cool', 'gentleman', 'treat', 'dignity', 'respect'],
#  ['like', 'people', 'much', 'shy', 'pa'],
#  ['operate', 'lt', 'gt'],
#  ['still', 'looking', 'job', 'much', 'ta', 'earn'],
#  ['sorry', 'call', 'later'],
#  ['call', 'ah'],
#  ['ok', 'way', 'home', 'hi', 'hi'],
#  ['place', 'man'],
#  ['yup', 'next', 'stop'],
#  ['call', 'later', 'network', 'urgnt', 'sm'],
#  ['real',
#   'getting',
#   'yo',
#   'need',
#   'ticket',
#   'one',
#   'jacket',
#   'done',
#   'already',
#   'used',
#   'multis'],
#  ['yes',
#   'started',
#   'send',
#   'request',
#   'make',
#   'pain',
#   'came',
#   'back',
#   'back',
#   'bed',
#   'double',
#   'coin',
#   'factory',
#   'gotta',
#   'cash',
#   'nitros'],
#  ['really', 'still', 'tonight', 'babe'],
#  ['ela', 'kano', 'il', 'download', 'come', 'wen', 'ur', 'free'],
#  ['yeah', 'stand', 'close', 'tho', 'catch', 'something'],
#  ['sorry',
#   'pain',
#   'ok',
#   'meet',
#   'another',
#   'night',
#   'spent',
#   'late',
#   'afternoon',
#   'casualty',
#   'mean',
#   'done',
#   'stuff',
#   'moro',
#   'includes',
#   'time',
#   'sheet',
#   'sorry'],
#  ['smile',
#   'pleasure',
#   'smile',
#   'pain',
#   'smile',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'sum',
#   'hurt',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'see',
#   'smiling'],
#  ['please',
#   'call',
#   'customer',
#   'service',
#   'representative',
#   'pm',
#   'guaranteed',
#   'cash',
#   'prize'],
#  ['havent',
#   'planning',
#   'buy',
#   'later',
#   'check',
#   'already',
#   'lido',
#   'got',
#   'show',
#   'afternoon',
#   'finish',
#   'work',
#   'already'],
#  ['free',
#   'ringtone',
#   'waiting',
#   'collected',
#   'simply',
#   'text',
#   'password',
#   'mix',
#   'verify',
#   'get',
#   'usher',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['watching', 'telugu', 'movie', 'wat', 'abt'],
#  ['see', 'finish', 'load', 'loan', 'pay'],
#  ['hi',
#   'wk',
#   'ok',
#   'hols',
#   'yes',
#   'bit',
#   'run',
#   'forgot',
#   'hairdresser',
#   'appointment',
#   'four',
#   'need',
#   'get',
#   'home',
#   'shower',
#   'beforehand',
#   'cause',
#   'prob'],
#  ['see', 'cup', 'coffee', 'animation'],
#  ['please', 'text', 'anymore', 'nothing', 'else', 'say'],
#  ['okay',
#   'name',
#   'ur',
#   'price',
#   'long',
#   'legal',
#   'wen',
#   'pick',
#   'ave',
#   'am',
#   'xx'],
#  ['still', 'looking', 'car', 'buy', 'gone', 'driving', 'test', 'yet'],
#  ['per',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertune',
#   'caller',
#   'press',
#   'copy',
#   'friend',
#   'callertune'],
#  ['wow',
#   'right',
#   'mean',
#   'guess',
#   'gave',
#   'boston',
#   'men',
#   'changed',
#   'search',
#   'location',
#   'nyc',
#   'something',
#   'changed',
#   'cuz',
#   'signin',
#   'page',
#   'still',
#   'say',
#   'boston'],
#  ['umma', 'life', 'vava', 'umma', 'love', 'lot', 'dear'],
#  ['thanks',
#   'lot',
#   'wish',
#   'birthday',
#   'thanks',
#   'making',
#   'birthday',
#   'truly',
#   'memorable'],
#  ['aight', 'hit', 'get', 'cash'],
#  ['would',
#   'ip',
#   'address',
#   'test',
#   'considering',
#   'computer',
#   'minecraft',
#   'server'],
#  ['know',
#   'grumpy',
#   'old',
#   'people',
#   'mom',
#   'like',
#   'better',
#   'lying',
#   'always',
#   'one',
#   'play',
#   'joke'],
#  ['dont', 'worry', 'guess', 'busy'],
#  ['plural', 'noun', 'research'],
#  ['going', 'dinner', 'msg'],
#  ['ok',
#   'wif',
#   'co',
#   'like',
#   'try',
#   'new',
#   'thing',
#   'scared',
#   'dun',
#   'like',
#   'mah',
#   'co',
#   'said',
#   'loud'],
#  ['gent',
#   'trying',
#   'contact',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'ppm'],
#  ['wa',
#   'ur',
#   'openin',
#   'sentence',
#   'formal',
#   'anyway',
#   'fine',
#   'juz',
#   'tt',
#   'eatin',
#   'much',
#   'puttin',
#   'weight',
#   'haha',
#   'anythin',
#   'special',
#   'happened'],
#  ['entered',
#   'cabin',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'askd',
#   'lunch',
#   'lunch',
#   'invited',
#   'apartment',
#   'went'],
#  ['winner',
#   'specially',
#   'selected',
#   'receive',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'live',
#   'operator',
#   'claim',
#   'min'],
#  ['goodo',
#   'yes',
#   'must',
#   'speak',
#   'friday',
#   'egg',
#   'potato',
#   'ratio',
#   'tortilla',
#   'needed'],
#  ['hmm',
#   'uncle',
#   'informed',
#   'paying',
#   'school',
#   'directly',
#   'pls',
#   'buy',
#   'food'],
#  ['private',
#   'account',
#   'statement',
#   'show',
#   'unredeemed',
#   'bonus',
#   'point',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['urgent',
#   'mobile',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'final',
#   'try',
#   'contact',
#   'call',
#   'landline',
#   'box',
#   'wr',
#   'ppm'],
#  ['new', 'address', 'apple', 'pair', 'malarky'],
#  ['today',
#   'voda',
#   'number',
#   'ending',
#   'selected',
#   'receive',
#   'award',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['going', 'sao', 'mu', 'today', 'done'],
#  ['predict', 'wat', 'time', 'finish', 'buying'],
#  ['good', 'stuff'],
#  ['know',
#   'yetunde',
#   'sent',
#   'money',
#   'yet',
#   'sent',
#   'text',
#   'bother',
#   'sending',
#   'dont',
#   'involve',
#   'anything',
#   'imposed',
#   'anything',
#   'first',
#   'place',
#   'apologise'],
#  ['room'],
#  ['hey',
#   'girl',
#   'hope',
#   'well',
#   'del',
#   'bak',
#   'long',
#   'time',
#   'give',
#   'call',
#   'sum',
#   'time',
#   'lucyxx'],
#  ['much', 'cost'],
#  ['home'],
#  ['dear', 'call', 'tmorrow', 'pls', 'accomodate'],
#  ['first', 'answer', 'question'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'know',
#   'country',
#   'algarve',
#   'txt',
#   'ansr',
#   'sp',
#   'tyrone'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'nt',
#   'ec',
#   'msg'],
#  ['haf', 'msn', 'yijue', 'hotmail', 'com'],
#  ['call', 'meet'],
#  ['check', 'room', 'befor', 'activity'],
#  ['rcv',
#   'msg',
#   'chat',
#   'svc',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'get',
#   'nothing',
#   'must',
#   'age',
#   'verify',
#   'yr',
#   'network',
#   'try'],
#  ['got', 'lazy', 'type', 'forgot', 'lect', 'saw', 'pouch', 'like', 'nice'],
#  ['text', 'way'],
#  ['sir', 'waiting', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tired',
#   'little',
#   'thing',
#   'lovable',
#   'person',
#   'coz',
#   'somtimes',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'heart',
#   'gud',
#   'ni'],
#  ['know', 'pls', 'open', 'back'],
#  ['yes', 'see', 'ya', 'dot'],
#  ['whats', 'staff', 'name', 'taking', 'class'],
#  ['freemsg',
#   'replied',
#   'text',
#   'randy',
#   'sexy',
#   'female',
#   'live',
#   'local',
#   'luv',
#   'hear',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'end'],
#  ['ummma', 'call', 'check', 'life', 'begin', 'qatar', 'pls', 'pray', 'hard'],
#  ['deleted', 'contact'],
#  ['sindu', 'got', 'job', 'birla', 'soft'],
#  ['wine', 'flowing', 'nevering'],
#  ['yup', 'thk', 'cine', 'better', 'co', 'need', 'go', 'plaza', 'mah'],
#  ['ok', 'ur', 'typical', 'reply'],
#  ['per',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertune',
#   'caller',
#   'press',
#   'copy',
#   'friend',
#   'callertune'],
#  ['everywhere',
#   'dirt',
#   'floor',
#   'window',
#   'even',
#   'shirt',
#   'sometimes',
#   'open',
#   'mouth',
#   'come',
#   'flowing',
#   'dream',
#   'world',
#   'without',
#   'half',
#   'chore',
#   'time',
#   'joy',
#   'lot',
#   'tv',
#   'show',
#   'see',
#   'guess',
#   'like',
#   'thing',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'mist',
#   'time',
#   'done',
#   'become',
#   'one'],
#  ['aaooooright', 'work'],
#  ['leaving', 'house'],
#  ['hello',
#   'love',
#   'get',
#   'interview',
#   'today',
#   'happy',
#   'good',
#   'boy',
#   'think',
#   'missing'],
#  ['customer',
#   'service',
#   'annoncement',
#   'new',
#   'year',
#   'delivery',
#   'waiting',
#   'please',
#   'call',
#   'arrange',
#   'delivery'],
#  ['winner',
#   'specially',
#   'selected',
#   'receive',
#   'cash',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'live',
#   'operator',
#   'claim'],
#  ['keep',
#   'safe',
#   'need',
#   'miss',
#   'already',
#   'envy',
#   'everyone',
#   'see',
#   'real',
#   'life'],
#  ['new', 'car', 'house', 'parent', 'new', 'job', 'hand'],
#  ['love', 'excited', 'day', 'spend', 'make', 'happy'],
#  ['pls',
#   'stop',
#   'bootydelious',
#   'inviting',
#   'friend',
#   'reply',
#   'yes',
#   'see',
#   'www',
#   'sm',
#   'ac',
#   'bootydelious',
#   'stop',
#   'send',
#   'stop',
#   'frnd'],
#  ['bangbabes',
#   'ur',
#   'order',
#   'way',
#   'receive',
#   'service',
#   'msg',
#   'download',
#   'ur',
#   'content',
#   'goto',
#   'wap',
#   'bangb',
#   'tv',
#   'ur',
#   'mobile',
#   'internet',
#   'service',
#   'menu'],
#  ['place', 'ur', 'point', 'culture', 'module', 'already'],
#  ['urgent',
#   'trying',
#   'contact',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr'],
#  ['hi',
#   'frnd',
#   'best',
#   'way',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'beloved',
#   'one'],
#  ['great', 'escape', 'fancy', 'bridge', 'need', 'lager', 'see', 'tomo'],
#  ['yes', 'completely', 'form', 'clark', 'also', 'utter', 'waste'],
#  ['sir', 'need', 'axis', 'bank', 'account', 'bank', 'address'],
#  ['hmmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'hop',
#   'ard',
#   'ya',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'discus',
#   'liao'],
#  ['time', 'coming', 'later'],
#  ['bloody',
#   'hell',
#   'cant',
#   'believe',
#   'forgot',
#   'surname',
#   'mr',
#   'ill',
#   'give',
#   'clue',
#   'spanish',
#   'begin'],
#  ['well', 'gonna', 'finish', 'bath', 'good', 'fine', 'night'],
#  ['let', 'know', 'got', 'money', 'carlos', 'make', 'call'],
#  ['still', 'going', 'mall'],
#  ['turn',
#   'friend',
#   'staying',
#   'whole',
#   'show',
#   'back',
#   'til',
#   'lt',
#   'gt',
#   'feel',
#   'free',
#   'go',
#   'ahead',
#   'smoke',
#   'lt',
#   'gt',
#   'worth'],
#  ['text', 'doesnt', 'reply', 'let', 'know', 'log'],
#  ['hi',
#   'spoke',
#   'maneesha',
#   'like',
#   'know',
#   'satisfied',
#   'experience',
#   'reply',
#   'toll',
#   'free',
#   'yes'],
#  ['lifted',
#   'hope',
#   'offer',
#   'money',
#   'need',
#   'especially',
#   'end',
#   'month',
#   'approach',
#   'hurt',
#   'studying',
#   'anyways',
#   'gr',
#   'weekend'],
#  ['lol', 'trust'],
#  ['ok', 'gentleman', 'treat', 'dignity', 'respect'],
#  ['guy', 'close'],
#  ['going', 'nothing', 'great', 'bye'],
#  ['hello',
#   'handsome',
#   'finding',
#   'job',
#   'lazy',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'net',
#   'mummy',
#   'boytoy',
#   'miss'],
#  ['haha', 'awesome', 'minute'],
#  ['please',
#   'call',
#   'customer',
#   'service',
#   'representative',
#   'freephone',
#   'pm',
#   'guaranteed',
#   'cash',
#   'prize'],
#  ['got', 'xmas', 'radio', 'time', 'get'],
#  ['jus',
#   'reached',
#   'home',
#   'go',
#   'bathe',
#   'first',
#   'si',
#   'using',
#   'net',
#   'tell',
#   'finish'],
#  ['unique',
#   'enough',
#   'find',
#   'th',
#   'august',
#   'www',
#   'areyouunique',
#   'co',
#   'uk'],
#  ['sorry',
#   'joined',
#   'league',
#   'people',
#   'dont',
#   'keep',
#   'touch',
#   'mean',
#   'great',
#   'deal',
#   'friend',
#   'time',
#   'even',
#   'great',
#   'personal',
#   'cost',
#   'great',
#   'week'],
#  ['hi', 'finally', 'completed', 'course'],
#  ['stop',
#   'however',
#   'suggest',
#   'stay',
#   'someone',
#   'able',
#   'give',
#   'or',
#   'every',
#   'stool'],
#  ['hope', 'settled', 'new', 'school', 'year', 'wishin', 'gr', 'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['got', 'person', 'story'],
#  ['hamster', 'dead', 'hey', 'tmr', 'meet', 'pm', 'orchard', 'mrt'],
#  ['hi',
#   'kate',
#   'evening',
#   'hope',
#   'see',
#   'tomorrow',
#   'bit',
#   'bloody',
#   'babyjontet',
#   'txt',
#   'back',
#   'xxx'],
#  ['found', 'enc', 'lt', 'gt'],
#  ['sent', 'lt', 'gt', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'txt',
#   'finish',
#   'love',
#   'kate',
#   'xxx'],
#  ['account',
#   'refilled',
#   'successfully',
#   'inr',
#   'lt',
#   'decimal',
#   'gt',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'lt',
#   'decimal',
#   'gt',
#   'transaction',
#   'id',
#   'kr',
#   'lt',
#   'gt'],
#  ['goodmorning', 'sleeping', 'ga'],
#  ['call', 'alter', 'ok'],
#  ['say',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'cannot',
#   'oredi',
#   'lar'],
#  ['entered',
#   'cabin',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'askd',
#   'lunch',
#   'lunch',
#   'invited',
#   'apartment',
#   'went'],
#  ['aight', 'yo', 'dat', 'straight', 'dogg'],
#  ['please',
#   'give',
#   'connection',
#   'today',
#   'lt',
#   'decimal',
#   'gt',
#   'refund',
#   'bill'],
#  ['shoot', 'big', 'load', 'get', 'ready'],
#  ['bruv', 'hope', 'great', 'break', 'rewarding', 'semester'],
#  ['home', 'always', 'chat'],
#  ['good', 'study', 'well'],
#  ['yup', 'noe', 'leh'],
#  ['sound', 'great', 'home'],
#  ['finally', 'match', 'heading', 'towards', 'draw', 'prediction'],
#  ['tired', 'slept', 'well', 'past', 'night'],
#  ['easy', 'ah', 'sen', 'got', 'selected', 'mean', 'good'],
#  ['take', 'exam', 'march'],
#  ['yeah',
#   'think',
#   'use',
#   'gt',
#   'atm',
#   'register',
#   'sure',
#   'anyway',
#   'help',
#   'let',
#   'know',
#   'sure',
#   'ready'],
#  ['ok', 'prob', 'take', 'ur', 'time'],
#  ['called',
#   'ubandu',
#   'run',
#   'without',
#   'installing',
#   'hard',
#   'disk',
#   'use',
#   'copy',
#   'important',
#   'file',
#   'system',
#   'give',
#   'repair',
#   'shop'],
#  ['sorry', 'call', 'later'],
#  ['say',
#   'leh',
#   'course',
#   'nothing',
#   'happen',
#   'lar',
#   'say',
#   'romantic',
#   'jus',
#   'bit',
#   'lor',
#   'thk',
#   'nite',
#   'scenery',
#   'nice',
#   'leh'],
#  ['new',
#   'mobile',
#   'must',
#   'go',
#   'txt',
#   'nokia',
#   'collect',
#   'today',
#   'www',
#   'tc',
#   'biz',
#   'optout',
#   'gbp',
#   'mtmsg'],
#  ['would', 'really', 'appreciate', 'call', 'need', 'someone', 'talk'],
#  ['meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon',
#   'ur',
#   'career',
#   'flyng',
#   'start',
#   'find',
#   'free',
#   'txt',
#   'horo',
#   'followed',
#   'ur',
#   'star',
#   'sign',
#   'horo',
#   'aries'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['life',
#   'strict',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'conduct',
#   'exam',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'teach',
#   'lesson',
#   'happy',
#   'morning'],
#  ['dear', 'good', 'morning'],
#  ['get',
#   'gandhipuram',
#   'walk',
#   'cross',
#   'cut',
#   'road',
#   'right',
#   'side',
#   'lt',
#   'gt',
#   'street',
#   'road',
#   'turn',
#   'first',
#   'right'],
#  ['dear', 'going', 'rubber', 'place'],
#  ['sorry', 'battery', 'died', 'yeah'],
#  ['yes', 'tv', 'always', 'available', 'work', 'place'],
#  ['text',
#   'meet',
#   'someone',
#   'sexy',
#   'today',
#   'find',
#   'date',
#   'even',
#   'flirt',
#   'join',
#   'reply',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recd',
#   'thirtyeight',
#   'penny'],
#  ['printed', 'oh', 'lt', 'gt', 'come', 'upstairs'],
#  ['ill', 'little', 'closer', 'like', 'bus', 'stop', 'street'],
#  ['wil', 'reach'],
#  ['new',
#   'theory',
#   'argument',
#   'win',
#   'situation',
#   'loses',
#   'person',
#   'dont',
#   'argue',
#   'ur',
#   'friend',
#   'kick',
#   'amp',
#   'say',
#   'always',
#   'correct'],
#  ['secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'find',
#   'reveal',
#   'think',
#   'ur',
#   'special',
#   'call'],
#  ['tomarrow', 'final', 'hearing', 'laptop', 'case', 'cant'],
#  ['tel', 'avent', 'done', 'sportsx'],
#  ['okay', 'shining', 'meant', 'signing', 'sound', 'better'],
#  ['although',
#   'told',
#   'dat',
#   'baig',
#   'face',
#   'watch',
#   'really',
#   'like',
#   'watch',
#   'gave',
#   'co',
#   'fr',
#   'thanx',
#   'everything',
#   'dat',
#   'done',
#   'today',
#   'touched'],
#  ['remember', 'old', 'commercial'],
#  ['late', 'said', 'website', 'dont', 'slipper'],
#  ['asked', 'call', 'ok'],
#  ['kallis', 'wont', 'bat', 'nd', 'inning'],
#  ['didnt',
#   'work',
#   'oh',
#   'ok',
#   'goodnight',
#   'fix',
#   'ready',
#   'time',
#   'wake',
#   'dearly',
#   'missed',
#   'good',
#   'night',
#   'sleep'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'cd',
#   'voucher',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'deepak', 'min', 'hold'],
#  ['wen',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'dnt',
#   'take',
#   'seriously',
#   'coz',
#   'angry',
#   'childish',
#   'true',
#   'way',
#   'showing',
#   'deep',
#   'affection',
#   'care',
#   'luv',
#   'kettoda',
#   'manda',
#   'nice',
#   'day',
#   'da'],
#  ['ups',
#   'day',
#   'also',
#   'shipping',
#   'company',
#   'take',
#   'wks',
#   'way',
#   'usps',
#   'take',
#   'week',
#   'get',
#   'lag',
#   'may',
#   'bribe',
#   'nipost',
#   'get',
#   'stuff'],
#  ['back', 'lemme', 'know', 'ready'],
#  ['necessarily', 'expect', 'done', 'get', 'back', 'though', 'headin'],
#  ['mmm', 'yummy', 'babe', 'nice', 'jolt', 'suzy'],
#  ['lover', 'need'],
#  ['tried',
#   'contact',
#   'reply',
#   'offer',
#   'video',
#   'handset',
#   'anytime',
#   'network',
#   'min',
#   'unlimited',
#   'text',
#   'camcorder',
#   'reply',
#   'call'],
#  ['parked', 'next', 'mini', 'coming', 'today', 'think'],
#  ['yup'],
#  ['anyway',
#   'going',
#   'shopping',
#   'co',
#   'si',
#   'done',
#   'yet',
#   'dun',
#   'disturb',
#   'liao'],
#  ['luton', 'ring', 'ur', 'around'],
#  ['hey',
#   'really',
#   'horny',
#   'want',
#   'chat',
#   'see',
#   'naked',
#   'text',
#   'hot',
#   'text',
#   'charged',
#   'pm',
#   'unsubscribe',
#   'text',
#   'stop'],
#  ['dint', 'come'],
#  ['wana', 'plan', 'trip', 'sometme'],
#  ['sure', 'yet', 'still', 'trying', 'get', 'hold'],
#  ['ur',
#   'ringtone',
#   'service',
#   'changed',
#   'free',
#   'credit',
#   'go',
#   'club',
#   'mobile',
#   'com',
#   'choose',
#   'content',
#   'stop',
#   'txt',
#   'club',
#   'stop',
#   'wk',
#   'club',
#   'po',
#   'box',
#   'mk',
#   'wt'],
#  ['evo', 'download', 'flash', 'jealous'],
#  ['ringtone',
#   'club',
#   'get',
#   'uk',
#   'single',
#   'chart',
#   'mobile',
#   'week',
#   'choose',
#   'top',
#   'quality',
#   'ringtone',
#   'message',
#   'free',
#   'charge'],
#  ['come', 'mu', 'sorting', 'narcotic', 'situation'],
#  ['night',
#   'ended',
#   'another',
#   'day',
#   'morning',
#   'come',
#   'special',
#   'way',
#   'may',
#   'smile',
#   'like',
#   'sunny',
#   'ray',
#   'leaf',
#   'worry',
#   'blue',
#   'blue',
#   'bay'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pound',
#   'genuine',
#   'hmv',
#   'voucher',
#   'answer',
#   'easy',
#   'question',
#   'play',
#   'send',
#   'hmv',
#   'info',
#   'www',
#   'percent',
#   'real',
#   'com'],
#  ['usf', 'guess', 'might', 'well', 'take', 'car'],
#  ['objection', 'bf', 'coming'],
#  ['thanx'],
#  ['tell', 'rob', 'mack', 'gf', 'theater'],
#  ['awesome', 'see', 'bit'],
#  ['sent', 'type', 'food', 'like'],
#  ['done', 'handed', 'celebration', 'full', 'swing', 'yet'],
#  ['got', 'called', 'tool'],
#  ['wen',
#   'miss',
#   'someone',
#   'person',
#   'definitely',
#   'special',
#   'person',
#   'special',
#   'miss',
#   'keep',
#   'touch',
#   'gdeve'],
#  ['ok', 'asked', 'money', 'far'],
#  ['okie'],
#  ['yeah',
#   'think',
#   'usual',
#   'guy',
#   'still',
#   'passed',
#   'last',
#   'night',
#   'get',
#   'ahold',
#   'anybody',
#   'let',
#   'know',
#   'throw'],
#  ['might', 'come', 'tonight', 'class', 'let', 'early'],
#  ['ok'],
#  ['hi',
#   'baby',
#   'im',
#   'cruisin',
#   'girl',
#   'friend',
#   'give',
#   'call',
#   'hour',
#   'home',
#   'thats',
#   'alright',
#   'fone',
#   'fone',
#   'love',
#   'jenny',
#   'xxx'],
#  ['life',
#   'mean',
#   'lot',
#   'love',
#   'life',
#   'love',
#   'people',
#   'life',
#   'world',
#   'call',
#   'friend',
#   'call',
#   'world',
#   'ge'],
#  ['dear',
#   'shall',
#   'mail',
#   'tonite',
#   'busy',
#   'street',
#   'shall',
#   'update',
#   'tonite',
#   'thing',
#   'looking',
#   'ok',
#   'varunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollu',
#   'good',
#   'one',
#   'real',
#   'sense'],
#  ['hey', 'told', 'name', 'gautham', 'ah'],
#  ['haf', 'found', 'feel', 'stupid', 'da', 'cam', 'working'],
#  ['oops', 'got', 'bit'],
#  ['much', 'buzy'],
#  ['accidentally', 'deleted', 'message', 'resend', 'please'],
#  ['mobile',
#   'customer',
#   'may',
#   'claim',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'loyalty',
#   'call',
#   'offer',
#   'end',
#   'thfeb',
#   'apply'],
#  ['unless', 'situation', 'go', 'gurl', 'would', 'appropriate'],
#  ['hurt',
#   'tease',
#   'make',
#   'cry',
#   'end',
#   'life',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'grave',
#   'say',
#   'stupid',
#   'miss',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'phone', 'right', 'pls', 'send', 'message'],
#  ['need', 'coffee', 'run', 'tomo', 'believe', 'time', 'week', 'already'],
#  ['awesome',
#   'remember',
#   'last',
#   'time',
#   'got',
#   'somebody',
#   'high',
#   'first',
#   'time',
#   'diesel'],
#  ['shit',
#   'really',
#   'shocking',
#   'scary',
#   'cant',
#   'imagine',
#   'second',
#   'def',
#   'night',
#   'think',
#   'somewhere',
#   'could',
#   'crash',
#   'night',
#   'save',
#   'taxi'],
#  ['oh', 'way', 'food', 'fridge', 'want', 'go', 'meal', 'tonight'],
#  ['womdarfull', 'actor'],
#  ['sm',
#   'ac',
#   'blind',
#   'date',
#   'rodds',
#   'aberdeen',
#   'united',
#   'kingdom',
#   'check',
#   'http',
#   'img',
#   'sm',
#   'ac',
#   'icmb',
#   'cktz',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['yup', 'remb', 'think', 'book'],
#  ['jos', 'ask', 'wana', 'meet'],
#  ['lol', 'yes', 'friendship', 'hanging', 'thread', 'cause', 'buy', 'stuff'],
#  ['themob',
#   'check',
#   'newest',
#   'selection',
#   'content',
#   'game',
#   'tone',
#   'gossip',
#   'babe',
#   'sport',
#   'keep',
#   'mobile',
#   'fit',
#   'funky',
#   'text',
#   'wap'],
#  ['garage', 'key', 'bookshelf'],
#  ['today',
#   'accept',
#   'day',
#   'accept',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'rply',
#   'mean',
#   'enemy'],
#  ['think',
#   'ur',
#   'smart',
#   'win',
#   'week',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'winnersclub',
#   'po',
#   'box',
#   'uz',
#   'gbp',
#   'week'],
#  ['say',
#   'give',
#   'call',
#   'friend',
#   'got',
#   'money',
#   'definitely',
#   'buying',
#   'end',
#   'week'],
#  ['hi',
#   'way',
#   'day',
#   'normal',
#   'way',
#   'real',
#   'ur',
#   'unique',
#   'hope',
#   'know',
#   'rest',
#   'mylife',
#   'hope',
#   'find',
#   'wot',
#   'lost'],
#  ['made', 'day', 'great', 'day'],
#  ['advance', 'happy', 'pongal'],
#  ['hmmm',
#   'guess',
#   'go',
#   'kb',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['really', 'dude', 'friend', 'afraid'],
#  ['december',
#   'mobile',
#   'mths',
#   'entitled',
#   'update',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'free',
#   'call',
#   'mobile',
#   'update',
#   'co',
#   'free'],
#  ['coffee', 'cake', 'guess'],
#  ['merry', 'christmas', 'babe', 'love', 'ya', 'kiss'],
#  ['hey', 'dont', 'go', 'watch', 'men', 'lunch', 'haha'],
#  ['cud',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'bit',
#   'co',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete'],
#  ['would',
#   'great',
#   'guild',
#   'could',
#   'meet',
#   'bristol',
#   'road',
#   'somewhere',
#   'get',
#   'touch',
#   'weekend',
#   'plan',
#   'take',
#   'flight',
#   'good',
#   'week'],
#  ['problem'],
#  ['call', 'message', 'missed', 'call'],
#  ['hi', 'da', 'today', 'class'],
#  ['say',
#   'good',
#   'sign',
#   'well',
#   'know',
#   'track',
#   'record',
#   'reading',
#   'woman'],
#  ['cool', 'text', 'parked'],
#  ['reading', 'text', 'sent', 'meant', 'joke', 'read', 'light'],
#  ['apo', 'good', 'movie'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'tomo',
#   'return',
#   'immediately',
#   'something'],
#  ['call',
#   'germany',
#   'penny',
#   'per',
#   'minute',
#   'call',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   'prepayment',
#   'direct',
#   'access'],
#  ['chance',
#   'might',
#   'evaporated',
#   'soon',
#   'violated',
#   'privacy',
#   'stealing',
#   'phone',
#   'number',
#   'employer',
#   'paperwork',
#   'cool',
#   'please',
#   'contact',
#   'report',
#   'supervisor'],
#  ['valentine',
#   'day',
#   'special',
#   'win',
#   'quiz',
#   'take',
#   'partner',
#   'trip',
#   'lifetime',
#   'send',
#   'go',
#   'msg',
#   'rcvd',
#   'custcare'],
#  ['ta', 'daaaaa', 'home', 'babe', 'still'],
#  ['cool', 'come', 'havent', 'wined', 'dined'],
#  ['sleeping', 'surfing'],
#  ['sorry', 'call', 'later'],
#  ['calling', 'right', 'call', 'hand', 'phone'],
#  ['ok', 'great', 'thanx', 'lot'],
#  ['take',
#   'post',
#   'come',
#   'must',
#   'text',
#   'happy',
#   'reading',
#   'one',
#   'wiv',
#   'hello',
#   'caroline',
#   'end',
#   'favourite',
#   'bless'],
#  ['hiding', 'stranger'],
#  ['interested', 'like'],
#  ['sister', 'cleared', 'two', 'round', 'birla', 'soft', 'yesterday'],
#  ['gudnite', 'tc', 'practice', 'going'],
#  ['dis',
#   'yijue',
#   'jus',
#   'saw',
#   'ur',
#   'mail',
#   'case',
#   'huiming',
#   'havent',
#   'sent',
#   'num',
#   'dis',
#   'num'],
#  ['one', 'small', 'prestige', 'problem'],
#  ['fancy',
#   'shag',
#   'interested',
#   'sextextuk',
#   'com',
#   'txt',
#   'xxuk',
#   'suzy',
#   'txts',
#   'cost',
#   'per',
#   'msg',
#   'tncs',
#   'website'],
#  ['checking', 'really', 'miss', 'seeing', 'jeremiah', 'great', 'month'],
#  ['nah', 'help', 'never', 'iphone'],
#  ['car', 'hour', 'half', 'going', 'apeshit'],
#  ['today',
#   'sorry',
#   'day',
#   'ever',
#   'angry',
#   'ever',
#   'misbehaved',
#   'hurt',
#   'plz',
#   'plz',
#   'slap',
#   'urself',
#   'bcoz',
#   'ur',
#   'fault',
#   'basically',
#   'good'],
#  ['yo',
#   'guy',
#   'ever',
#   'figure',
#   'much',
#   'need',
#   'alcohol',
#   'jay',
#   'trying',
#   'figure',
#   'much',
#   'safely',
#   'spend',
#   'weed'],
#  ['lt', 'gt', 'ish', 'minute', 'minute', 'ago', 'wtf'],
#  ['thank',
#   'calling',
#   'forgot',
#   'say',
#   'happy',
#   'onam',
#   'sirji',
#   'fine',
#   'remembered',
#   'met',
#   'insurance',
#   'person',
#   'meet',
#   'qatar',
#   'insha',
#   'allah',
#   'rakhesh',
#   'ex',
#   'tata',
#   'aig',
#   'joined',
#   'tissco',
#   'tayseer'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'cd',
#   'voucher',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ur',
#   'cash',
#   'balance',
#   'currently',
#   'pound',
#   'maximize',
#   'ur',
#   'cash',
#   'send',
#   'cash',
#   'msg',
#   'cc',
#   'hg',
#   'suite',
#   'land',
#   'row',
#   'hl'],
#  ['actor',
#   'work',
#   'work',
#   'evening',
#   'sleep',
#   'late',
#   'since',
#   'unemployed',
#   'moment',
#   'always',
#   'sleep',
#   'late',
#   'unemployed',
#   'every',
#   'day',
#   'saturday'],
#  ['hello',
#   'got',
#   'st',
#   'andrew',
#   'boy',
#   'long',
#   'way',
#   'cold',
#   'keep',
#   'posted'],
#  ['ha', 'ha', 'cool', 'cool', 'chikku', 'chikku', 'db'],
#  ['oh', 'ok', 'prob'],
#  ['check', 'audrey', 'status', 'right'],
#  ['busy',
#   'trying',
#   'finish',
#   'new',
#   'year',
#   'looking',
#   'forward',
#   'finally',
#   'meeting'],
#  ['good',
#   'afternoon',
#   'sunshine',
#   'dawn',
#   'day',
#   'refreshed',
#   'happy',
#   'alive',
#   'breathe',
#   'air',
#   'smile',
#   'think',
#   'love',
#   'always'],
#  ['well', 'know', 'take', 'care', 'worry'],
#  ['update_now',
#   'xmas',
#   'offer',
#   'latest',
#   'motorola',
#   'sonyericsson',
#   'nokia',
#   'free',
#   'bluetooth',
#   'double',
#   'min',
#   'txt',
#   'orange',
#   'call',
#   'mobileupd',
#   'call',
#   'optout'],
#  ['discount',
#   'code',
#   'rp',
#   'stop',
#   'message',
#   'reply',
#   'stop',
#   'www',
#   'regalportfolio',
#   'co',
#   'uk',
#   'customer',
#   'service'],
#  ['wat', 'uniform', 'get'],
#  ['cool', 'text', 'ready'],
#  ['hello',
#   'boytoy',
#   'geeee',
#   'miss',
#   'already',
#   'woke',
#   'wish',
#   'bed',
#   'cuddling',
#   'love'],
#  ['spoil', 'bed', 'well'],
#  ['going', 'bath', 'msg', 'next', 'lt', 'gt', 'min'],
#  ['cant',
#   'keep',
#   'talking',
#   'people',
#   'sure',
#   'pay',
#   'agree',
#   'price',
#   'pls',
#   'tell',
#   'want',
#   'really',
#   'buy',
#   'much',
#   'willing',
#   'pay'],
#  ['thanks',
#   'ringtone',
#   'order',
#   'reference',
#   'charged',
#   'gbp',
#   'per',
#   'week',
#   'unsubscribe',
#   'anytime',
#   'calling',
#   'customer',
#   'service'],
#  ['say', 'happen'],
#  ['could', 'seen', 'recognise', 'face'],
#  ['well',
#   'lot',
#   'thing',
#   'happening',
#   'lindsay',
#   'new',
#   'year',
#   'sigh',
#   'bar',
#   'ptbo',
#   'blue',
#   'heron',
#   'something',
#   'going'],
#  ['keep', 'payasam', 'rinu', 'brings'],
#  ['taught',
#   'ranjith',
#   'sir',
#   'called',
#   'sm',
#   'like',
#   'becaus',
#   'he',
#   'verifying',
#   'project',
#   'prabu',
#   'told',
#   'today',
#   'pa',
#   'dont',
#   'mistake'],
#  ['guess',
#   'worried',
#   'must',
#   'know',
#   'way',
#   'body',
#   'repair',
#   'quite',
#   'sure',
#   'worry',
#   'take',
#   'slow',
#   'first',
#   'test',
#   'guide',
#   'ovulation',
#   'relax',
#   'nothing',
#   'said',
#   'reason',
#   'worry',
#   'keep',
#   'followin'],
#  ['yeah', 'sure', 'give', 'couple', 'minute', 'track', 'wallet'],
#  ['hey', 'leave', 'big', 'deal', 'take', 'care'],
#  ['hey', 'late', 'ah', 'meet'],
#  ['double',
#   'min',
#   'txts',
#   'month',
#   'free',
#   'bluetooth',
#   'orange',
#   'available',
#   'sony',
#   'nokia',
#   'motorola',
#   'phone',
#   'call',
#   'mobileupd',
#   'call',
#   'optout',
#   'dx'],
#  ['took', 'mr', 'owl', 'lick'],
#  ['customer', 'place', 'call'],
#  ['mm', 'time', 'dont', 'like', 'fun'],
#  ['mths',
#   'half',
#   'price',
#   'orange',
#   'line',
#   'rental',
#   'latest',
#   'camera',
#   'phone',
#   'free',
#   'phone',
#   'mths',
#   'call',
#   'mobilesdirect',
#   'free',
#   'update',
#   'stoptxt'],
#  ['yup', 'lunch', 'buffet', 'eat', 'already'],
#  ['huh', 'late', 'fr', 'dinner'],
#  ['hey', 'sat', 'going', 'intro', 'pilate', 'kickboxing'],
#  ['morning', 'ok'],
#  ['yes',
#   'think',
#   'office',
#   'lap',
#   'room',
#   'think',
#   'thats',
#   'last',
#   'day',
#   'didnt',
#   'shut'],
#  ['pick', 'bout', 'ish', 'time', 'going'],
#  ['performance',
#   'award',
#   'calculated',
#   'every',
#   'two',
#   'month',
#   'current',
#   'one',
#   'month',
#   'period'],
#  ['actually',
#   'sleeping',
#   'still',
#   'might',
#   'call',
#   'back',
#   'text',
#   'gr',
#   'rock',
#   'si',
#   'send',
#   'text',
#   'wen',
#   'wake'],
#  ['always',
#   'putting',
#   'business',
#   'put',
#   'picture',
#   'as',
#   'facebook',
#   'one',
#   'open',
#   'people',
#   'ever',
#   'met',
#   'would',
#   'think',
#   'picture',
#   'room',
#   'would',
#   'hurt',
#   'make',
#   'feel',
#   'violated'],
#  ['good',
#   'evening',
#   'sir',
#   'al',
#   'salam',
#   'wahleykkum',
#   'sharing',
#   'happy',
#   'news',
#   'grace',
#   'god',
#   'got',
#   'offer',
#   'tayseer',
#   'tissco',
#   'joined',
#   'hope',
#   'fine',
#   'inshah',
#   'allah',
#   'meet',
#   'sometime',
#   'rakhesh',
#   'visitor',
#   'india'],
#  ['hmmm',
#   'want',
#   'change',
#   'field',
#   'quickly',
#   'da',
#   'wanna',
#   'get',
#   'system',
#   'administrator',
#   'network',
#   'administrator'],
#  ['free',
#   'ringtone',
#   'text',
#   'first',
#   'poly',
#   'text',
#   'get',
#   'true',
#   'tone',
#   'help',
#   'st',
#   'free',
#   'tone',
#   'pw',
#   'nd',
#   'txt',
#   'stop'],
#  ['dear', 'chechi', 'talk'],
#  ['hair', 'cream', 'shipped'],
#  ['none', 'happening', 'til', 'get', 'though'],
#  ['yep',
#   'great',
#   'loxahatchee',
#   'xmas',
#   'tree',
#   'burning',
#   'lt',
#   'gt',
#   'start',
#   'hour'],
#  ['haha', 'get', 'used', 'driving', 'usf', 'man', 'know', 'lot', 'stoner'],
#  ['well',
#   'slightly',
#   'disastrous',
#   'class',
#   'pm',
#   'fav',
#   'darling',
#   'hope',
#   'day',
#   'ok',
#   'coffee',
#   'wld',
#   'good',
#   'stay',
#   'late',
#   'tomorrow',
#   'time',
#   'place',
#   'always'],
#  ['hello', 'good', 'week', 'fancy', 'drink', 'something', 'later'],
#  ['headin', 'towards', 'busetop'],
#  ['message',
#   'text',
#   'missing',
#   'sender',
#   'name',
#   'missing',
#   'number',
#   'missing',
#   'sent',
#   'date',
#   'missing',
#   'missing',
#   'lot',
#   'thats',
#   'everything',
#   'missing',
#   'sent',
#   'via',
#   'fullonsms',
#   'com'],
#  ['come', 'room', 'point', 'iron', 'plan', 'weekend'],
#  ['co', 'want', 'thing'],
#  ['okies',
#   'go',
#   'yan',
#   'jiu',
#   'skip',
#   'ard',
#   'oso',
#   'go',
#   'cine',
#   'den',
#   'go',
#   'mrt',
#   'one',
#   'blah',
#   'blah',
#   'blah'],
#  ['bring', 'home', 'wendy'],
#  ['dating', 'service', 'cal', 'box', 'sk', 'ch'],
#  ['whatsup', 'dont', 'want', 'sleep'],
#  ['alright', 'new', 'goal'],
#  ['free',
#   'entry',
#   'weekly',
#   'competition',
#   'text',
#   'word',
#   'win',
#   'www',
#   'txttowin',
#   'co',
#   'uk'],
#  ['alright', 'head', 'minute', 'text', 'meet'],
#  ['send',
#   'logo',
#   'ur',
#   'lover',
#   'name',
#   'joined',
#   'heart',
#   'txt',
#   'love',
#   'name',
#   'name',
#   'mobno',
#   'eg',
#   'love',
#   'adam',
#   'eve',
#   'yahoo',
#   'pobox',
#   'wq',
#   'txtno',
#   'ad'],
#  ['yes', 'last', 'week', 'taking', 'live', 'call'],
#  ['someone',
#   'contacted',
#   'dating',
#   'service',
#   'entered',
#   'phone',
#   'fancy',
#   'find',
#   'call',
#   'landline',
#   'pobox',
#   'tf'],
#  ['siva', 'hostel', 'aha'],
#  ['urgent',
#   'mobile',
#   'number',
#   'awarded',
#   'prize',
#   'guaranteed',
#   'call',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr'],
#  ['send',
#   'ur',
#   'friend',
#   'receive',
#   'something',
#   'ur',
#   'voice',
#   'speaking',
#   'expression',
#   'childish',
#   'naughty',
#   'sentiment',
#   'rowdy',
#   'ful',
#   'attitude',
#   'romantic',
#   'shy',
#   'attractive',
#   'funny',
#   'lt',
#   'gt',
#   'irritating',
#   'lt',
#   'gt',
#   'lovable',
#   'reply'],
#  ['ok', 'ok', 'guess'],
#  ['aathi', 'dear'],
#  ['pain', 'urination', 'thing', 'else'],
#  ['esplanade', 'mind', 'giving', 'lift', 'co', 'got', 'car', 'today'],
#  ['wnt',
#   'buy',
#   'bmw',
#   'car',
#   'urgently',
#   'vry',
#   'urgent',
#   'hv',
#   'shortage',
#   'lt',
#   'gt',
#   'lac',
#   'source',
#   'arng',
#   'dis',
#   'amt',
#   'lt',
#   'gt',
#   'lac',
#   'thats',
#   'prob'],
#  ['home', 'watching', 'tv', 'lor'],
#  ['usually',
#   'take',
#   'fifteen',
#   'fucking',
#   'minute',
#   'respond',
#   'yes',
#   'question'],
#  ['congrats',
#   'nokia',
#   'video',
#   'camera',
#   'phone',
#   'call',
#   'call',
#   'cost',
#   'ppm',
#   'ave',
#   'call',
#   'min',
#   'vary',
#   'mobile',
#   'close',
#   'post',
#   'bcm',
#   'ldn',
#   'wc',
#   'xx'],
#  ['booked', 'ticket', 'pongal'],
#  ['available',
#   'like',
#   'right',
#   'around',
#   'hillsborough',
#   'amp',
#   'lt',
#   'gt',
#   'th'],
#  ['message',
#   'sent',
#   'askin',
#   'lt',
#   'gt',
#   'dollar',
#   'shoul',
#   'pay',
#   'lt',
#   'gt',
#   'lt',
#   'gt'],
#  ['ask', 'iouri', 'told', 'story', 'like', 'ten', 'time', 'already'],
#  ['long', 'applebees', 'fucking', 'take'],
#  ['hi',
#   'hope',
#   'get',
#   'txt',
#   'journey',
#   'hasnt',
#   'gd',
#   'min',
#   'late',
#   'think'],
#  ['like', 'love', 'arrange'],
#  ['yes',
#   'really',
#   'great',
#   'bhaji',
#   'told',
#   'kallis',
#   'best',
#   'cricketer',
#   'sachin',
#   'world',
#   'tough',
#   'get'],
#  ['supposed', 'wake', 'gt'],
#  ['oic', 'saw', 'tot', 'din', 'found', 'group', 'liao'],
#  ['sorry', 'call', 'later'],
#  ['hey',
#   'hey',
#   'werethe',
#   'monkeespeople',
#   'say',
#   'monkeyaround',
#   'howdy',
#   'gorgeous',
#   'howu',
#   'doin',
#   'foundurself',
#   'jobyet',
#   'sausage',
#   'love',
#   'jen',
#   'xxx'],
#  ['sorry', 'battery', 'died', 'come', 'getting', 'gram', 'place'],
#  ['well',
#   'done',
#   'blimey',
#   'exercise',
#   'yeah',
#   'kinda',
#   'remember',
#   'wot',
#   'hmm'],
#  ['wont', 'get', 'concentration', 'dear', 'know', 'mind', 'everything'],
#  ['lol', 'made', 'plan', 'new', 'year'],
#  ['min', 'later'],
#  ['hank', 'lotsly'],
#  ['thanks', 'hope', 'good', 'day', 'today'],
#  ['detail', 'want', 'transfer', 'acc', 'enough'],
#  ['ok',
#   'tell',
#   'stay',
#   'yeah',
#   'tough',
#   'optimistic',
#   'thing',
#   'improve',
#   'month'],
#  ['loan',
#   'purpose',
#   'homeowner',
#   'tenant',
#   'welcome',
#   'previously',
#   'refused',
#   'still',
#   'help',
#   'call',
#   'free',
#   'text',
#   'back',
#   'help'],
#  ['si', 'si', 'think', 'ill', 'go', 'make', 'oreo', 'truffle'],
#  ['look',
#   'amy',
#   'ure',
#   'beautiful',
#   'intelligent',
#   'woman',
#   'like',
#   'lot',
#   'know',
#   'like',
#   'like',
#   'worry'],
#  ['hope',
#   'result',
#   'consistently',
#   'intelligent',
#   'kind',
#   'start',
#   'asking',
#   'practicum',
#   'link',
#   'keep',
#   'ear',
#   'open',
#   'best',
#   'ttyl'],
#  ['call',
#   'cost',
#   'guess',
#   'isnt',
#   'bad',
#   'miss',
#   'ya',
#   'need',
#   'ya',
#   'want',
#   'ya',
#   'love',
#   'ya'],
#  ['going',
#   'thru',
#   'different',
#   'feeling',
#   'wavering',
#   'decision',
#   'coping',
#   'individual',
#   'time',
#   'heal',
#   'everything',
#   'believe'],
#  ['go', 'phone', 'gonna', 'die', 'stay'],
#  ['great', 'never', 'better', 'day', 'give', 'even', 'reason', 'thank', 'god'],
#  ['upgrdcentre',
#   'orange',
#   'customer',
#   'may',
#   'claim',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'loyalty',
#   'call',
#   'offer',
#   'end',
#   'th',
#   'july',
#   'apply',
#   'opt',
#   'available'],
#  ['sorry', 'call', 'later', 'ok', 'bye'],
#  ['ok', 'way', 'railway'],
#  ['great',
#   'princess',
#   'love',
#   'giving',
#   'receiving',
#   'oral',
#   'doggy',
#   'style',
#   'fave',
#   'position',
#   'enjoy',
#   'making',
#   'love',
#   'lt',
#   'gt',
#   'time',
#   'per',
#   'night'],
#  ['put', 'stuff', 'road', 'keep', 'getting', 'slippery'],
#  ['going', 'ride', 'bike'],
#  ['yup', 'need', 'jus', 'wait', 'rain', 'stop'],
#  ['many', 'company', 'tell', 'language'],
#  ['okmail',
#   'dear',
#   'dave',
#   'final',
#   'notice',
#   'collect',
#   'tenerife',
#   'holiday',
#   'cash',
#   'award',
#   'call',
#   'landline',
#   'tc',
#   'sae',
#   'box',
#   'cw',
#   'wx',
#   'ppm'],
#  ['long', 'since', 'screamed', 'princess'],
#  ['nothing',
#   'meant',
#   'money',
#   'enters',
#   'account',
#   'bank',
#   'remove',
#   'flat',
#   'rate',
#   'someone',
#   'transfered',
#   'lt',
#   'gt',
#   'account',
#   'lt',
#   'gt',
#   'dollar',
#   'got',
#   'removed',
#   'bank',
#   'differ',
#   'charge',
#   'also',
#   'differ',
#   'sure',
#   'trust',
#   'ja',
#   'person',
#   'sending',
#   'account',
#   'detail',
#   'co'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'txting',
#   'moan',
#   'nyt',
#   'ec',
#   'msg'],
#  ['nice',
#   'line',
#   'said',
#   'broken',
#   'heart',
#   'plz',
#   'cum',
#   'time',
#   'infront',
#   'wise',
#   'trust',
#   'good'],
#  ['ok', 'gonna', 'head', 'usf', 'like', 'fifteen', 'minute'],
#  ['love', 'aathi', 'love', 'lot'],
#  ['tension', 'ah', 'machi', 'problem'],
#  ['pick', 'another', 'th', 'done'],
#  ['guy', 'getting', 'back', 'said', 'thinking', 'staying', 'mcr'],
#  ['almost', 'see', 'sec'],
#  ['yo', 'carlos', 'friend', 'already', 'asking', 'working', 'weekend'],
#  ['watching', 'tv', 'lor'],
#  ['thank', 'baby', 'cant', 'wait', 'taste', 'real', 'thing'],
#  ['change', 'fb', 'jaykwon', 'thuglyfe', 'falconerf'],
#  ['win', 'really', 'side', 'long', 'time'],
#  ['free',
#   'message',
#   'activate',
#   'free',
#   'text',
#   'message',
#   'replying',
#   'message',
#   'word',
#   'free',
#   'term',
#   'condition',
#   'visit',
#   'www',
#   'com'],
#  ['dear', 'reached', 'railway', 'happen'],
#  ['depends',
#   'quality',
#   'want',
#   'type',
#   'sent',
#   'boye',
#   'faded',
#   'glory',
#   'want',
#   'ralphs',
#   'maybe'],
#  ['think', 'fixed', 'send', 'test', 'message'],
#  ['sorry',
#   'man',
#   'account',
#   'dry',
#   'would',
#   'want',
#   'could',
#   'trade',
#   'back',
#   'half',
#   'could',
#   'buy',
#   'shit',
#   'credit',
#   'card'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'call',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'free',
#   'bx',
#   'ip',
#   'pm',
#   'dont',
#   'miss'],
#  ['sorry', 'meeting', 'call', 'later'],
#  ['class', 'lt', 'gt', 'reunion'],
#  ['free', 'call'],
#  ['got', 'meh'],
#  ['nope', 'think', 'go', 'monday', 'sorry', 'replied', 'late'],
#  ['told', 'accenture', 'confirm', 'true'],
#  ['kate', 'jackson', 'rec', 'center', 'ish', 'right'],
#  ['dear', 'reache', 'room'],
#  ['fighting',
#   'world',
#   'easy',
#   'either',
#   'win',
#   'lose',
#   'bt',
#   'fightng',
#   'close',
#   'dificult',
#   'lose',
#   'lose',
#   'win',
#   'still',
#   'lose'],
#  ['come'],
#  ['check', 'nuerologist'],
#  ['lolnice', 'went', 'fish', 'water'],
#  ['congratulation',
#   'week',
#   'competition',
#   'draw',
#   'prize',
#   'claim',
#   'call',
#   'stop',
#   'sm',
#   'ppm'],
#  ['waiting',
#   'car',
#   'dat',
#   'bored',
#   'wat',
#   'co',
#   'wait',
#   'outside',
#   'got',
#   'nothing',
#   'home',
#   'stuff',
#   'watch',
#   'tv',
#   'wat'],
#  ['maybe', 'westshore', 'hyde', 'park', 'village', 'place', 'near', 'house'],
#  ['know',
#   'anthony',
#   'bringing',
#   'money',
#   'school',
#   'fee',
#   'pay',
#   'rent',
#   'stuff',
#   'like',
#   'thats',
#   'need',
#   'help',
#   'friend',
#   'need'],
#  ['significance'],
#  ['opinion',
#   'jada',
#   'kusruthi',
#   'lovable',
#   'silent',
#   'spl',
#   'character',
#   'matured',
#   'stylish',
#   'simple',
#   'pls',
#   'reply'],
#  ['latest', 'still', 'scrounge', 'ammo', 'want', 'give', 'new', 'ak', 'try'],
#  ['prabha', 'soryda', 'realy', 'frm', 'heart', 'sory'],
#  ['lol', 'ok', 'forgiven'],
#  ['jst', 'change', 'tat'],
#  ['guaranteed',
#   'latest',
#   'nokia',
#   'phone',
#   'gb',
#   'ipod',
#   'mp',
#   'player',
#   'prize',
#   'txt',
#   'word',
#   'collect',
#   'ibhltd',
#   'ldnw',
#   'mtmsgrcvd'],
#  ['competition'],
#  ['boltblue',
#   'tone',
#   'reply',
#   'poly',
#   'mono',
#   'eg',
#   'poly',
#   'cha',
#   'cha',
#   'slide',
#   'yeah',
#   'slow',
#   'jamz',
#   'toxic',
#   'come',
#   'stop',
#   'tone',
#   'txt'],
#  ['credit',
#   'topped',
#   'http',
#   'www',
#   'bubbletext',
#   'com',
#   'renewal',
#   'pin',
#   'tgxxrz'],
#  ['way',
#   'transport',
#   'le',
#   'problematic',
#   'sat',
#   'night',
#   'way',
#   'want',
#   'ask',
#   'join',
#   'bday',
#   'feel',
#   'free',
#   'need',
#   'know',
#   'definite',
#   'no',
#   'booking',
#   'fri'],
#  ['usually',
#   'person',
#   'unconscious',
#   'child',
#   'adult',
#   'may',
#   'behave',
#   'abnormally',
#   'call'],
#  ['ebay', 'might', 'le', 'elsewhere'],
#  ['shall', 'come', 'get', 'pickle'],
#  ['gonna', 'go', 'get', 'taco'],
#  ['rude', 'campus'],
#  ['urgent',
#   'mobile',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'nd',
#   'attempt',
#   'contact',
#   'call',
#   'box',
#   'qu'],
#  ['hi', 'ard', 'christmas', 'enjoy', 'merry', 'ma'],
#  ['today',
#   'offer',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucher',
#   'text',
#   'yes',
#   'savamob',
#   'member',
#   'offer',
#   'mobile',
#   'sub',
#   'unsub',
#   'reply'],
#  ['yes', 'pretty', 'lady', 'like', 'single'],
#  ['recieve',
#   'tone',
#   'within',
#   'next',
#   'hr',
#   'term',
#   'condition',
#   'please',
#   'see',
#   'channel',
#   'teletext',
#   'pg'],
#  ['jay', 'say', 'double', 'faggot'],
# ...
#   'oh',
#   'countin',
#   'aburo',
#   'enjoy',
#   'message',
#   'sent',
#   'day',
#   'ago'],
#  ['surely', 'result', 'offer'],
#  ['good', 'morning', 'dear', 'great', 'amp', 'successful', 'day'],
#  ['want',
#   'anytime',
#   'network',
#   'min',
#   'text',
#   'new',
#   'video',
#   'phone',
#   'five',
#   'pound',
#   'per',
#   'week',
#   'call',
#   'reply',
#   'delivery',
#   'tomorrow'],
#  ['sir',
#   'late',
#   'paying',
#   'rent',
#   'past',
#   'month',
#   'pay',
#   'lt',
#   'gt',
#   'charge',
#   'felt',
#   'would',
#   'inconsiderate',
#   'nag',
#   'something',
#   'give',
#   'great',
#   'cost',
#   'didnt',
#   'speak',
#   'however',
#   'recession',
#   'wont',
#   'able',
#   'pay',
#   'charge',
#   'month',
#   'hence',
#   'askin',
#   'well',
#   'ahead',
#   'month',
#   'end',
#   'please',
#   'help',
#   'thanks'],
#  ['tried',
#   'contact',
#   'offer',
#   'new',
#   'video',
#   'phone',
#   'anytime',
#   'network',
#   'min',
#   'half',
#   'price',
#   'rental',
#   'camcorder',
#   'call',
#   'reply',
#   'delivery',
#   'wed'],
#  ['last',
#   'chance',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucher',
#   'text',
#   'yes',
#   'savamob',
#   'member',
#   'offer',
#   'mobile',
#   'sub',
#   'remove',
#   'txt',
#   'stop'],
#  ['luv',
#   'soo',
#   'much',
#   'understand',
#   'special',
#   'ring',
#   'morrow',
#   'luv',
#   'xxx'],
#  ['pls', 'send', 'comprehensive', 'mail', 'paying', 'much'],
#  ['prashanthettan',
#   'mother',
#   'passed',
#   'away',
#   'last',
#   'night',
#   'pray',
#   'family'],
#  ['urgent',
#   'call',
#   'landline',
#   'complimentary',
#   'ibiza',
#   'holiday',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'po',
#   'box',
#   'sk',
#   'wp',
#   'ppm'],
#  ['going'],
#  ['meanwhile',
#   'shit',
#   'suite',
#   'xavier',
#   'decided',
#   'give',
#   'lt',
#   'gt',
#   'second',
#   'warning',
#   'samantha',
#   'coming',
#   'playing',
#   'jay',
#   'guitar',
#   'impress',
#   'shit',
#   'also',
#   'think',
#   'doug',
#   'realizes',
#   'live',
#   'anymore'],
#  ['stomach',
#   'thru',
#   'much',
#   'trauma',
#   'swear',
#   'eat',
#   'better',
#   'lose',
#   'weight'],
#  ['office', 'whats', 'matter', 'msg', 'call', 'break'],
#  ['yeah',
#   'barely',
#   'enough',
#   'room',
#   'two',
#   'many',
#   'fucking',
#   'shoe',
#   'sorry',
#   'man',
#   'see',
#   'later'],
#  ['today',
#   'offer',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucher',
#   'text',
#   'yes',
#   'savamob',
#   'member',
#   'offer',
#   'mobile',
#   'sub',
#   'unsub',
#   'reply'],
#  ['reach', 'orchard', 'already', 'wan', 'go', 'buy', 'ticket', 'first'],
#  ['real', 'baby', 'want', 'bring', 'inner', 'tigress'],
#  ['da', 'run', 'activate', 'full', 'version', 'da'],
#  ['ah',
#   'poor',
#   'baby',
#   'hope',
#   'urfeeling',
#   'bettersn',
#   'luv',
#   'probthat',
#   'overdose',
#   'work',
#   'hey',
#   'go',
#   'careful',
#   'spk',
#   'sn',
#   'lot',
#   'lovejen',
#   'xxx'],
#  ['stop', 'story', 'told', 'returned', 'saying', 'order'],
#  ['talk',
#   'sexy',
#   'make',
#   'new',
#   'friend',
#   'fall',
#   'love',
#   'world',
#   'discreet',
#   'text',
#   'dating',
#   'service',
#   'text',
#   'vip',
#   'see',
#   'could',
#   'meet'],
#  ['going', 'take', 'babe'],
#  ['hai',
#   'ana',
#   'tomarrow',
#   'coming',
#   'morning',
#   'lt',
#   'decimal',
#   'gt',
#   'ill',
#   'sathy',
#   'go',
#   'rto',
#   'office',
#   'reply',
#   'came',
#   'home'],
#  ['spoon', 'okay'],
#  ['say', 'somebody', 'named', 'tampa'],
#  ['work', 'going', 'min'],
#  ['brother', 'genius'],
#  ['sorry',
#   'guess',
#   'whenever',
#   'get',
#   'hold',
#   'connection',
#   'maybe',
#   'hour',
#   'two',
#   'text'],
#  ['find', 'time', 'bus', 'coz', 'need', 'sort', 'stuff'],
#  ['dude', 'ive', 'seeing', 'lotta', 'corvette', 'lately'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'either',
#   'yr',
#   'supply',
#   'cd',
#   'virgin',
#   'record',
#   'mystery',
#   'gift',
#   'guaranteed',
#   'call',
#   'www',
#   'smsco',
#   'net',
#   'pm',
#   'approx',
#   'min'],
#  ['consider',
#   'wall',
#   'bunker',
#   'shit',
#   'important',
#   'never',
#   'play',
#   'peaceful',
#   'guess',
#   'place',
#   'high',
#   'enough',
#   'matter'],
#  ['private',
#   'account',
#   'statement',
#   'xxxxxx',
#   'show',
#   'un',
#   'redeemed',
#   'point',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['hello',
#   'need',
#   'posh',
#   'bird',
#   'chap',
#   'user',
#   'trial',
#   'prod',
#   'champneys',
#   'put',
#   'need',
#   'address',
#   'dob',
#   'asap',
#   'ta'],
#  ['want',
#   'xmas',
#   'free',
#   'text',
#   'message',
#   'new',
#   'video',
#   'phone',
#   'half',
#   'price',
#   'line',
#   'rental',
#   'call',
#   'free',
#   'find'],
#  ['well',
#   'officially',
#   'philosophical',
#   'hole',
#   'wanna',
#   'call',
#   'home',
#   'ready',
#   'saved'],
#  ['going',
#   'good',
#   'problem',
#   'still',
#   'need',
#   'little',
#   'experience',
#   'understand',
#   'american',
#   'customer',
#   'voice'],
#  ['text', 'drop'],
#  ['ugh', 'long', 'day', 'exhausted', 'want', 'cuddle', 'take', 'nap'],
#  ['talk',
#   'atleast',
#   'day',
#   'otherwise',
#   'miss',
#   'best',
#   'friend',
#   'world',
#   'shakespeare',
#   'shesil',
#   'lt',
#   'gt'],
#  ['shop',
#   'till',
#   'drop',
#   'either',
#   'cash',
#   'travel',
#   'voucher',
#   'call',
#   'ntt',
#   'po',
#   'box',
#   'cr',
#   'bt',
#   'fixedline',
#   'cost',
#   'ppm',
#   'mobile',
#   'vary'],
#  ['castor', 'need', 'see', 'something'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'know',
#   'country',
#   'liverpool',
#   'played',
#   'mid',
#   'week',
#   'txt',
#   'ansr',
#   'sp',
#   'tyrone'],
#  ['secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'find',
#   'reveal',
#   'think',
#   'ur',
#   'special',
#   'call'],
#  ['secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'find',
#   'reveal',
#   'think',
#   'ur',
#   'special',
#   'call',
#   'stopsms'],
#  ['reminder',
#   'downloaded',
#   'content',
#   'already',
#   'paid',
#   'goto',
#   'http',
#   'doit',
#   'mymoby',
#   'tv',
#   'collect',
#   'content'],
#  ['see',
#   'knew',
#   'giving',
#   'break',
#   'time',
#   'woul',
#   'lead',
#   'always',
#   'wanting',
#   'miss',
#   'curfew',
#   'gonna',
#   'gibe',
#   'til',
#   'one',
#   'midnight',
#   'movie',
#   'gonna',
#   'get',
#   'til',
#   'need',
#   'come',
#   'home',
#   'need',
#   'getsleep',
#   'anything',
#   'need',
#   'studdying',
#   'ear',
#   'training'],
#  ['love', 'give', 'massage', 'use', 'lot', 'baby', 'oil', 'fave', 'position'],
#  ['dude', 'go', 'sup'],
#  ['yoyyooo',
#   'know',
#   'change',
#   'permission',
#   'drive',
#   'mac',
#   'usb',
#   'flash',
#   'drive'],
#  ['gibbs', 'unsold', 'mike', 'hussey'],
#  ['like', 'talk', 'pa', 'able', 'dont', 'know'],
#  ['dun', 'cut', 'short', 'leh', 'dun', 'like', 'ah', 'failed', 'quite', 'sad'],
#  ['unbelievable', 'faglord'],
#  ['wife', 'knew', 'time', 'murder', 'exactly'],
#  ['ask', 'princess'],
#  ['great', 'princess', 'thinking'],
#  ['nutter', 'cutter', 'ctter', 'cttergg', 'cttargg', 'ctargg', 'ctagg', 'ie'],
#  ['ok',
#   'noe',
#   'busy',
#   'really',
#   'bored',
#   'msg',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'choose',
#   'one'],
#  ['class', 'early', 'tomorrow', 'thus', 'trying', 'smoke', 'lt', 'gt'],
#  ['superb',
#   'thought',
#   'grateful',
#   'dont',
#   'everything',
#   'want',
#   'mean',
#   'still',
#   'opportunity',
#   'happier',
#   'tomorrow',
#   'today'],
#  ['hope', 'good', 'week', 'checking'],
#  ['used',
#   'hope',
#   'agent',
#   'drop',
#   'since',
#   'booked',
#   'thing',
#   'year',
#   'whole',
#   'boston',
#   'nyc',
#   'experiment'],
#  ['thursday', 'night', 'yeah', 'sure', 'thing', 'work'],
#  ['free',
#   'ringtone',
#   'waiting',
#   'collected',
#   'simply',
#   'text',
#   'password',
#   'mix',
#   'verify',
#   'get',
#   'usher',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['probably',
#   'money',
#   'worry',
#   'thing',
#   'coming',
#   'due',
#   'several',
#   'outstanding',
#   'invoice',
#   'work',
#   'two',
#   'three',
#   'month',
#   'ago'],
#  ['possible', 'teach'],
#  ['wonder', 'phone', 'battery', 'went', 'dead', 'tell', 'love', 'babe'],
#  ['lovely', 'smell', 'bus', 'tobacco'],
#  ['getting', 'worried', 'derek', 'taylor', 'already', 'assumed', 'worst'],
#  ['hey', 'charles', 'sorry', 'late', 'reply'],
#  ['lastest',
#   'stereophonics',
#   'marley',
#   'dizzee',
#   'racal',
#   'libertine',
#   'stroke',
#   'win',
#   'nookii',
#   'game',
#   'flirt',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'text',
#   'wap'],
#  ['give', 'plus', 'said', 'grinule', 'greet', 'whenever', 'speak'],
#  ['white', 'fudge', 'oreo', 'store'],
#  ['january',
#   'male',
#   'sale',
#   'hot',
#   'gay',
#   'chat',
#   'cheaper',
#   'call',
#   'national',
#   'rate',
#   'min',
#   'cheap',
#   'min',
#   'peak',
#   'stop',
#   'text',
#   'call',
#   'min'],
#  ['love',
#   'come',
#   'took',
#   'long',
#   'leave',
#   'zaher',
#   'got',
#   'word',
#   'ym',
#   'happy',
#   'see',
#   'sad',
#   'left',
#   'miss'],
#  ['sorry', 'hurt'],
#  ['feel',
#   'nauseous',
#   'pissed',
#   'eat',
#   'sweet',
#   'week',
#   'cause',
#   'today',
#   'planning',
#   'pig',
#   'dieting',
#   'week',
#   'hungry'],
#  ['ok', 'lor', 'early', 'still', 'project', 'meeting'],
#  ['call', 'da', 'waiting', 'call'],
#  ['could', 'ask', 'carlos', 'could', 'get', 'anybody', 'else', 'chip'],
#  ['actually', 'send', 'reminder', 'today', 'wonderful', 'weekend'],
#  ['people',
#   'see',
#   'msg',
#   'think',
#   'iam',
#   'addicted',
#   'msging',
#   'wrong',
#   'bcoz',
#   'don',
#   'know',
#   'iam',
#   'addicted',
#   'sweet',
#   'friend',
#   'bslvyl'],
#  ['hey',
#   'gave',
#   'photo',
#   'registered',
#   'driving',
#   'ah',
#   'tmr',
#   'wanna',
#   'meet',
#   'yck'],
#  ['dont', 'talk', 'ever', 'ok', 'word'],
#  ['wana', 'see'],
#  ['way', 'school', 'pls', 'send', 'ashley', 'number'],
#  ['shall', 'fine', 'avalarr', 'hollalater'],
#  ['went',
#   'attend',
#   'another',
#   'two',
#   'round',
#   'today',
#   'still',
#   'reach',
#   'home'],
#  ['actually',
#   'deleted',
#   'old',
#   'website',
#   'blogging',
#   'magicalsongs',
#   'blogspot',
#   'com'],
#  ['wait', 'chikku', 'il', 'send', 'aftr', 'lt', 'gt', 'min'],
#  ['diet',
#   'ate',
#   'many',
#   'slice',
#   'pizza',
#   'yesterday',
#   'ugh',
#   'always',
#   'diet'],
#  ['give', 'kvb', 'acc', 'detail'],
#  ['oh', 'come', 'ah'],
#  ['money',
#   'lucky',
#   'winner',
#   'claim',
#   'prize',
#   'text',
#   'money',
#   'million',
#   'give',
#   'away',
#   'ppt',
#   'normal',
#   'text',
#   'rate',
#   'box',
#   'jy'],
#  ['really',
#   'sorry',
#   'able',
#   'friday',
#   'hope',
#   'find',
#   'alternative',
#   'hope',
#   'yr',
#   'term',
#   'going',
#   'ok'],
#  ['congratulation',
#   'ore',
#   'mo',
#   'owo',
#   'wa',
#   'enjoy',
#   'wish',
#   'many',
#   'happy',
#   'moment',
#   'fro',
#   'wherever',
#   'go'],
#  ['samus', 'shoulder', 'yet'],
#  ['time', 'think', 'need', 'know', 'near', 'campus'],
#  ['dear',
#   'matthew',
#   'please',
#   'call',
#   'landline',
#   'complimentary',
#   'lux',
#   'tenerife',
#   'holiday',
#   'cash',
#   'await',
#   'collection',
#   'ppm',
#   'sae',
#   'box',
#   'sk',
#   'xh'],
#  ['dun', 'wear', 'jean', 'lor'],
#  ['since', 'side', 'fever', 'vomitin'],
#  ['college'],
#  ['urgent',
#   'call',
#   'landline',
#   'complimentary',
#   'tenerife',
#   'holiday',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'box',
#   'hp',
#   'yf',
#   'ppm'],
#  ['better',
#   'made',
#   'friday',
#   'stuffed',
#   'like',
#   'pig',
#   'yesterday',
#   'feel',
#   'bleh',
#   'least',
#   'writhing',
#   'pain',
#   'kind',
#   'bleh'],
#  ['sell',
#   'ton',
#   'coin',
#   'sell',
#   'coin',
#   'someone',
#   'thru',
#   'paypal',
#   'voila',
#   'money',
#   'back',
#   'life',
#   'pocket'],
#  ['theyre', 'lot', 'place', 'hospital', 'medical', 'place', 'safe'],
#  ['getting',
#   'touch',
#   'folk',
#   'waiting',
#   'company',
#   'txt',
#   'back',
#   'name',
#   'age',
#   'opt',
#   'enjoy',
#   'community',
#   'sm'],
#  ['also',
#   'sorta',
#   'blown',
#   'couple',
#   'time',
#   'recently',
#   'id',
#   'rather',
#   'text',
#   'blue',
#   'looking',
#   'weed'],
#  ['sent',
#   'score',
#   'sophas',
#   'secondary',
#   'application',
#   'school',
#   'think',
#   'thinking',
#   'applying',
#   'research',
#   'cost',
#   'also',
#   'contact',
#   'joke',
#   'ogunrinde',
#   'school',
#   'one',
#   'le',
#   'expensive',
#   'one'],
#  ['cant', 'wait', 'see', 'photo', 'useful'],
#  ['ur',
#   'cash',
#   'balance',
#   'currently',
#   'pound',
#   'maximize',
#   'ur',
#   'cash',
#   'send',
#   'go',
#   'msg',
#   'cc',
#   'po',
#   'box',
#   'tcr'],
#  ['hey',
#   'booked',
#   'kb',
#   'sat',
#   'already',
#   'lesson',
#   'going',
#   'ah',
#   'keep',
#   'sat',
#   'night',
#   'free',
#   'need',
#   'meet',
#   'confirm',
#   'lodging'],
#  ['chk', 'ur', 'belovd', 'dict'],
#  ['time', 'want', 'come'],
#  ['awesome', 'lemme', 'know', 'whenever', 'around'],
#  ['shb', 'ok', 'lor', 'thanx'],
#  ['beautiful',
#   'truth',
#   'gravity',
#   'read',
#   'carefully',
#   'heart',
#   'feel',
#   'light',
#   'someone',
#   'feel',
#   'heavy',
#   'someone',
#   'leaf',
#   'good',
#   'night'],
#  ['also', 'remember', 'get', 'dobby', 'bowl', 'car'],
#  ['filthy', 'story', 'girl', 'waiting'],
#  ['sorry',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'poor',
#   'thing',
#   'one',
#   'night',
#   'tmr',
#   'brand',
#   'new',
#   'room',
#   'sleep'],
#  ['love',
#   'decision',
#   'feeling',
#   'could',
#   'decide',
#   'love',
#   'life',
#   'would',
#   'much',
#   'simpler',
#   'le',
#   'magical'],
#  ['welp', 'apparently', 'retired'],
#  ['sort',
#   'code',
#   'acc',
#   'bank',
#   'natwest',
#   'reply',
#   'confirm',
#   'sent',
#   'right',
#   'person'],
#  ['sure', 'take', 'sick', 'time'],
#  ['urgent',
#   'trying',
#   'contact',
#   'today',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr'],
#  ['watching',
#   'cartoon',
#   'listening',
#   'music',
#   'amp',
#   'eve',
#   'go',
#   'temple',
#   'amp',
#   'church'],
#  ['yo',
#   'chad',
#   'gymnastics',
#   'class',
#   'wanna',
#   'take',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'full'],
#  ['much', 'buzy'],
#  ['better', 'still', 'catch', 'let', 'ask', 'sell', 'lt', 'gt'],
#  ['sure', 'night', 'menu', 'know', 'noon', 'menu'],
#  ['want',
#   'come',
#   'back',
#   'beautiful',
#   'necklace',
#   'token',
#   'heart',
#   'thats',
#   'give',
#   'wife',
#   'liking',
#   'see',
#   'one',
#   'give',
#   'dont',
#   'call',
#   'wait',
#   'till',
#   'come'],
#  ['willing', 'go', 'aptitude', 'class'],
#  ['wont', 'trying', 'sort', 'house', 'ok'],
#  ['yar',
#   'lor',
#   'wan',
#   'go',
#   'horse',
#   'racing',
#   'today',
#   'mah',
#   'eat',
#   'earlier',
#   'lor',
#   'ate',
#   'chicken',
#   'rice'],
#  ['haha', 'awesome', 'omw', 'back'],
#  ['yup', 'thk', 'shop', 'close', 'lor'],
#  ['account', 'number'],
#  ['eh', 'send', 'wrongly', 'lar'],
#  ['hey',
#   'ad',
#   'crap',
#   'nite',
#   'borin',
#   'without',
#   'ya',
#   'boggy',
#   'boring',
#   'biatch',
#   'thanx',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['ok', 'shall', 'talk'],
#  ['dont',
#   'hesitate',
#   'know',
#   'second',
#   'time',
#   'weakness',
#   'like',
#   'keep',
#   'notebook',
#   'eat',
#   'day',
#   'anything',
#   'changed',
#   'day',
#   'sure',
#   'nothing'],
#  ['hey', 'pay', 'salary', 'de', 'lt', 'gt'],
#  ['another', 'month', 'need', 'chocolate', 'weed', 'alcohol'],
#  ['started', 'searching', 'get', 'job', 'day', 'great', 'potential', 'talent'],
#  ['reckon', 'need', 'town', 'eightish', 'walk', 'carpark'],
#  ['congrats',
#   'mobile',
#   'videophones',
#   'call',
#   'videochat',
#   'wid',
#   'mate',
#   'play',
#   'java',
#   'game',
#   'dload',
#   'polyph',
#   'music',
#   'noline',
#   'rentl'],
#  ['look', 'fuckin', 'time', 'fuck', 'think'],
#  ['yo', 'guess', 'dropped'],
#  ['carlos', 'say', 'mu', 'lt', 'gt', 'minute'],
#  ['office', 'call', 'lt', 'gt', 'min'],
#  ['geeee',
#   'miss',
#   'already',
#   'know',
#   'think',
#   'fuck',
#   'wait',
#   'till',
#   'next',
#   'year',
#   'together',
#   'loving',
#   'kiss'],
#  ['yun',
#   'ah',
#   'ubi',
#   'one',
#   'say',
#   'wan',
#   'call',
#   'tomorrow',
#   'call',
#   'look',
#   'irene',
#   'ere',
#   'got',
#   'bus',
#   'ubi',
#   'cres',
#   'ubi',
#   'tech',
#   'park',
#   'ph',
#   'st',
#   'wkg',
#   'day'],
#  ['ugh', 'gotta', 'drive', 'back', 'sd', 'la', 'butt', 'sore'],
#  ['th', 'july'],
#  ['hi',
#   'im',
#   'relaxing',
#   'time',
#   'ever',
#   'get',
#   'every',
#   'day',
#   'party',
#   'good',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'ish'],
#  ['wan', 'come', 'come', 'lor', 'din', 'stripe', 'skirt'],
#  ['xmas',
#   'story',
#   'peace',
#   'xmas',
#   'msg',
#   'love',
#   'xmas',
#   'miracle',
#   'jesus',
#   'hav',
#   'blessed',
#   'month',
#   'ahead',
#   'amp',
#   'wish',
#   'merry',
#   'xmas'],
#  ['number'],
#  ['change', 'one', 'next', 'escalator'],
#  ['yetunde', 'class', 'run', 'water', 'make', 'ok', 'pls'],
#  ['lot',
#   'happened',
#   'feel',
#   'quiet',
#   'beth',
#   'aunt',
#   'charlie',
#   'working',
#   'lot',
#   'helen',
#   'mo'],
#  ['wait',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar',
#   'dun',
#   'go',
#   'get',
#   'car',
#   'come',
#   'back',
#   'pick'],
#  ['aight', 'thanks', 'comin'],
#  ['heard', 'abt', 'tat'],
#  ...]

# %% [markdown]
# ## Creating a model here

# %%
gen_model = gensim.models.Word2Vec(data , window = 5, min_count=2)

# %%
gen_model.corpus_count
# Out:
# 5564

# %%
gen_model.wv['true']
# Out:
# array([-0.06955916,  0.19918968,  0.04472566,  0.00323539,  0.02958924,
#        -0.24830404,  0.06872506,  0.3865112 , -0.15748863, -0.13047616,
#        -0.16094357, -0.25219616, -0.00832602,  0.08995714,  0.05514419,
#        -0.14880903, -0.00886152, -0.21105322,  0.00715304, -0.3859799 ,
#         0.07948924,  0.08129758,  0.09995139, -0.10358785, -0.07191981,
#         0.03750145, -0.12349802, -0.10249162, -0.1810371 ,  0.05846952,
#         0.22536889,  0.02581494,  0.10104671, -0.1332759 , -0.10462256,
#         0.2618104 , -0.01020282, -0.1225917 , -0.09598018, -0.27830774,
#        -0.01892437, -0.18544014, -0.05047188,  0.06059856,  0.17091952,
#        -0.11377553, -0.16383941, -0.01231472,  0.1074466 ,  0.14653024,
#         0.0842393 , -0.17577203, -0.07261598, -0.02942367, -0.11227053,
#         0.12445485,  0.07824145, -0.00204713, -0.24304931,  0.04486886,
#         0.07429691,  0.07755686, -0.05959117,  0.01613203, -0.21256138,
#         0.15580262,  0.10682927,  0.12675789, -0.2517039 ,  0.28497574,
#        -0.12840079,  0.12204408,  0.22596669, -0.05251008,  0.18261875,
#         0.10451538,  0.00731857, -0.03208046, -0.16408269,  0.11168574,
#        -0.04095383, -0.06211226, -0.19753782,  0.25324145, -0.03987079,
#         0.02092817, -0.05978406,  0.2310158 ,  0.23493376,  0.11825441,
#         0.28741693,  0.11470674,  0.03653289,  0.10538391,  0.29470542,
#         0.18957624,  0.10767505, -0.20803832,  0.0729054 , -0.03657403],
#       dtype=float32)

# %%
def avg_word2vec(doc):
    return np.mean([gen_model.wv[word] for word in doc if word in gen_model.wv.index_to_key], axis = 0)

# %%
## tqdm is used to display the progress bar in case of loop
from tqdm import tqdm
import numpy as np

# %%
x = []
for i in tqdm(range(0,len(data))):
    x.append(avg_word2vec(data[i]))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 5564/5564 [00:01<00:00, 2967.32it/s]

# %%
x
# Out:
# [array([-0.08957642,  0.2760092 ,  0.06748349,  0.02053057,  0.03584648,
#         -0.3330439 ,  0.10289612,  0.52521896, -0.20264691, -0.16287957,
#         -0.20593466, -0.34974432, -0.01349413,  0.10987574,  0.06247725,
#         -0.20727341, -0.02374696, -0.28687352,  0.00997861, -0.51630217,
#          0.09860113,  0.10848317,  0.12866028, -0.13001294, -0.08785524,
#          0.05499409, -0.17178251, -0.1483139 , -0.2395898 ,  0.07369483,
#          0.2983684 ,  0.04245346,  0.12238222, -0.18482828, -0.15566894,
#          0.34398344, -0.01571408, -0.16641775, -0.11269902, -0.3798634 ,
#         -0.01239007, -0.25178644, -0.05770686,  0.08520132,  0.22819526,
#         -0.14771695, -0.20684288, -0.01855484,  0.1403745 ,  0.20457979,
#          0.10179054, -0.24353908, -0.08959202, -0.02787657, -0.15287411,
#          0.16699553,  0.11136764, -0.00088235, -0.31364784,  0.05320905,
#          0.08885884,  0.11512369, -0.09491283,  0.03084638, -0.2888398 ,
#          0.21975745,  0.13298135,  0.1637237 , -0.33964252,  0.38111603,
#         -0.17821534,  0.15401793,  0.2908983 , -0.06734869,  0.23816483,
#          0.13507472,  0.01988522, -0.05081293, -0.2083589 ,  0.16444178,
#         -0.04493849, -0.07751362, -0.27058366,  0.35295334, -0.04018198,
#          0.01758192, -0.09075105,  0.31888977,  0.30951855,  0.14994434,
#          0.38379154,  0.16796236,  0.03623575,  0.15286697,  0.38247514,
#          0.2698725 ,  0.14521798, -0.2815039 ,  0.09747541, -0.05537494],
#        dtype=float32),
#  array([-0.05864348,  0.18693605,  0.04675434,  0.01451806,  0.02624234,
#         -0.2276349 ,  0.06902634,  0.35208908, -0.13650025, -0.11073271,
#         -0.13910428, -0.23564386, -0.00721859,  0.07612945,  0.03725064,
#         -0.14300516, -0.0140055 , -0.1934094 ,  0.00256465, -0.35059053,
#          0.06646111,  0.07447754,  0.08597977, -0.08858341, -0.06681697,
#          0.04105684, -0.11519518, -0.09595328, -0.1592792 ,  0.04472452,
#          0.20864113,  0.0299907 ,  0.08080722, -0.12769231, -0.10400598,
#          0.23184583, -0.01325944, -0.11483242, -0.07566905, -0.2581504 ,
#         -0.00384783, -0.16502334, -0.03693456,  0.05735395,  0.15777342,
#         -0.09526978, -0.1422937 , -0.018982  ,  0.09943028,  0.13614568,
#          0.06950435, -0.16273615, -0.06463484, -0.01818156, -0.11023927,
#          0.11631323,  0.07216566, -0.00899163, -0.21744113,  0.03270695,
#          0.06304888,  0.07545327, -0.06133907,  0.02182321, -0.19627675,
#          0.14730762,  0.09028048,  0.1119983 , -0.23135933,  0.25872594,
#         -0.12112866,  0.10932903,  0.19510138, -0.03926329,  0.16562346,
#          0.09042685,  0.01359193, -0.03255586, -0.14407697,  0.11034535,
#         -0.03339735, -0.05527278, -0.18348296,  0.23990169, -0.02573289,
#          0.01362814, -0.05958151,  0.21511956,  0.20653927,  0.10161813,
#          0.26234737,  0.11437719,  0.02630333,  0.10205263,  0.2602918 ,
#          0.18014662,  0.0996711 , -0.18876263,  0.06261846, -0.031607  ],
#        dtype=float32),
#  array([-8.47024769e-02,  2.62909353e-01,  6.52180985e-02,  2.52047833e-02,
#          3.95587310e-02, -3.11622083e-01,  9.90041420e-02,  4.90281492e-01,
#         -1.87969908e-01, -1.49381012e-01, -1.91342413e-01, -3.24549973e-01,
#         -4.27790824e-03,  1.06526673e-01,  6.01316690e-02, -1.99583560e-01,
#         -2.35101655e-02, -2.68689901e-01,  7.84899853e-03, -4.80444282e-01,
#          9.26117823e-02,  1.00157358e-01,  1.23938598e-01, -1.21143684e-01,
#         -7.59733692e-02,  5.46057895e-02, -1.54804587e-01, -1.41792268e-01,
#         -2.27618739e-01,  6.73368126e-02,  2.84204364e-01,  3.55455205e-02,
#          1.17018305e-01, -1.72791973e-01, -1.42761379e-01,  3.20844620e-01,
#         -1.24697564e-02, -1.62061721e-01, -1.04624808e-01, -3.59278828e-01,
#         -1.79350562e-02, -2.38747954e-01, -5.59419207e-02,  8.32733661e-02,
#          2.17272326e-01, -1.39462203e-01, -1.93620831e-01, -1.92847811e-02,
#          1.33541897e-01,  1.94062650e-01,  9.34081376e-02, -2.23513842e-01,
#         -8.89808610e-02, -2.02795956e-02, -1.45905465e-01,  1.58574373e-01,
#          1.02445506e-01,  2.84992944e-04, -2.97580540e-01,  4.87750396e-02,
#          8.34999606e-02,  1.03857920e-01, -8.91365856e-02,  3.01771164e-02,
#         -2.71780163e-01,  2.03918412e-01,  1.24483444e-01,  1.53909490e-01,
#         -3.25904042e-01,  3.65259439e-01, -1.63568497e-01,  1.49684161e-01,
#          2.82619953e-01, -6.15770631e-02,  2.18036696e-01,  1.20747089e-01,
#          1.92404147e-02, -4.97399308e-02, -1.95185661e-01,  1.54939473e-01,
#         -4.18168493e-02, -7.52580017e-02, -2.51832545e-01,  3.26898545e-01,
#         -4.00601402e-02,  1.81462709e-02, -8.87265205e-02,  3.05934131e-01,
#          2.95211852e-01,  1.42830774e-01,  3.61412168e-01,  1.60718843e-01,
#          4.06571738e-02,  1.41887039e-01,  3.61231863e-01,  2.60120004e-01,
#          1.34720922e-01, -2.64633477e-01,  8.85746926e-02, -4.62162569e-02],
#        dtype=float32),
#  array([-0.1151444 ,  0.33778176,  0.08333   ,  0.02738978,  0.04521671,
#         -0.41361222,  0.12677151,  0.6524427 , -0.2468044 , -0.19954413,
#         -0.25559464, -0.43062735, -0.01697346,  0.13837571,  0.08035938,
#         -0.2533271 , -0.03113524, -0.35546577,  0.01326065, -0.6327209 ,
#          0.1179366 ,  0.13501044,  0.1601315 , -0.16621213, -0.11171794,
#          0.07327244, -0.21439101, -0.17958672, -0.2994248 ,  0.08980527,
#          0.3727716 ,  0.05262098,  0.15411519, -0.22439827, -0.19334985,
#          0.4250747 , -0.01890672, -0.20129709, -0.14046666, -0.46966004,
#         -0.01349205, -0.31352258, -0.07324746,  0.10809597,  0.2885693 ,
#         -0.17967372, -0.26159015, -0.02245752,  0.18124259,  0.25094047,
#          0.12414864, -0.3041227 , -0.11402756, -0.03003467, -0.19047028,
#          0.21429312,  0.13671479, -0.00544759, -0.38858163,  0.06572398,
#          0.11191045,  0.1431048 , -0.12067135,  0.03685801, -0.35651   ,
#          0.2694957 ,  0.16694717,  0.19856827, -0.4251739 ,  0.47610605,
#         -0.21762405,  0.19262888,  0.36061755, -0.0808858 ,  0.2941004 ,
#          0.17387027,  0.02823395, -0.06924386, -0.25900954,  0.20380007,
#         -0.05173461, -0.09590004, -0.33368266,  0.44187656, -0.05089729,
#          0.02653983, -0.116738  ,  0.3984513 ,  0.3840214 ,  0.18401752,
#          0.47360197,  0.20721917,  0.05094939,  0.19133246,  0.47311482,
#          0.33519387,  0.17903201, -0.34427467,  0.12121147, -0.07001363],
#        dtype=float32),
#  array([-0.11161651,  0.3331197 ,  0.07853357,  0.02042216,  0.03591614,
#         -0.39810398,  0.12727578,  0.62757736, -0.24310757, -0.19153437,
#         -0.24626295, -0.41559348, -0.01284836,  0.12980162,  0.07107226,
#         -0.2460061 , -0.03169433, -0.3397015 ,  0.01453102, -0.61636895,
#          0.11489081,  0.13266572,  0.15241179, -0.15558457, -0.11038919,
#          0.07106221, -0.19706003, -0.1762674 , -0.28613076,  0.08444798,
#          0.36004236,  0.04886514,  0.14751032, -0.22543278, -0.18496701,
#          0.41540334, -0.01757026, -0.20031437, -0.13552006, -0.45722887,
#         -0.01682552, -0.30442864, -0.06859811,  0.1033179 ,  0.27740344,
#         -0.1774222 , -0.2477621 , -0.01872366,  0.16958816,  0.24215153,
#          0.12266849, -0.29204792, -0.10980809, -0.02922469, -0.18666482,
#          0.20446777,  0.13611075, -0.00325133, -0.37931514,  0.05709451,
#          0.11064852,  0.13669199, -0.11428303,  0.04048941, -0.34036002,
#          0.2575551 ,  0.1585994 ,  0.19762981, -0.41263983,  0.46131277,
#         -0.20998621,  0.18676531,  0.35411692, -0.0794359 ,  0.28476125,
#          0.17008604,  0.02269028, -0.06434257, -0.24719541,  0.19841126,
#         -0.0534388 , -0.09785568, -0.3222045 ,  0.42232847, -0.04752403,
#          0.01666337, -0.10926259,  0.3867474 ,  0.37328586,  0.18299595,
#          0.46011835,  0.20333946,  0.04818868,  0.17749248,  0.4615543 ,
#          0.3208515 ,  0.17706935, -0.33562693,  0.11462542, -0.06482084],
#        dtype=float32),
#  array([-0.10028411,  0.31130806,  0.07602069,  0.02754145,  0.04242056,
#         -0.37543887,  0.1168461 ,  0.59673667, -0.23397616, -0.18419188,
#         -0.2311992 , -0.39542007, -0.01131623,  0.13029033,  0.07150898,
#         -0.2369787 , -0.02765647, -0.32278055,  0.01402224, -0.5853335 ,
#          0.11027689,  0.1206639 ,  0.1485444 , -0.14853603, -0.09851836,
#          0.06485018, -0.18941036, -0.1637566 , -0.2723507 ,  0.08156674,
#          0.34392926,  0.04972941,  0.1373981 , -0.20748939, -0.17034908,
#          0.38774166, -0.01782668, -0.19192205, -0.12779094, -0.43665245,
#         -0.01884347, -0.2878969 , -0.06281247,  0.10011517,  0.2615023 ,
#         -0.16750751, -0.23508297, -0.02139707,  0.16238813,  0.22995989,
#          0.11715993, -0.27835652, -0.10700183, -0.02841682, -0.17783566,
#          0.19276838,  0.12603325, -0.00200362, -0.35678872,  0.06137529,
#          0.10014167,  0.12884732, -0.10515228,  0.03823547, -0.32939976,
#          0.24959072,  0.15486182,  0.18839006, -0.39380705,  0.43918696,
#         -0.20199141,  0.17604835,  0.33469036, -0.07541776,  0.27103037,
#          0.15161881,  0.02246565, -0.05484267, -0.23806353,  0.18761508,
#         -0.04928051, -0.08891077, -0.3059619 ,  0.40037477, -0.0442235 ,
#          0.0223596 , -0.10324103,  0.36517745,  0.3565405 ,  0.17099203,
#          0.43845308,  0.19028844,  0.04329044,  0.17273232,  0.43505436,
#          0.30754623,  0.16635707, -0.31813416,  0.10751083, -0.05932917],
#        dtype=float32),
#  array([-0.10368498,  0.3266984 ,  0.07779742,  0.02468281,  0.04370538,
#         -0.38972047,  0.12069265,  0.6157939 , -0.23665199, -0.19197474,
#         -0.23622747, -0.40421385, -0.01227653,  0.1323557 ,  0.07410942,
#         -0.24193323, -0.02838077, -0.33489102,  0.01181299, -0.602254  ,
#          0.11093275,  0.12336738,  0.1476947 , -0.15902583, -0.10699044,
#          0.06573197, -0.1976781 , -0.16540651, -0.2816214 ,  0.08238437,
#          0.3509287 ,  0.05035687,  0.14076768, -0.2155879 , -0.17532508,
#          0.39989904, -0.01973518, -0.19259147, -0.13601513, -0.44522315,
#         -0.01736076, -0.29593444, -0.06960343,  0.10564726,  0.26756966,
#         -0.17345129, -0.23898529, -0.02361272,  0.16269782,  0.23932658,
#          0.12100154, -0.28507134, -0.10853464, -0.0275214 , -0.1896056 ,
#          0.20198391,  0.1293313 , -0.00140391, -0.36990565,  0.06230464,
#          0.1061071 ,  0.13433805, -0.10920183,  0.04004537, -0.3374753 ,
#          0.25432268,  0.16020013,  0.19468601, -0.40227947,  0.44927105,
#         -0.20572849,  0.18339777,  0.3412884 , -0.07442098,  0.27981287,
#          0.16283403,  0.02231943, -0.0572322 , -0.24341236,  0.1922755 ,
#         -0.05413606, -0.08769449, -0.32124898,  0.41096458, -0.0475559 ,
#          0.019208  , -0.10692038,  0.37489614,  0.36898562,  0.17819773,
#          0.4500625 ,  0.198769  ,  0.04180216,  0.17516877,  0.4486198 ,
#          0.30893177,  0.16832255, -0.3282652 ,  0.11066874, -0.05869479],
#        dtype=float32),
#  array([-0.04997201,  0.15063302,  0.03797477,  0.01113435,  0.02019554,
#         -0.17636718,  0.05664671,  0.27894813, -0.10969495, -0.08478611,
#         -0.10977188, -0.18579492, -0.00698398,  0.06085658,  0.03422715,
#         -0.11085527, -0.01350274, -0.15517972,  0.00812801, -0.27431068,
#          0.0514999 ,  0.05927656,  0.06694324, -0.06876839, -0.04601919,
#          0.03086683, -0.08922623, -0.07378589, -0.1295878 ,  0.03404703,
#          0.15871379,  0.02301489,  0.06512506, -0.09959232, -0.08399708,
#          0.17973751, -0.00609322, -0.09453081, -0.05825871, -0.20108382,
#         -0.01050323, -0.13225113, -0.02895415,  0.0438997 ,  0.12315038,
#         -0.08215187, -0.1115028 , -0.0093619 ,  0.0760442 ,  0.10847712,
#          0.05451794, -0.12887363, -0.05040463, -0.01317688, -0.08192201,
#          0.09089039,  0.05996668, -0.00237414, -0.16791837,  0.02887214,
#          0.04981087,  0.06534299, -0.05189675,  0.01824701, -0.15352814,
#          0.11416383,  0.07304811,  0.08885063, -0.18250576,  0.2072447 ,
#         -0.09138908,  0.08367987,  0.15626885, -0.0345696 ,  0.12523907,
#          0.07250533,  0.01414725, -0.03120103, -0.10917868,  0.08538906,
#         -0.02338703, -0.04038165, -0.14391896,  0.18506686, -0.02304127,
#          0.01109644, -0.04724809,  0.17314754,  0.16835131,  0.07848299,
#          0.20470046,  0.0914893 ,  0.02283186,  0.08162767,  0.20512111,
#          0.14572422,  0.07816733, -0.15224521,  0.04721384, -0.02780914],
#        dtype=float32),
#  array([-0.08453505,  0.27013022,  0.0671315 ,  0.0304792 ,  0.05169623,
#         -0.3133167 ,  0.1024765 ,  0.5127186 , -0.20070381, -0.1583453 ,
#         -0.1939825 , -0.33302256, -0.01259721,  0.10979557,  0.0557391 ,
#         -0.2080007 , -0.02820514, -0.27080348,  0.0110548 , -0.48920092,
#          0.08813938,  0.10357044,  0.12987609, -0.12891616, -0.08203478,
#          0.04481429, -0.1679654 , -0.14661585, -0.24260727,  0.0631667 ,
#          0.2785493 ,  0.03335092,  0.12428903, -0.17962001, -0.15428472,
#          0.32471365, -0.00817941, -0.16505276, -0.10059615, -0.36897394,
#         -0.01170446, -0.24003415, -0.05728965,  0.0803313 ,  0.2238475 ,
#         -0.14848213, -0.20306605, -0.00514373,  0.14094557,  0.20304061,
#          0.10595328, -0.2244246 , -0.08935291, -0.01987693, -0.14493798,
#          0.16266352,  0.11924268,  0.00119724, -0.30067044,  0.05532308,
#          0.08345447,  0.11060358, -0.09151433,  0.02141216, -0.27633983,
#          0.20332041,  0.12075775,  0.1639368 , -0.33711624,  0.37383282,
#         -0.17028522,  0.1595589 ,  0.29228303, -0.06761985,  0.22706482,
#          0.12026699,  0.02382463, -0.04505385, -0.20864871,  0.14858437,
#         -0.04177687, -0.08182342, -0.26474422,  0.33480853, -0.04657212,
#          0.02208529, -0.08868232,  0.31548747,  0.30659306,  0.1517558 ,
#          0.37973693,  0.17277469,  0.04371617,  0.15977226,  0.38704172,
#          0.26520267,  0.1330591 , -0.26889148,  0.09187869, -0.05307228],
#        dtype=float32),
#  array([-0.12883763,  0.40309256,  0.09427082,  0.04021279,  0.06273618,
#         -0.47102025,  0.15086067,  0.752832  , -0.28882018, -0.2369508 ,
#         -0.28578997, -0.5014275 , -0.00639178,  0.16005859,  0.08711684,
#         -0.31120232, -0.03781413, -0.41771013,  0.01634248, -0.73212385,
#          0.14585494,  0.15353206,  0.19085109, -0.18875575, -0.11348195,
#          0.07594105, -0.24285254, -0.21422033, -0.3582582 ,  0.08438682,
#          0.4347748 ,  0.05227296,  0.18892916, -0.2622965 , -0.21598151,
#          0.484993  , -0.01982419, -0.24681859, -0.15798725, -0.550868  ,
#         -0.02839113, -0.3584643 , -0.08896144,  0.11559279,  0.324188  ,
#         -0.21939075, -0.29622963, -0.02098044,  0.20428094,  0.3035547 ,
#          0.14600685, -0.33579913, -0.13459513, -0.02422172, -0.21399462,
#          0.24325195,  0.16677488,  0.00101646, -0.45791116,  0.08318106,
#          0.12381501,  0.15650858, -0.13718347,  0.03476169, -0.41958418,
#          0.3117884 ,  0.18684514,  0.24099927, -0.5007879 ,  0.56011236,
#         -0.2518255 ,  0.22889456,  0.43835256, -0.09324763,  0.33324668,
#          0.17658724,  0.02911057, -0.07300013, -0.30234763,  0.23506236,
#         -0.0675742 , -0.11680628, -0.38868076,  0.50125873, -0.06351561,
#          0.02925714, -0.1332399 ,  0.46676835,  0.44964418,  0.21922113,
#          0.55160767,  0.24613039,  0.06284385,  0.22438565,  0.5645876 ,
#          0.40103978,  0.20124732, -0.40209278,  0.13151829, -0.07778543],
#        dtype=float32),
#  array([-0.10704088,  0.32542914,  0.08119857,  0.02477985,  0.0376115 ,
#         -0.39126545,  0.12281934,  0.6123837 , -0.23912914, -0.1891462 ,
#         -0.24079351, -0.4096137 , -0.01261992,  0.12714806,  0.07373595,
#         -0.24438469, -0.02870565, -0.33269387,  0.01593974, -0.6046799 ,
#          0.11586511,  0.12299602,  0.14320502, -0.15493765, -0.1048952 ,
#          0.07094093, -0.19699189, -0.1709302 , -0.2795667 ,  0.08192299,
#          0.3519842 ,  0.05287444,  0.1390463 , -0.21542545, -0.17817268,
#          0.40229383, -0.01507849, -0.19457674, -0.13285433, -0.44674635,
#         -0.01493671, -0.2949121 , -0.06664821,  0.10382333,  0.2712616 ,
#         -0.17631724, -0.24397306, -0.02103613,  0.16607735,  0.23639634,
#          0.12064912, -0.28440303, -0.10823505, -0.03299174, -0.17953178,
#          0.20032299,  0.12895542, -0.00529685, -0.3710088 ,  0.06299431,
#          0.10209502,  0.13259871, -0.10941766,  0.03970816, -0.33550647,
#          0.25428012,  0.15450466,  0.19010167, -0.39798978,  0.44758987,
#         -0.20587459,  0.17997035,  0.34108973, -0.0773861 ,  0.27647728,
#          0.16135313,  0.02575019, -0.0652763 , -0.24073295,  0.19349778,
#         -0.05305346, -0.08639198, -0.31487456,  0.4121956 , -0.0469861 ,
#          0.02448961, -0.10345352,  0.37723604,  0.36472565,  0.17642927,
#          0.4497506 ,  0.19280162,  0.04626652,  0.17078467,  0.4484982 ,
#          0.31554872,  0.17019407, -0.32790875,  0.11516013, -0.06052111],
#        dtype=float32),
#  array([-0.10930315,  0.34036246,  0.08443471,  0.03018262,  0.04453452,
#         -0.40499783,  0.1263486 ,  0.6425467 , -0.25080487, -0.19738093,
#         -0.25091398, -0.42438823, -0.00731323,  0.13828458,  0.07544589,
#         -0.25801942, -0.02879729, -0.3498194 ,  0.01489704, -0.62750447,
#          0.1193063 ,  0.13363385,  0.15917726, -0.15987214, -0.10599104,
#          0.06994101, -0.2058132 , -0.18189782, -0.2990363 ,  0.08638954,
#          0.36725366,  0.05200521,  0.15465985, -0.22653376, -0.18602043,
#          0.41509572, -0.01827248, -0.21216853, -0.137633  , -0.47032404,
#         -0.01504783, -0.31065443, -0.06969859,  0.10420389,  0.28021052,
#         -0.182739  , -0.25401732, -0.0242962 ,  0.17520049,  0.25369358,
#          0.12192957, -0.29550284, -0.11164997, -0.02867765, -0.18977325,
#          0.21081224,  0.1361964 , -0.00302365, -0.3861122 ,  0.06562084,
#          0.11111771,  0.13935934, -0.11849215,  0.04157324, -0.35635647,
#          0.2685361 ,  0.16456194,  0.2041996 , -0.42717132,  0.47766864,
#         -0.2138675 ,  0.19114102,  0.36850324, -0.08408586,  0.28966796,
#          0.16340442,  0.02388878, -0.06233652, -0.25463915,  0.20291053,
#         -0.05593777, -0.09877969, -0.33285406,  0.4297815 , -0.05108704,
#          0.02334036, -0.11403526,  0.39807674,  0.38382608,  0.1866473 ,
#          0.47893828,  0.20807418,  0.04542463,  0.18834169,  0.47310418,
#          0.3354398 ,  0.17717737, -0.3451823 ,  0.11540321, -0.06246486],
#        dtype=float32),
#  array([-0.09472912,  0.30513048,  0.07453107,  0.03179866,  0.04953372,
#         -0.35647058,  0.11423767,  0.57171696, -0.22291851, -0.17641969,
#         -0.22106147, -0.37614828, -0.00725055,  0.12156712,  0.06625682,
#         -0.23348561, -0.03103358, -0.3120873 ,  0.01194024, -0.5565125 ,
#          0.10322166,  0.11598057,  0.14056033, -0.14286225, -0.08667603,
#          0.05655705, -0.18489353, -0.16501454, -0.2680362 ,  0.07678033,
#          0.32274395,  0.04179557,  0.13738364, -0.20078804, -0.16816455,
#          0.3684095 , -0.01565503, -0.18841654, -0.11535773, -0.41989526,
#         -0.01614416, -0.27208984, -0.06485154,  0.09320576,  0.24625736,
#         -0.16352282, -0.225309  , -0.01797606,  0.15429202,  0.2269085 ,
#          0.11444553, -0.25502965, -0.10251608, -0.02259123, -0.1665632 ,
#          0.18537502,  0.1283226 ,  0.00235278, -0.34481642,  0.05945081,
#          0.09604584,  0.12075824, -0.1050649 ,  0.03070508, -0.31508875,
#          0.23299414,  0.14480466,  0.18170632, -0.38311607,  0.4244427 ,
#         -0.19024225,  0.17729507,  0.33161756, -0.07213104,  0.25341752,
#          0.13604961,  0.02309462, -0.05186567, -0.22793472,  0.17630069,
#         -0.05056005, -0.08753415, -0.29192623,  0.37632987, -0.04788974,
#          0.0208437 , -0.1012921 ,  0.35283896,  0.3409609 ,  0.1654444 ,
#          0.4245929 ,  0.19249119,  0.04511832,  0.16964921,  0.4250412 ,
#          0.30195537,  0.1549403 , -0.30432847,  0.10064442, -0.0568722 ],
#        dtype=float32),
#  array([-0.08089703,  0.24836607,  0.06335389,  0.01909135,  0.03235188,
#         -0.29917744,  0.09136826,  0.47242185, -0.17805062, -0.14808868,
#         -0.184097  , -0.31295332, -0.00931608,  0.10041397,  0.05695002,
#         -0.18983519, -0.02239211, -0.2602245 ,  0.01048132, -0.46553004,
#          0.08881363,  0.09560436,  0.11406827, -0.11657747, -0.07966454,
#          0.04943787, -0.15051642, -0.1302469 , -0.2212003 ,  0.0662688 ,
#          0.2696015 ,  0.04376509,  0.10932362, -0.16626658, -0.13781498,
#          0.3109829 , -0.01275772, -0.15571761, -0.10259404, -0.34560952,
#         -0.014005  , -0.22505562, -0.0535938 ,  0.07834721,  0.20640123,
#         -0.13547787, -0.18371846, -0.01718674,  0.12880357,  0.18097419,
#          0.09321769, -0.2174484 , -0.08252982, -0.02249341, -0.14084102,
#          0.15754454,  0.09996143, -0.00100136, -0.28177235,  0.04795448,
#          0.08053353,  0.10547519, -0.08426417,  0.02747904, -0.26143026,
#          0.19601868,  0.12314302,  0.14538057, -0.30865684,  0.3462893 ,
#         -0.1622197 ,  0.14394934,  0.26434502, -0.05914623,  0.21679397,
#          0.12107424,  0.01969905, -0.05218076, -0.19044791,  0.15052697,
#         -0.03644004, -0.06703847, -0.24392991,  0.31809875, -0.0348993 ,
#          0.01923362, -0.08419207,  0.28909048,  0.28325835,  0.13962057,
#          0.34894764,  0.15289085,  0.03602116,  0.13275737,  0.3470019 ,
#          0.23948129,  0.1346667 , -0.2512084 ,  0.08378913, -0.04979517],
#        dtype=float32),
#  array([-0.04856692,  0.13786587,  0.03581466,  0.01465916,  0.01151039,
#         -0.15989304,  0.04626615,  0.2531921 , -0.09623916, -0.0803068 ,
#         -0.10072042, -0.15707406, -0.00596689,  0.05431696,  0.03756526,
#         -0.1032915 , -0.01759131, -0.13612121,  0.00390047, -0.24075037,
#          0.05091935,  0.04894417,  0.05358451, -0.0604023 , -0.03982743,
#          0.03224918, -0.08120692, -0.06452353, -0.10988492,  0.03132813,
#          0.13345191,  0.01489597,  0.05774301, -0.08377238, -0.07343984,
#          0.15470396, -0.0025601 , -0.07268962, -0.05710675, -0.18090326,
#         -0.00597456, -0.11400981, -0.02795626,  0.04122414,  0.10641292,
#         -0.07458024, -0.09708476, -0.00143379,  0.07002422,  0.0965287 ,
#          0.04164679, -0.11517977, -0.04096268, -0.01521978, -0.07502963,
#          0.07720935,  0.05589581, -0.00095668, -0.1448732 ,  0.01783487,
#          0.04757295,  0.06192554, -0.04516731,  0.01221903, -0.13019162,
#          0.10304036,  0.06522086,  0.07674465, -0.15724859,  0.19003078,
#         -0.08531424,  0.07939687,  0.13970092, -0.03566337,  0.11705218,
#          0.07092055,  0.01453987, -0.0193774 , -0.10032108,  0.07700442,
#         -0.02561364, -0.03053029, -0.13285828,  0.16654013, -0.01383355,
#          0.00390147, -0.04724736,  0.14425045,  0.1506075 ,  0.07313636,
#          0.18002339,  0.08523827,  0.01539999,  0.06932628,  0.18149668,
#          0.12713778,  0.06325392, -0.13029492,  0.05077253, -0.01936957],
#        dtype=float32),
#  array([-0.08659054,  0.2599732 ,  0.06490714,  0.02302877,  0.03351689,
#         -0.30710292,  0.09542748,  0.4882153 , -0.18990453, -0.14864221,
#         -0.18701227, -0.32058403, -0.0064798 ,  0.10375188,  0.05773076,
#         -0.1966934 , -0.02487395, -0.26888692,  0.01063174, -0.47607553,
#          0.09158716,  0.09704807,  0.12231498, -0.12066447, -0.07907577,
#          0.05149609, -0.15831107, -0.13968939, -0.22398883,  0.06654095,
#          0.27851877,  0.03560277,  0.11768406, -0.16987051, -0.1415143 ,
#          0.31487063, -0.01363473, -0.15536503, -0.10328706, -0.3540834 ,
#         -0.01432402, -0.2374801 , -0.05786899,  0.07714395,  0.21476631,
#         -0.13808472, -0.19264145, -0.01911784,  0.13181879,  0.18935893,
#          0.09628135, -0.22403397, -0.08973318, -0.02081039, -0.14424661,
#          0.15630843,  0.10297986, -0.00444251, -0.29201028,  0.04925634,
#          0.08017897,  0.1051011 , -0.08908785,  0.02973683, -0.26691267,
#          0.20740032,  0.12855916,  0.15253322, -0.318358  ,  0.36373946,
#         -0.16359746,  0.14452998,  0.27468243, -0.06398251,  0.21533561,
#          0.11844719,  0.02031582, -0.05008526, -0.19243121,  0.15682226,
#         -0.04342837, -0.07443626, -0.2515943 ,  0.32843798, -0.03487467,
#          0.01662119, -0.08877021,  0.29998675,  0.28766915,  0.1378097 ,
#          0.3566592 ,  0.1582249 ,  0.0386728 ,  0.14025387,  0.35254896,
#          0.25061688,  0.13596033, -0.25659892,  0.08533332, -0.04481054],
#        dtype=float32),
#  array([-0.08839366,  0.2888391 ,  0.0700565 ,  0.02021449,  0.0367404 ,
#         -0.3474258 ,  0.11911675,  0.55791175, -0.21413186, -0.1791378 ,
#         -0.21413343, -0.36290205, -0.00978286,  0.1169863 ,  0.07352555,
#         -0.21647081, -0.02266041, -0.30271447,  0.01825952, -0.53880376,
#          0.1093213 ,  0.11692324,  0.13132146, -0.1334243 , -0.10057024,
#          0.0672684 , -0.17995384, -0.15482648, -0.25210294,  0.08085934,
#          0.31531653,  0.04414491,  0.12493402, -0.19502898, -0.15664822,
#          0.36119908, -0.01766851, -0.1785378 , -0.12243859, -0.4019834 ,
#         -0.01446335, -0.2683591 , -0.06425242,  0.08651075,  0.24693644,
#         -0.16090575, -0.21840818, -0.02205987,  0.15207227,  0.20742655,
#          0.10845692, -0.25666732, -0.09779142, -0.02850236, -0.15709122,
#          0.17532024,  0.1157397 , -0.00587221, -0.33637097,  0.0633481 ,
#          0.09495391,  0.11941344, -0.09526995,  0.02886557, -0.30412847,
#          0.22330894,  0.14338773,  0.16438787, -0.35935992,  0.39357612,
#         -0.1911141 ,  0.16416758,  0.30291608, -0.06794457,  0.25073785,
#          0.13980274,  0.02772254, -0.04979232, -0.22818556,  0.17478558,
#         -0.05052675, -0.07420642, -0.27800483,  0.3814224 , -0.04622239,
#          0.02561211, -0.0983232 ,  0.34119546,  0.32666624,  0.1555127 ,
#          0.40309012,  0.17475486,  0.03833281,  0.14953415,  0.4011658 ,
#          0.2804308 ,  0.14360648, -0.29789892,  0.10307884, -0.05211305],
#        dtype=float32),
#  array([-0.07541575,  0.22567892,  0.05400701,  0.01786722,  0.02648649,
#         -0.26841548,  0.08163223,  0.42217207, -0.1669901 , -0.12902689,
#         -0.16589011, -0.28063005, -0.00508089,  0.08948398,  0.05063269,
#         -0.16996835, -0.02110725, -0.23157196,  0.00898642, -0.41661352,
#          0.07865171,  0.0877296 ,  0.10394892, -0.10552739, -0.07348441,
#          0.04890279, -0.13583119, -0.11703626, -0.19637139,  0.05508128,
#          0.24206302,  0.03433028,  0.09732835, -0.14987442, -0.1262155 ,
#          0.27452978, -0.01344495, -0.13201624, -0.08714085, -0.31091666,
#         -0.00821789, -0.20311408, -0.05001264,  0.07119037,  0.18639135,
#         -0.11926489, -0.16548686, -0.01606698,  0.11581767,  0.16676533,
#          0.07994299, -0.1978874 , -0.07324008, -0.02273334, -0.12409301,
#          0.13888851,  0.08896087, -0.00133618, -0.25676808,  0.04405081,
#          0.07324932,  0.09727833, -0.07340638,  0.02705074, -0.2298073 ,
#          0.17607827,  0.10763995,  0.1346383 , -0.27598712,  0.3104456 ,
#         -0.14416416,  0.12736264,  0.24180399, -0.05189056,  0.19430013,
#          0.11292085,  0.01697084, -0.04528311, -0.16799696,  0.13351054,
#         -0.03428598, -0.0650261 , -0.21722317,  0.28787562, -0.03187571,
#          0.01468653, -0.0752569 ,  0.25605473,  0.25495863,  0.12354122,
#          0.31237656,  0.13616197,  0.0308582 ,  0.12311205,  0.30984095,
#          0.21893014,  0.11429605, -0.22735837,  0.07548628, -0.04441359],
#        dtype=float32),
#  array([-1.28363654e-01,  4.02609229e-01,  9.45096985e-02,  2.51851678e-02,
#          5.31437770e-02, -4.84212995e-01,  1.54973388e-01,  7.54833579e-01,
#         -3.04785490e-01, -2.29382634e-01, -2.95539737e-01, -5.08932173e-01,
#         -1.71581022e-02,  1.61734521e-01,  9.57369804e-02, -2.98663199e-01,
#         -3.39358822e-02, -4.14128155e-01,  1.19182253e-02, -7.51097202e-01,
#          1.33541480e-01,  1.57830894e-01,  1.81625411e-01, -1.91753656e-01,
#         -1.36208624e-01,  9.22103450e-02, -2.37923592e-01, -2.14904964e-01,
#         -3.48964334e-01,  1.00242659e-01,  4.44990933e-01,  6.26735911e-02,
#          1.84481502e-01, -2.68665045e-01, -2.16250479e-01,  5.03340840e-01,
#         -1.93120893e-02, -2.41968349e-01, -1.65247545e-01, -5.55458784e-01,
#         -1.84319746e-02, -3.75401199e-01, -8.68259743e-02,  1.30068406e-01,
#          3.32098097e-01, -2.11381346e-01, -3.02229971e-01, -2.53040735e-02,
#          2.07378104e-01,  2.93487191e-01,  1.50132567e-01, -3.58721167e-01,
#         -1.31940439e-01, -3.34518813e-02, -2.28756368e-01,  2.55434662e-01,
#          1.63725168e-01, -4.77404392e-05, -4.64216352e-01,  7.61617720e-02,
#          1.26326978e-01,  1.71639115e-01, -1.39162615e-01,  5.31882495e-02,
#         -4.13645357e-01,  3.21377277e-01,  1.97429359e-01,  2.32407540e-01,
#         -4.92888391e-01,  5.61687708e-01, -2.58258045e-01,  2.25344121e-01,
#          4.23851073e-01, -9.58720669e-02,  3.48017931e-01,  1.98838279e-01,
#          3.38088274e-02, -7.48094320e-02, -2.94552058e-01,  2.40882918e-01,
#         -6.67251572e-02, -1.11483544e-01, -3.97363007e-01,  5.06782949e-01,
#         -6.50992393e-02,  2.62243450e-02, -1.31617129e-01,  4.75581765e-01,
#          4.60366845e-01,  2.24258438e-01,  5.51685929e-01,  2.50456661e-01,
#          5.19609004e-02,  2.18747482e-01,  5.51325560e-01,  3.90163243e-01,
#          2.15378866e-01, -4.10713553e-01,  1.47155806e-01, -7.66432732e-02],
#        dtype=float32),
#  array([-0.07918822,  0.2507398 ,  0.0622873 ,  0.02006553,  0.03156097,
#         -0.29734522,  0.09373575,  0.47061276, -0.18235645, -0.14569238,
#         -0.18355936, -0.30997664, -0.00529908,  0.09922083,  0.05550799,
#         -0.1923567 , -0.02332292, -0.25464362,  0.00796974, -0.45778856,
#          0.08981511,  0.09301832,  0.11634145, -0.1178918 , -0.07636281,
#          0.05200531, -0.15087715, -0.1324139 , -0.21497737,  0.06621929,
#          0.2714242 ,  0.03575138,  0.11120971, -0.16355038, -0.13657472,
#          0.30305496, -0.01415912, -0.15423091, -0.10022615, -0.34295854,
#         -0.01732366, -0.22405149, -0.05256879,  0.07564513,  0.20305192,
#         -0.13104731, -0.1828494 , -0.01764205,  0.12733066,  0.1836019 ,
#          0.09424645, -0.21219344, -0.08559199, -0.02175653, -0.13763909,
#          0.15215825,  0.10108698, -0.00110963, -0.28555655,  0.04920702,
#          0.07748064,  0.10196575, -0.08787582,  0.03027264, -0.25991783,
#          0.19638504,  0.12216002,  0.14983821, -0.30808395,  0.3500364 ,
#         -0.15702307,  0.14028545,  0.26730156, -0.06017885,  0.21073775,
#          0.11688814,  0.01900986, -0.04572865, -0.18481936,  0.15545844,
#         -0.04223664, -0.06992444, -0.24216425,  0.31156665, -0.03529578,
#          0.01625232, -0.08346974,  0.28878337,  0.28389382,  0.1378402 ,
#          0.34349695,  0.15244143,  0.03722316,  0.13619567,  0.3433574 ,
#          0.24083465,  0.128366  , -0.25141335,  0.0874499 , -0.04658287],
#        dtype=float32),
#  array([-5.6633711e-02,  1.7105174e-01,  3.8009305e-02,  1.5617694e-02,
#          1.3562482e-02, -2.0581742e-01,  5.9720512e-02,  3.2376227e-01,
#         -1.2708141e-01, -1.0112494e-01, -1.3590737e-01, -2.1643598e-01,
#         -3.6570772e-03,  6.8492152e-02,  3.0995481e-02, -1.3435794e-01,
#         -1.8841738e-02, -1.8499754e-01,  8.8339774e-03, -3.1982967e-01,
#          5.5538069e-02,  6.8336129e-02,  8.3422400e-02, -8.3354644e-02,
#         -5.3583194e-02,  3.8027175e-02, -1.0805786e-01, -9.1195524e-02,
#         -1.4529754e-01,  4.5270424e-02,  1.9134180e-01,  3.2021351e-02,
#          8.0633126e-02, -1.2310308e-01, -9.8127730e-02,  2.1382749e-01,
#         -1.0826170e-02, -1.0756117e-01, -5.9695955e-02, -2.4126339e-01,
#         -2.2146776e-03, -1.6159846e-01, -4.2760685e-02,  5.7908434e-02,
#          1.3941456e-01, -9.8207086e-02, -1.3277994e-01, -1.6057163e-02,
#          9.4899483e-02,  1.2797263e-01,  6.3684262e-02, -1.4761257e-01,
#         -5.6133986e-02, -1.9982880e-02, -9.6454799e-02,  1.1284983e-01,
#          6.9063731e-02, -1.2475516e-04, -1.9501989e-01,  3.4806825e-02,
#          6.1625551e-02,  7.4474081e-02, -5.5559140e-02,  2.0195460e-02,
#         -1.8615663e-01,  1.3908045e-01,  8.0250584e-02,  9.9417932e-02,
#         -2.1235168e-01,  2.4808244e-01, -1.1571583e-01,  9.7674400e-02,
#          1.9259025e-01, -3.6008760e-02,  1.5695415e-01,  8.9815855e-02,
#          1.6933708e-02, -3.2053098e-02, -1.3031314e-01,  1.0440483e-01,
#         -2.4325827e-02, -4.6447318e-02, -1.6366313e-01,  2.2169401e-01,
#         -2.7226642e-02,  1.2911167e-02, -5.6431543e-02,  1.9879873e-01,
#          2.0040376e-01,  9.3920469e-02,  2.3579066e-01,  1.0751932e-01,
#          2.4215376e-02,  8.8335633e-02,  2.4519956e-01,  1.6728389e-01,
#          9.2625119e-02, -1.7856032e-01,  5.6444395e-02, -3.5646837e-02],
#        dtype=float32),
#  array([-0.08139574,  0.2509561 ,  0.06037023,  0.01993317,  0.03000063,
#         -0.30943432,  0.09108994,  0.4858414 , -0.18848406, -0.1491686 ,
#         -0.19101691, -0.31791523, -0.0139467 ,  0.09880078,  0.05694697,
#         -0.1904397 , -0.01686575, -0.27035415,  0.0127568 , -0.47595945,
#          0.09119579,  0.09775431,  0.11560223, -0.12011442, -0.08244877,
#          0.05868651, -0.15323201, -0.13238984, -0.21887209,  0.06505921,
#          0.27681437,  0.03713332,  0.1126161 , -0.16556276, -0.1361748 ,
#          0.31170514, -0.01068869, -0.15457699, -0.10583666, -0.34126714,
#         -0.01260167, -0.22723536, -0.05227727,  0.07728557,  0.21119195,
#         -0.13812481, -0.19607018, -0.01817114,  0.12875704,  0.18477386,
#          0.09277127, -0.22687168, -0.08624474, -0.02043761, -0.13924687,
#          0.15929922,  0.1002197 , -0.00404404, -0.29035237,  0.05179013,
#          0.08256981,  0.10552132, -0.08820791,  0.03420316, -0.26264983,
#          0.19755904,  0.11975554,  0.15321045, -0.31259912,  0.35144666,
#         -0.16543126,  0.14536826,  0.26996282, -0.05913837,  0.21855031,
#          0.12369474,  0.02107948, -0.05045478, -0.19630933,  0.15050162,
#         -0.0457516 , -0.06840646, -0.2471652 ,  0.32342446, -0.036614  ,
#          0.02171389, -0.08428416,  0.29959485,  0.28809524,  0.13610199,
#          0.35467708,  0.15673387,  0.03333271,  0.13898341,  0.35334924,
#          0.2508408 ,  0.13695437, -0.25978208,  0.08700215, -0.04807095],
#        dtype=float32),
#  array([-0.0789886 ,  0.23840807,  0.05793672,  0.01652552,  0.0274768 ,
#         -0.28634128,  0.09293648,  0.4497932 , -0.17587183, -0.14016828,
#         -0.17775519, -0.29392633, -0.01137214,  0.09540991,  0.05297041,
#         -0.17859127, -0.02385217, -0.25210017,  0.00644979, -0.44152418,
#          0.0821927 ,  0.09277908,  0.1116666 , -0.10960129, -0.07643085,
#          0.0502757 , -0.14488731, -0.12480757, -0.20941831,  0.06225197,
#          0.2617738 ,  0.03262475,  0.10194763, -0.15847386, -0.13125262,
#          0.294222  , -0.0140268 , -0.14454937, -0.09696892, -0.33089128,
#         -0.01144619, -0.2137307 , -0.0466556 ,  0.0765807 ,  0.19849283,
#         -0.12612163, -0.18080167, -0.01710112,  0.12203563,  0.17421985,
#          0.09094292, -0.20448764, -0.0771543 , -0.02515031, -0.13405947,
#          0.15105861,  0.09043061, -0.0028485 , -0.271543  ,  0.04309069,
#          0.07280072,  0.09736414, -0.0774185 ,  0.03123465, -0.2467985 ,
#          0.18589719,  0.11117063,  0.13848715, -0.29191858,  0.33146673,
#         -0.150903  ,  0.13829191,  0.2511939 , -0.05726528,  0.20447133,
#          0.11389937,  0.01549246, -0.04430471, -0.17306446,  0.14041586,
#         -0.0385201 , -0.06823225, -0.2284019 ,  0.30545777, -0.03598391,
#          0.02133276, -0.07385134,  0.27808186,  0.2707993 ,  0.13009363,
#          0.3264692 ,  0.1474581 ,  0.03757263,  0.12672205,  0.33404443,
#          0.23392619,  0.12154195, -0.24158455,  0.08217316, -0.04965362],
#        dtype=float32),
#  array([-0.10638951,  0.3261182 ,  0.0784642 ,  0.0244666 ,  0.03981257,
#         -0.3881833 ,  0.12029086,  0.6206629 , -0.23717025, -0.186331  ,
#         -0.23981626, -0.4060847 , -0.01036028,  0.13354799,  0.06940131,
#         -0.2452453 , -0.02402239, -0.33875957,  0.01062607, -0.60628426,
#          0.11347146,  0.12237011,  0.15309417, -0.15688986, -0.10817765,
#          0.064203  , -0.19611126, -0.16939364, -0.28275317,  0.08868586,
#          0.35440427,  0.05286032,  0.13825616, -0.21433355, -0.18341391,
#          0.4071154 , -0.02295667, -0.19749922, -0.1307877 , -0.4503237 ,
#         -0.01435793, -0.29134712, -0.07100848,  0.10251824,  0.27098697,
#         -0.17512004, -0.24079086, -0.02226403,  0.166094  ,  0.23882903,
#          0.1203469 , -0.2880275 , -0.10965829, -0.0304346 , -0.18625198,
#          0.20350258,  0.13417321, -0.00579443, -0.3740748 ,  0.05795834,
#          0.10668186,  0.13106209, -0.1118087 ,  0.03461822, -0.34331575,
#          0.25942528,  0.15954034,  0.18619305, -0.40620196,  0.45330554,
#         -0.207133  ,  0.18138608,  0.344681  , -0.07871199,  0.27721757,
#          0.15904588,  0.02805726, -0.06566983, -0.24983358,  0.19539548,
#         -0.04913427, -0.08956508, -0.31924364,  0.41712758, -0.04646126,
#          0.02116532, -0.11074492,  0.38142124,  0.36816823,  0.17745821,
#          0.45460653,  0.19840227,  0.04104485,  0.1757026 ,  0.44887802,
#          0.31648004,  0.17302315, -0.33115757,  0.11668288, -0.06494532],
#        dtype=float32),
#  array([-8.71012583e-02,  2.68473148e-01,  6.42834157e-02,  1.61831230e-02,
#          3.26105393e-02, -3.22291523e-01,  1.05001800e-01,  5.10350406e-01,
#         -1.99204564e-01, -1.52970254e-01, -1.98145419e-01, -3.35152090e-01,
#         -1.33925602e-02,  1.01544268e-01,  6.50662407e-02, -2.01794103e-01,
#         -2.34022103e-02, -2.79863030e-01,  9.90626961e-03, -5.04458487e-01,
#          9.15321335e-02,  1.08218096e-01,  1.23275049e-01, -1.27795711e-01,
#         -9.00854394e-02,  5.98198585e-02, -1.59083679e-01, -1.40387729e-01,
#         -2.31578559e-01,  6.53441921e-02,  2.96523005e-01,  4.90042157e-02,
#          1.21489830e-01, -1.73047841e-01, -1.44475624e-01,  3.37317199e-01,
#         -1.36010405e-02, -1.63311571e-01, -1.07333519e-01, -3.75003695e-01,
#         -8.43183417e-03, -2.45281085e-01, -5.45596033e-02,  8.67939815e-02,
#          2.23018304e-01, -1.44923806e-01, -2.01886952e-01, -1.54444976e-02,
#          1.42157927e-01,  1.91720918e-01,  9.98727828e-02, -2.37233073e-01,
#         -8.99002329e-02, -2.53430083e-02, -1.48159713e-01,  1.68346584e-01,
#          1.06950194e-01,  2.54926301e-04, -3.05914760e-01,  4.80051935e-02,
#          8.51944461e-02,  1.15764447e-01, -9.01809782e-02,  3.07793599e-02,
#         -2.74172723e-01,  2.19018772e-01,  1.34080634e-01,  1.53510481e-01,
#         -3.32423508e-01,  3.71481836e-01, -1.73612699e-01,  1.49278060e-01,
#          2.84747899e-01, -6.79285154e-02,  2.34804600e-01,  1.24858983e-01,
#          1.97313260e-02, -5.23206517e-02, -1.97109178e-01,  1.62878200e-01,
#         -4.22935113e-02, -7.17434883e-02, -2.63040960e-01,  3.46108586e-01,
#         -4.16071191e-02,  2.16194466e-02, -8.68683383e-02,  3.10444921e-01,
#          3.06577086e-01,  1.51152790e-01,  3.69989634e-01,  1.66240439e-01,
#          3.54736298e-02,  1.41471952e-01,  3.72311443e-01,  2.60108173e-01,
#          1.41422197e-01, -2.72037357e-01,  9.38032568e-02, -5.16108349e-02],
#        dtype=float32),
#  array([-0.06108816,  0.1871507 ,  0.04501233,  0.01216262,  0.02498182,
#         -0.22713086,  0.07019623,  0.35531777, -0.1402168 , -0.11050954,
#         -0.14240313, -0.23758304, -0.0099364 ,  0.07472838,  0.04267635,
#         -0.14128621, -0.01583101, -0.19627608,  0.01084638, -0.35561687,
#          0.06538199,  0.07153445,  0.08468871, -0.08950939, -0.06219075,
#          0.04073026, -0.1140293 , -0.09738255, -0.16575997,  0.04433624,
#          0.20574144,  0.03384903,  0.08286218, -0.12471364, -0.10324284,
#          0.23438096, -0.01058965, -0.11368793, -0.0771337 , -0.25951234,
#         -0.00636672, -0.17211808, -0.03976191,  0.06049417,  0.15843274,
#         -0.10101505, -0.14137758, -0.01349366,  0.09628976,  0.14006433,
#          0.06749676, -0.16449866, -0.06233635, -0.01829629, -0.10618515,
#          0.11786107,  0.07627667, -0.0013691 , -0.21360949,  0.03600148,
#          0.05947349,  0.07950111, -0.06479263,  0.02358078, -0.19770612,
#          0.14877486,  0.09181822,  0.11131484, -0.23306428,  0.2610145 ,
#         -0.11980396,  0.10567816,  0.20100488, -0.046756  ,  0.16283168,
#          0.09455186,  0.01692723, -0.03751084, -0.14172576,  0.11421545,
#         -0.02969861, -0.05316069, -0.18512912,  0.24341266, -0.02608772,
#          0.01363094, -0.06449748,  0.22138818,  0.21521081,  0.10527762,
#          0.2609684 ,  0.11499359,  0.02741119,  0.10169394,  0.263419  ,
#          0.18132465,  0.10072959, -0.18966793,  0.06694264, -0.03668631],
#        dtype=float32),
#  array([-0.07939764,  0.23133661,  0.05559142,  0.01922644,  0.02675052,
#         -0.28761217,  0.08547706,  0.44880906, -0.17846487, -0.13704987,
#         -0.17900185, -0.29671153, -0.01522659,  0.09274793,  0.04821506,
#         -0.1803742 , -0.02264178, -0.24371795,  0.01490015, -0.44250882,
#          0.08451864,  0.08826896,  0.10808959, -0.10679439, -0.08384869,
#          0.05288355, -0.14647613, -0.12312397, -0.20253338,  0.05494815,
#          0.26021826,  0.04350002,  0.10518486, -0.15645732, -0.13023268,
#          0.29332656, -0.0099215 , -0.14156897, -0.0953036 , -0.3297617 ,
#         -0.00975054, -0.21350344, -0.05481223,  0.08277351,  0.1990275 ,
#         -0.12776773, -0.17543817, -0.01716574,  0.12204069,  0.17857759,
#          0.08397184, -0.20606034, -0.07906438, -0.01928916, -0.13577603,
#          0.15109144,  0.09945812, -0.00686585, -0.272603  ,  0.04615889,
#          0.07168408,  0.10110489, -0.0809291 ,  0.02874514, -0.25463805,
#          0.18590969,  0.10850435,  0.13627945, -0.29579625,  0.33389786,
#         -0.14863433,  0.13765804,  0.25170827, -0.05773124,  0.20597072,
#          0.11731598,  0.01735382, -0.04593207, -0.18064968,  0.14520119,
#         -0.03716641, -0.06409473, -0.23583539,  0.30350772, -0.0305592 ,
#          0.02279344, -0.07581868,  0.2784487 ,  0.2717581 ,  0.13168187,
#          0.32538193,  0.14233302,  0.03302268,  0.12404588,  0.3265352 ,
#          0.2281385 ,  0.12352545, -0.23860405,  0.08025591, -0.05065564],
#        dtype=float32),
#  array([-0.07049452,  0.21562217,  0.05304749,  0.01483361,  0.0270262 ,
#         -0.2569941 ,  0.08002684,  0.40382436, -0.15912981, -0.12605141,
#         -0.15928678, -0.26929432, -0.00735087,  0.08755938,  0.04861623,
#         -0.16254503, -0.01878104, -0.2170965 ,  0.00874256, -0.40061644,
#          0.07620037,  0.08108301,  0.09950891, -0.10249311, -0.0717447 ,
#          0.04617042, -0.13066743, -0.11048442, -0.18731047,  0.05083945,
#          0.23293538,  0.03313786,  0.09429958, -0.13890858, -0.11832404,
#          0.26443216, -0.00961723, -0.12717557, -0.08718735, -0.29334202,
#         -0.00885953, -0.19463204, -0.04833159,  0.06891586,  0.17729227,
#         -0.11287471, -0.15990524, -0.01603046,  0.11033064,  0.15674059,
#          0.07714363, -0.19037737, -0.07000493, -0.02048909, -0.12080833,
#          0.13521855,  0.08519   , -0.00078437, -0.24598007,  0.03888179,
#          0.07078969,  0.08511081, -0.07159588,  0.02756931, -0.21976155,
#          0.16794956,  0.10424238,  0.12405854, -0.26224387,  0.29798067,
#         -0.1381942 ,  0.11999879,  0.22583334, -0.05144091,  0.18539381,
#          0.11015513,  0.0176544 , -0.04233239, -0.15887335,  0.12921387,
#         -0.03563224, -0.05738081, -0.21121491,  0.2775925 , -0.02978509,
#          0.01540538, -0.07092746,  0.24691008,  0.24181795,  0.11964145,
#          0.29690358,  0.1290945 ,  0.02827186,  0.11526036,  0.29342878,
#          0.21208005,  0.11236402, -0.21344014,  0.07388256, -0.04151798],
#        dtype=float32),
#  array([-0.14948808,  0.4461694 ,  0.10303877,  0.03134563,  0.05633759,
#         -0.539207  ,  0.16806625,  0.85735637, -0.32721016, -0.2608544 ,
#         -0.32881066, -0.5673705 , -0.02427219,  0.18073793,  0.10254446,
#         -0.33529928, -0.03894145, -0.46891215,  0.02482326, -0.8424557 ,
#          0.1584856 ,  0.17706983,  0.21052492, -0.21043418, -0.14624776,
#          0.09582865, -0.2735425 , -0.22850037, -0.38910493,  0.11898214,
#          0.49046588,  0.06874136,  0.20195116, -0.29678535, -0.24870475,
#          0.5557223 , -0.02501058, -0.27485457, -0.1812826 , -0.6165195 ,
#         -0.02538012, -0.4100422 , -0.09686411,  0.14499332,  0.37747347,
#         -0.236417  , -0.33175078, -0.02977805,  0.23568612,  0.3332871 ,
#          0.16723888, -0.3907455 , -0.1498994 , -0.04020924, -0.2531064 ,
#          0.2740412 ,  0.18372452, -0.00516549, -0.5110026 ,  0.08736539,
#          0.14274304,  0.19251136, -0.14984727,  0.05351575, -0.47356543,
#          0.3542715 ,  0.21634227,  0.26787183, -0.5535293 ,  0.6219584 ,
#         -0.29087242,  0.25460806,  0.47403637, -0.10986099,  0.3853948 ,
#          0.22284769,  0.02775258, -0.08538372, -0.33850607,  0.27037635,
#         -0.07123498, -0.12248757, -0.437345  ,  0.5781086 , -0.062612  ,
#          0.03052718, -0.15512578,  0.5237674 ,  0.5073785 ,  0.24471295,
#          0.6246725 ,  0.27219233,  0.06607898,  0.24308346,  0.6284333 ,
#          0.4369273 ,  0.24086924, -0.4502205 ,  0.15986913, -0.08706164],
#        dtype=float32),
#  array([-0.13266489,  0.40141326,  0.09545682,  0.03065478,  0.04987111,
#         -0.48416024,  0.14531958,  0.75644684, -0.29544556, -0.23284419,
#         -0.29539847, -0.49700975, -0.0141833 ,  0.15726067,  0.09250701,
#         -0.3014602 , -0.03102429, -0.41165438,  0.01758355, -0.74867505,
#          0.13625559,  0.15145855,  0.18470171, -0.19240002, -0.13501039,
#          0.088531  , -0.24493167, -0.20838296, -0.34475097,  0.09778341,
#          0.434766  ,  0.06536233,  0.17407742, -0.2659219 , -0.2173953 ,
#          0.4984277 , -0.02632895, -0.23839407, -0.16400692, -0.5496108 ,
#         -0.02145416, -0.36089665, -0.0881351 ,  0.12999117,  0.33311304,
#         -0.21080807, -0.29365352, -0.03122296,  0.20096652,  0.29364976,
#          0.14462301, -0.35362324, -0.13063744, -0.034177  , -0.22543773,
#          0.2486213 ,  0.1576958 , -0.00110256, -0.46053228,  0.07842487,
#          0.12984699,  0.16550991, -0.13213514,  0.04749925, -0.41612568,
#          0.31490785,  0.19806643,  0.23508553, -0.4946385 ,  0.55502146,
#         -0.25559753,  0.22986248,  0.42205173, -0.09497578,  0.3432404 ,
#          0.20214412,  0.02705166, -0.07623915, -0.29748076,  0.23567677,
#         -0.06895217, -0.10479234, -0.39446035,  0.51066506, -0.05749336,
#          0.02365475, -0.13037613,  0.4682897 ,  0.45712677,  0.22274968,
#          0.5539998 ,  0.23924835,  0.055591  ,  0.21803355,  0.54974127,
#          0.38414446,  0.20824656, -0.4035872 ,  0.13945201, -0.07722019],
#        dtype=float32),
#  array([-0.09815691,  0.3107167 ,  0.06783043,  0.01840078,  0.04069842,
#         -0.36482045,  0.11840107,  0.5794849 , -0.22822742, -0.18262465,
#         -0.22751907, -0.38932338, -0.0095506 ,  0.12314408,  0.07106579,
#         -0.23226504, -0.02526753, -0.31673485,  0.01317109, -0.5753998 ,
#          0.10894441,  0.12020009,  0.14390853, -0.14892745, -0.09819605,
#          0.06577253, -0.18928337, -0.16395417, -0.26751086,  0.07771339,
#          0.32955745,  0.05108932,  0.12901017, -0.20469889, -0.16555603,
#          0.38153332, -0.02303138, -0.1856062 , -0.12855971, -0.42405978,
#         -0.01016586, -0.2811444 , -0.0657751 ,  0.09859713,  0.25541297,
#         -0.1668105 , -0.23014483, -0.01910188,  0.15635414,  0.22199741,
#          0.11446787, -0.26678875, -0.10179111, -0.03063058, -0.17198256,
#          0.18774286,  0.12605362, -0.00270756, -0.34550843,  0.06366286,
#          0.10015812,  0.12268031, -0.10613295,  0.04144097, -0.32115677,
#          0.2445782 ,  0.14903279,  0.18170793, -0.38274017,  0.4297351 ,
#         -0.19679041,  0.17463927,  0.3238442 , -0.0735724 ,  0.2642096 ,
#          0.15500169,  0.02457222, -0.06013973, -0.23220457,  0.18849811,
#         -0.05071945, -0.08787221, -0.3007377 ,  0.3921798 , -0.0419276 ,
#          0.02240963, -0.09567861,  0.35926515,  0.34913626,  0.16479698,
#          0.4279563 ,  0.18702778,  0.04807964,  0.16793172,  0.4279676 ,
#          0.30025458,  0.16264299, -0.3117652 ,  0.10511035, -0.05864381],
#        dtype=float32),
#  array([-0.12192348,  0.37673336,  0.09030306,  0.02310745,  0.04657527,
#         -0.44928667,  0.14230843,  0.7143138 , -0.2759565 , -0.22077674,
#         -0.2724427 , -0.4726194 , -0.01658071,  0.14770095,  0.08536369,
#         -0.28064278, -0.03217399, -0.38777056,  0.01605394, -0.7015524 ,
# ...
#          0.10446751,  0.06591269, -0.00771122, -0.19322515,  0.03305709,
#          0.05130351,  0.06965396, -0.05792155,  0.02062519, -0.1824425 ,
#          0.13667746,  0.07863367,  0.10072455, -0.21445435,  0.24325162,
#         -0.11519351,  0.09243884,  0.17927784, -0.04245371,  0.13906954,
#          0.09092931,  0.00523886, -0.03014889, -0.1252698 ,  0.09995413,
#         -0.03018331, -0.04551489, -0.16342884,  0.2164921 , -0.0345244 ,
#          0.01141818, -0.0563002 ,  0.19469695,  0.19233787,  0.09565232,
#          0.24339338,  0.10271418,  0.02210752,  0.09744408,  0.24525568,
#          0.16698289,  0.09802214, -0.16946635,  0.05442423, -0.02394703],
#        dtype=float32),
#  array([-0.14519514,  0.43525174,  0.10623562,  0.02868019,  0.05319634,
#         -0.5214638 ,  0.16076493,  0.8149411 , -0.316948  , -0.2510417 ,
#         -0.32017043, -0.54577935, -0.01931925,  0.17137423,  0.09787466,
#         -0.32702675, -0.033232  , -0.44338086,  0.01730179, -0.80304587,
#          0.15664454,  0.17014001,  0.20419104, -0.20576675, -0.1391254 ,
#          0.09533828, -0.2656452 , -0.22836933, -0.37261698,  0.11199077,
#          0.4721393 ,  0.06968988,  0.19160025, -0.2918835 , -0.23396899,
#          0.533933  , -0.02468795, -0.25931832, -0.1776727 , -0.5940687 ,
#         -0.02146583, -0.3939857 , -0.08948494,  0.1381281 ,  0.35725802,
#         -0.23267461, -0.3233373 , -0.03300763,  0.22140574,  0.3145658 ,
#          0.16147111, -0.38128635, -0.14246556, -0.04088379, -0.2454062 ,
#          0.26668712,  0.16851363, -0.00459212, -0.49362844,  0.08692595,
#          0.13981143,  0.1787328 , -0.14807342,  0.0547027 , -0.4457111 ,
#          0.340451  ,  0.21636125,  0.25321984, -0.53345835,  0.5998765 ,
#         -0.27615806,  0.23781325,  0.45556933, -0.10211039,  0.36837265,
#          0.218365  ,  0.02982627, -0.07981055, -0.32192725,  0.25572553,
#         -0.07348077, -0.11875152, -0.42561314,  0.5491539 , -0.06405789,
#          0.02836582, -0.13738981,  0.50224465,  0.4885114 ,  0.23534168,
#          0.6003273 ,  0.2602581 ,  0.05635436,  0.22651224,  0.5944032 ,
#          0.41754708,  0.23209263, -0.43431395,  0.14825495, -0.08002204],
#        dtype=float32),
#  array([-0.12172453,  0.37750992,  0.0891069 ,  0.02336907,  0.04127734,
#         -0.45616227,  0.14051405,  0.72387075, -0.28039196, -0.22036795,
#         -0.27873293, -0.47549868, -0.00869002,  0.15109514,  0.08387916,
#         -0.28058243, -0.02760064, -0.39575773,  0.01672001, -0.7158786 ,
#          0.13543274,  0.14676027,  0.18046167, -0.18148163, -0.1313939 ,
#          0.0785711 , -0.23113994, -0.1962078 , -0.32290903,  0.10444987,
#          0.41352844,  0.06084442,  0.16569947, -0.24519105, -0.20471773,
#          0.4741536 , -0.02243612, -0.22618003, -0.15786126, -0.5211922 ,
#         -0.01468627, -0.34262595, -0.08369765,  0.12011296,  0.31376457,
#         -0.2070255 , -0.28117964, -0.02525996,  0.1945594 ,  0.2780704 ,
#          0.13815197, -0.33575854, -0.12787822, -0.0360915 , -0.21151552,
#          0.23406811,  0.14797987, -0.00526887, -0.4305485 ,  0.07147316,
#          0.11905819,  0.15220392, -0.12494577,  0.04339772, -0.4002583 ,
#          0.30470338,  0.17967917,  0.21650329, -0.46622363,  0.5228516 ,
#         -0.24337986,  0.21090491,  0.3934469 , -0.08930771,  0.32307702,
#          0.19139856,  0.03630898, -0.07826755, -0.28878766,  0.23357801,
#         -0.06247602, -0.09901746, -0.36875632,  0.49486881, -0.05812884,
#          0.02839715, -0.12475499,  0.44243765,  0.43317556,  0.2087839 ,
#          0.5296682 ,  0.22483388,  0.04902746,  0.2056185 ,  0.5213871 ,
#          0.3679789 ,  0.2068481 , -0.38551813,  0.13474952, -0.07657804],
#        dtype=float32),
#  array([-0.07632705,  0.227115  ,  0.05464927,  0.01455131,  0.02711617,
#         -0.27315325,  0.08372884,  0.4340131 , -0.16888748, -0.132658  ,
#         -0.17113554, -0.2854315 , -0.00713201,  0.09368747,  0.05272223,
#         -0.17141518, -0.02025294, -0.23464483,  0.01187744, -0.4290253 ,
#          0.08229094,  0.09364349,  0.10394049, -0.11013787, -0.07387287,
#          0.04785524, -0.13902743, -0.12263179, -0.1977415 ,  0.05790341,
#          0.24985714,  0.03722128,  0.0995778 , -0.15095831, -0.12560712,
#          0.28414038, -0.01234558, -0.13857393, -0.09365665, -0.3142836 ,
#         -0.01072815, -0.20970705, -0.0472648 ,  0.07373996,  0.19030948,
#         -0.12219483, -0.17189439, -0.01761756,  0.11986198,  0.16517863,
#          0.08100225, -0.20413294, -0.07491974, -0.01685617, -0.12823538,
#          0.1431621 ,  0.09244787, -0.00090517, -0.258891  ,  0.04442618,
#          0.07461015,  0.09761696, -0.08270315,  0.02429926, -0.24151112,
#          0.17827612,  0.10920341,  0.13549672, -0.28585073,  0.31817916,
#         -0.14685267,  0.12937796,  0.24694732, -0.05654489,  0.19418561,
#          0.11240209,  0.01823212, -0.04322711, -0.17420253,  0.13600373,
#         -0.03681726, -0.06139747, -0.22541489,  0.2917284 , -0.03387615,
#          0.01739363, -0.07909256,  0.26420152,  0.26186454,  0.12656093,
#          0.31716695,  0.13763526,  0.03183194,  0.12579837,  0.3186781 ,
#          0.22308385,  0.12259793, -0.2299863 ,  0.07865155, -0.04362994],
#        dtype=float32),
#  array([-0.15161772,  0.47756866,  0.1117821 ,  0.03654672,  0.08194812,
#         -0.5694509 ,  0.1861596 ,  0.9063375 , -0.35182264, -0.28723577,
#         -0.35407332, -0.59968907, -0.02745618,  0.19072296,  0.09784319,
#         -0.36425942, -0.05288188, -0.49454004,  0.02225449, -0.8851154 ,
#          0.17179753,  0.19367303,  0.22974601, -0.22063582, -0.1505289 ,
#          0.08819698, -0.28505507, -0.24779557, -0.40970832,  0.11234414,
#          0.51505435,  0.07832514,  0.2187863 , -0.3079337 , -0.2670678 ,
#          0.5760053 , -0.01448629, -0.28122067, -0.18577655, -0.6556732 ,
#         -0.01525252, -0.4252152 , -0.10452582,  0.1584443 ,  0.4006893 ,
#         -0.25777748, -0.35532132, -0.03309672,  0.23818111,  0.35699108,
#          0.17118163, -0.3935965 , -0.15160565, -0.04629723, -0.26801342,
#          0.2822847 ,  0.19937257, -0.0061745 , -0.535356  ,  0.08947746,
#          0.1535742 ,  0.2083858 , -0.16599612,  0.03684249, -0.49287826,
#          0.35724804,  0.23081073,  0.2882753 , -0.6024752 ,  0.6499529 ,
#         -0.30854708,  0.27635267,  0.5135891 , -0.11051523,  0.4003301 ,
#          0.22034071,  0.04066663, -0.08718228, -0.37104514,  0.27251098,
#         -0.0735081 , -0.13940713, -0.46517745,  0.59777063, -0.06955856,
#          0.02946862, -0.1456167 ,  0.5497156 ,  0.52045375,  0.25062963,
#          0.6530006 ,  0.29659307,  0.07750965,  0.2715454 ,  0.68169415,
#          0.47013372,  0.2504408 , -0.47916162,  0.15915036, -0.08336885],
#        dtype=float32),
#  array([-0.11848745,  0.3713571 ,  0.09087511,  0.02516827,  0.04348938,
#         -0.44112992,  0.13522677,  0.7032208 , -0.26994213, -0.2152297 ,
#         -0.27173474, -0.46906853, -0.01364431,  0.14530599,  0.08957746,
#         -0.2772906 , -0.03394762, -0.378939  ,  0.01602298, -0.6919713 ,
#          0.12868303,  0.14322376,  0.17195888, -0.17065018, -0.12678537,
#          0.07482202, -0.22216529, -0.19782329, -0.3192469 ,  0.08744789,
#          0.40542856,  0.05779503,  0.1607207 , -0.24686502, -0.20683563,
#          0.4611669 , -0.01491673, -0.21615446, -0.15003787, -0.50713545,
#         -0.01562412, -0.33788753, -0.08390731,  0.11909255,  0.31243637,
#         -0.19879442, -0.2769803 , -0.02748398,  0.19112165,  0.2734286 ,
#          0.13788314, -0.32753828, -0.12253494, -0.03830008, -0.21760981,
#          0.22882809,  0.14348613, -0.00866484, -0.42582986,  0.07241834,
#          0.12077317,  0.15733494, -0.12199561,  0.0409116 , -0.3851094 ,
#          0.29733133,  0.17666954,  0.21264859, -0.45803785,  0.5137798 ,
#         -0.23354708,  0.20941241,  0.38497105, -0.09273496,  0.32381976,
#          0.18851411,  0.02514395, -0.07459293, -0.2808708 ,  0.22055948,
#         -0.06376208, -0.10349213, -0.36536726,  0.47168267, -0.05989044,
#          0.02841339, -0.1252747 ,  0.43171883,  0.4189138 ,  0.19719672,
#          0.50645715,  0.2218811 ,  0.05013532,  0.19779496,  0.5155166 ,
#          0.35486975,  0.19391064, -0.37124798,  0.12321502, -0.07488865],
#        dtype=float32),
#  array([-0.09886839,  0.2956392 ,  0.07341547,  0.02351709,  0.03418273,
#         -0.3515118 ,  0.11214925,  0.5572068 , -0.21523707, -0.17456886,
#         -0.2163886 , -0.3698654 , -0.00931852,  0.11443082,  0.06266595,
#         -0.22182418, -0.02442898, -0.30264217,  0.0148044 , -0.5494094 ,
#          0.10292456,  0.11396585,  0.13490193, -0.14164206, -0.09593462,
#          0.06166441, -0.17892696, -0.15487026, -0.2574412 ,  0.07337365,
#          0.3223887 ,  0.05291257,  0.13012435, -0.19411744, -0.16527025,
#          0.3608046 , -0.01653581, -0.17819163, -0.11702941, -0.40852326,
#         -0.01145526, -0.26845893, -0.06481232,  0.09328667,  0.24629208,
#         -0.15486059, -0.2197493 , -0.02472837,  0.14840528,  0.21424672,
#          0.10977103, -0.26030296, -0.10472209, -0.02605577, -0.16632996,
#          0.1816666 ,  0.11619778, -0.00744215, -0.33620784,  0.05344959,
#          0.0941898 ,  0.12441225, -0.09977164,  0.03558499, -0.30863723,
#          0.23142628,  0.1407055 ,  0.17330483, -0.36104542,  0.40627748,
#         -0.18905091,  0.16887763,  0.311721  , -0.06878658,  0.25332844,
#          0.14527379,  0.01723281, -0.06096775, -0.22377183,  0.17625718,
#         -0.04241923, -0.08330001, -0.28818431,  0.37747288, -0.04417551,
#          0.01923095, -0.09536343,  0.3360135 ,  0.3314218 ,  0.16076687,
#          0.4086449 ,  0.18157499,  0.04050641,  0.16441365,  0.41224   ,
#          0.29143184,  0.15562963, -0.29647964,  0.10024713, -0.05615912],
#        dtype=float32),
#  array([-6.10433295e-02,  1.77706063e-01,  4.04667258e-02,  1.56200789e-02,
#          2.28664670e-02, -2.08448082e-01,  6.47333562e-02,  3.32930475e-01,
#         -1.33958653e-01, -9.98243764e-02, -1.29851148e-01, -2.18636185e-01,
#         -6.55013137e-03,  7.25506321e-02,  3.97191793e-02, -1.27936989e-01,
#         -1.68952961e-02, -1.79646149e-01,  6.47331588e-03, -3.24648678e-01,
#          6.03892133e-02,  6.78721145e-02,  8.64025205e-02, -8.55339691e-02,
#         -5.65905496e-02,  4.10447158e-02, -1.10736564e-01, -9.26429331e-02,
#         -1.53969377e-01,  4.30194885e-02,  1.90774262e-01,  3.17413658e-02,
#          7.69598186e-02, -1.15765058e-01, -9.62144434e-02,  2.20316648e-01,
#         -1.15448264e-02, -1.07119530e-01, -7.59325922e-02, -2.41983891e-01,
#         -1.15196668e-02, -1.62148058e-01, -3.44043337e-02,  6.10296205e-02,
#          1.45308450e-01, -9.71214846e-02, -1.34373963e-01, -1.17694838e-02,
#          8.93172845e-02,  1.29599884e-01,  6.64172769e-02, -1.54641405e-01,
#         -5.82785681e-02, -1.42491991e-02, -1.02066107e-01,  1.08247846e-01,
#          6.90568388e-02, -1.40952570e-05, -2.02818841e-01,  3.47728580e-02,
#          5.71910664e-02,  7.42348135e-02, -6.23966008e-02,  2.03553364e-02,
#         -1.81199491e-01,  1.37941495e-01,  8.98253843e-02,  1.07088007e-01,
#         -2.18394846e-01,  2.40829527e-01, -1.12318367e-01,  1.01362921e-01,
#          1.86985254e-01, -4.06617448e-02,  1.49877816e-01,  9.14691016e-02,
#          1.37926349e-02, -3.29661109e-02, -1.32982820e-01,  1.06616206e-01,
#         -2.83548664e-02, -4.58420515e-02, -1.68009296e-01,  2.27827236e-01,
#         -2.80464161e-02,  1.29910856e-02, -5.79857230e-02,  2.08069831e-01,
#          2.00280562e-01,  9.76403952e-02,  2.46376455e-01,  1.07511781e-01,
#          2.62289010e-02,  9.68923941e-02,  2.42034987e-01,  1.76353052e-01,
#          8.97532925e-02, -1.81254596e-01,  6.48299977e-02, -3.46543342e-02],
#        dtype=float32),
#  array([-0.13153847,  0.40106088,  0.09529303,  0.02764654,  0.05010463,
#         -0.47953886,  0.1508769 ,  0.75841993, -0.29499456, -0.23441882,
#         -0.29404512, -0.50126   , -0.01321443,  0.16070208,  0.08854537,
#         -0.30110654, -0.03492253, -0.41210347,  0.01461217, -0.7474173 ,
#          0.1362113 ,  0.15150854,  0.18922879, -0.19077256, -0.12740625,
#          0.08317055, -0.24155284, -0.21096292, -0.3470568 ,  0.10409288,
#          0.4355305 ,  0.06268296,  0.174318  , -0.26480845, -0.21878745,
#          0.4952511 , -0.02293416, -0.24239285, -0.16191983, -0.55229557,
#         -0.02051638, -0.36278948, -0.08738311,  0.12598145,  0.33377552,
#         -0.2153947 , -0.29584497, -0.03074091,  0.2079488 ,  0.29303303,
#          0.14790924, -0.35127923, -0.13219309, -0.03653901, -0.22489424,
#          0.2478338 ,  0.16166969, -0.00340235, -0.45682427,  0.07778014,
#          0.12997895,  0.16368262, -0.13668756,  0.04726043, -0.41527602,
#          0.31620315,  0.19405632,  0.235346  , -0.49390236,  0.5587306 ,
#         -0.25487167,  0.22635195,  0.4250093 , -0.09116512,  0.34107167,
#          0.19759527,  0.02839667, -0.07629031, -0.29949826,  0.2420543 ,
#         -0.06348887, -0.1137098 , -0.3900814 ,  0.5096736 , -0.05797586,
#          0.0273683 , -0.13313363,  0.4643527 ,  0.45203397,  0.21887697,
#          0.5566655 ,  0.2445866 ,  0.05739687,  0.2164273 ,  0.5571534 ,
#          0.39139992,  0.2128861 , -0.40620494,  0.14058417, -0.0776744 ],
#        dtype=float32),
#  array([-0.05253962,  0.17846356,  0.04680625,  0.01064696,  0.01920671,
#         -0.22186227,  0.0722683 ,  0.34812224, -0.14186089, -0.10278925,
#         -0.13539797, -0.23212928, -0.00768935,  0.07415896,  0.04082747,
#         -0.1393504 , -0.01238424, -0.19005351,  0.00867368, -0.3473797 ,
#          0.06347843,  0.07132246,  0.09171488, -0.08037262, -0.06148094,
#          0.03836866, -0.11361381, -0.09467203, -0.15851128,  0.04649587,
#          0.19385767,  0.02755516,  0.08022337, -0.12413885, -0.10150728,
#          0.22921193, -0.01167047, -0.11134141, -0.07074567, -0.25210243,
#         -0.00323626, -0.17096265, -0.03668728,  0.0546595 ,  0.14680596,
#         -0.09626498, -0.1440808 , -0.00952361,  0.09317771,  0.13240393,
#          0.06937084, -0.16129579, -0.05935964, -0.02188619, -0.10007904,
#          0.1178875 ,  0.07185909,  0.00055623, -0.21078981,  0.03544661,
#          0.05667769,  0.0756906 , -0.06268522,  0.02517454, -0.19315608,
#          0.14535852,  0.08580992,  0.11240753, -0.22142965,  0.2623394 ,
#         -0.11997694,  0.10204341,  0.1985867 , -0.04776741,  0.15874536,
#          0.09578469,  0.01537171, -0.0378567 , -0.13491471,  0.11311191,
#         -0.03101923, -0.05367556, -0.17865966,  0.23898692, -0.02928197,
#          0.01782863, -0.06037309,  0.21983324,  0.20868094,  0.09933855,
#          0.25927868,  0.11534586,  0.02293887,  0.09515026,  0.25298277,
#          0.18639183,  0.08993298, -0.18709414,  0.06563851, -0.04091595],
#        dtype=float32),
#  array([-0.04344678,  0.11696062,  0.02766139,  0.00949642,  0.0142001 ,
#         -0.14518492,  0.03551328,  0.22118239, -0.0881714 , -0.07090046,
#         -0.08151377, -0.14346372, -0.00693999,  0.05285496,  0.0232968 ,
#         -0.08677319, -0.0123146 , -0.11772215,  0.00550916, -0.21663678,
#          0.04058948,  0.0468331 ,  0.05492089, -0.0549446 , -0.04400003,
#          0.02516527, -0.07225278, -0.06219075, -0.09997931,  0.03380897,
#          0.1264946 ,  0.01833742,  0.0506396 , -0.08269426, -0.07028326,
#          0.14545043, -0.00947618, -0.07361367, -0.04840275, -0.15949228,
#         -0.00352123, -0.1068188 , -0.02373698,  0.03196437,  0.09561509,
#         -0.06485455, -0.08969652, -0.00619885,  0.06089184,  0.09257018,
#          0.04639104, -0.10013329, -0.04364508, -0.00462229, -0.06216206,
#          0.0723309 ,  0.04889792,  0.00164523, -0.1333116 ,  0.02435159,
#          0.04278721,  0.04905614, -0.03342557,  0.02321815, -0.11941119,
#          0.09650317,  0.04974086,  0.07018123, -0.14738704,  0.16185383,
#         -0.07559696,  0.07201525,  0.12575483, -0.02647631,  0.09771316,
#          0.05900608,  0.00825263, -0.02091424, -0.08702525,  0.06634165,
#         -0.01832925, -0.02890737, -0.11616844,  0.15763946, -0.01940542,
#          0.00574068, -0.03426814,  0.13778825,  0.13484365,  0.06016643,
#          0.16152225,  0.06519381,  0.02070514,  0.07035211,  0.16058232,
#          0.1084905 ,  0.06314193, -0.12097454,  0.04090162, -0.0259428 ],
#        dtype=float32),
#  ...]

# %%
len(x[0])
# Out:
# 100

# %%
type(x)
# Out:
# list

# %%
list(map(float, x.flatten()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [97], in <cell line: 1>()
# ----> 1 list(map(float, x.flatten()))
#
# AttributeError: 'list' object has no attribute 'flatten'

# %%
x_new = np.asarray(x,dtype="object")

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_new,y, train_size = 0.7, random_state = 4)

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()

# %%
model.fit([x_train],y_train)
# Out:
# C:\Users\seher\anaconda3\lib\site-packages\sklearn\utils\validation.py:964: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:787, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     786 try:
# --> 787     array = array.astype(np.float64)
#     788 except ValueError as e:
#
# ValueError: setting an array element with a sequence.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [95], in <cell line: 1>()
# ----> 1 model.fit([x_train],y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py:663, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     643 def fit(self, X, y, sample_weight=None):
#     644     """Fit Naive Bayes classifier according to X, y.
#     645
#     646     Parameters
#    (...)
#     661         Returns the instance itself.
#     662     """
# --> 663     X, y = self._check_X_y(X, y)
#     664     _, n_features = X.shape
#     666     labelbin = LabelBinarizer()
#
# File ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py:523, in _BaseDiscreteNB._check_X_y(self, X, y, reset)
#     521 def _check_X_y(self, X, y, reset=True):
#     522     """Validate X and y in fit methods."""
# --> 523     return self._validate_data(X, y, accept_sparse="csr", reset=reset)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# --> 581         X, y = check_X_y(X, y, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:964, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     961 if y is None:
#     962     raise ValueError("y cannot be None")
# --> 964 X = check_array(
#     965     X,
#     966     accept_sparse=accept_sparse,
#     967     accept_large_sparse=accept_large_sparse,
#     968     dtype=dtype,
#     969     order=order,
#     970     copy=copy,
#     971     force_all_finite=force_all_finite,
#     972     ensure_2d=ensure_2d,
#     973     allow_nd=allow_nd,
#     974     ensure_min_samples=ensure_min_samples,
#     975     ensure_min_features=ensure_min_features,
#     976     estimator=estimator,
#     977 )
#     979 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     981 check_consistent_length(X, y)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:789, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     787         array = array.astype(np.float64)
#     788     except ValueError as e:
# --> 789         raise ValueError(
#     790             "Unable to convert array of bytes/strings "
#     791             "into decimal numbers with dtype='numeric'"
#     792         ) from e
#     793 if not allow_nd and array.ndim >= 3:
#     794     raise ValueError(
#     795         "Found array with dim %d. %s expected <= 2."
#     796         % (array.ndim, estimator_name)
#     797     )
#
# ValueError: Unable to convert array of bytes/strings into decimal numbers with dtype='numeric'

# %%
from sklearn.naive_bayes import MultinomialNB
spam_detect_model = MultinomialNB().fit(x_train, y_train)
# Out:
# C:\Users\seher\anaconda3\lib\site-packages\sklearn\utils\validation.py:746: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   array = np.asarray(array, order=order, dtype=dtype)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [87], in <cell line: 2>()
#       1 from sklearn.naive_bayes import MultinomialNB
# ----> 2 spam_detect_model = MultinomialNB().fit(x_train, y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py:663, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     643 def fit(self, X, y, sample_weight=None):
#     644     """Fit Naive Bayes classifier according to X, y.
#     645
#     646     Parameters
#    (...)
#     661         Returns the instance itself.
#     662     """
# --> 663     X, y = self._check_X_y(X, y)
#     664     _, n_features = X.shape
#     666     labelbin = LabelBinarizer()
#
# File ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py:523, in _BaseDiscreteNB._check_X_y(self, X, y, reset)
#     521 def _check_X_y(self, X, y, reset=True):
#     522     """Validate X and y in fit methods."""
# --> 523     return self._validate_data(X, y, accept_sparse="csr", reset=reset)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# --> 581         X, y = check_X_y(X, y, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:964, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     961 if y is None:
#     962     raise ValueError("y cannot be None")
# --> 964 X = check_array(
#     965     X,
#     966     accept_sparse=accept_sparse,
#     967     accept_large_sparse=accept_large_sparse,
#     968     dtype=dtype,
#     969     order=order,
#     970     copy=copy,
#     971     force_all_finite=force_all_finite,
#     972     ensure_2d=ensure_2d,
#     973     allow_nd=allow_nd,
#     974     ensure_min_samples=ensure_min_samples,
#     975     ensure_min_features=ensure_min_features,
#     976     estimator=estimator,
#     977 )
#     979 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     981 check_consistent_length(X, y)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:769, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     767     # If input is 1D raise error
#     768     if array.ndim == 1:
# --> 769         raise ValueError(
#     770             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     771             "Reshape your data either using array.reshape(-1, 1) if "
#     772             "your data has a single feature or array.reshape(1, -1) "
#     773             "if it contains a single sample.".format(array)
#     774         )
#     776 # make sure we actually converted to numeric:
#     777 if dtype_numeric and array.dtype.kind in "OUSV":
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[array([-0.12063584,  0.37888396,  0.08983022,  0.02781296,  0.05388147,
#         -0.45622817,  0.14654176,  0.721863  , -0.28364357, -0.22656696,
#         -0.28275833, -0.47819152, -0.01682468,  0.15013824,  0.08243623,
#         -0.28643772, -0.03454135, -0.39298046,  0.02213353, -0.7036156 ,
#          0.1337224 ,  0.15181893,  0.1743403 , -0.18111785, -0.11714979,
#          0.07999039, -0.22955878, -0.20065977, -0.32738587,  0.09284869,
#          0.4127277 ,  0.06233066,  0.16936874, -0.25160047, -0.20957315,
#          0.46780458, -0.01919525, -0.22960556, -0.14835031, -0.53310907,
#         -0.01859528, -0.34887525, -0.08236568,  0.12233328,  0.3186731 ,
#         -0.20355232, -0.2857738 , -0.02842459,  0.19981724,  0.27623013,
#          0.13741906, -0.33269107, -0.12493903, -0.03446538, -0.21430822,
#          0.23626107,  0.15661259, -0.00553119, -0.4260973 ,  0.07341314,
#          0.12508593,  0.16771846, -0.12956162,  0.04112124, -0.4017924 ,
#          0.30106732,  0.18215503,  0.23062496, -0.4730164 ,  0.52950644,
#         -0.2425638 ,  0.21559764,  0.40816233, -0.0903269 ,  0.32729295,
#          0.17945158,  0.02290123, -0.07154735, -0.28894392,  0.22540838,
#         -0.05972994, -0.10815694, -0.3728266 ,  0.48345292, -0.05612162,
#          0.02192461, -0.12374277,  0.4424329 ,  0.42503962,  0.20733075,
#          0.5253569 ,  0.23790006,  0.05596765,  0.21305913,  0.5331757 ,
#          0.37461445,  0.20145518, -0.3838552 ,  0.12983336, -0.07086682],
#        dtype=float32)
#  array([-0.10973924,  0.30764505,  0.0734492 ,  0.02335854,  0.03613159,
#         -0.37304255,  0.11566176,  0.58931047, -0.22962476, -0.18089987,
#         -0.22646928, -0.38988462, -0.01256499,  0.12420321,  0.07103506,
#         -0.22964151, -0.02322757, -0.32398787,  0.01887593, -0.58427215,
#          0.10764072,  0.12458944,  0.14059584, -0.14877747, -0.09763336,
#          0.06521147, -0.19376254, -0.15874629, -0.2714342 ,  0.08008152,
#          0.3388095 ,  0.05431941,  0.14022796, -0.20406614, -0.17709176,
#          0.38691726, -0.01269506, -0.18548386, -0.1273507 , -0.42534605,
#         -0.01102439, -0.28109616, -0.06689889,  0.10015011,  0.26249477,
#         -0.16690631, -0.23441882, -0.01809707,  0.16522637,  0.2309813 ,
#          0.11847108, -0.27168182, -0.10624518, -0.02687372, -0.16959675,
#          0.19134247,  0.12566186, -0.00427523, -0.35165104,  0.06198911,
#          0.1029428 ,  0.13634747, -0.10478481,  0.04212339, -0.32320789,
#          0.23919095,  0.14774305,  0.18062842, -0.38562608,  0.42877802,
#         -0.19360916,  0.18019457,  0.32759106, -0.0828365 ,  0.2655239 ,
#          0.15520263,  0.02281827, -0.06048333, -0.2300859 ,  0.18784012,
#         -0.05040294, -0.08807999, -0.30456287,  0.40073523, -0.04242945,
#          0.01608059, -0.10851654,  0.3660945 ,  0.35386148,  0.17153247,
#          0.4247456 ,  0.19175227,  0.04448129,  0.17328878,  0.43812618,
#          0.29886386,  0.1608535 , -0.31228423,  0.11494669, -0.06188137],
#        dtype=float32)
#  array([-0.13594009,  0.42113513,  0.09945203,  0.02586159,  0.05340778,
#         -0.50629926,  0.15859494,  0.7998657 , -0.30850285, -0.24134138,
#         -0.30810827, -0.5271689 , -0.01766005,  0.16074662,  0.09167659,
#         -0.3171172 , -0.03361077, -0.4357621 ,  0.0151244 , -0.7862808 ,
#          0.14683554,  0.15821728,  0.19296448, -0.20308828, -0.1398577 ,
#          0.08386941, -0.25252143, -0.22310814, -0.36333352,  0.10333937,
#          0.4616297 ,  0.06509472,  0.18656376, -0.27892956, -0.23164964,
#          0.52112895, -0.02682789, -0.2585006 , -0.1669757 , -0.5815506 ,
#         -0.01325347, -0.37913632, -0.08944384,  0.12666854,  0.35029736,
#         -0.22442095, -0.31837088, -0.0231641 ,  0.2185607 ,  0.30993605,
#          0.15691602, -0.3701702 , -0.13818595, -0.0324818 , -0.2415617 ,
#          0.26539004,  0.17027366, -0.00542794, -0.4777134 ,  0.07985117,
#          0.13892722,  0.17037836, -0.14022867,  0.04774527, -0.4374631 ,
#          0.33655816,  0.20337948,  0.24675564, -0.5222559 ,  0.58023244,
#         -0.27084422,  0.2383719 ,  0.4425524 , -0.10415317,  0.36228874,
#          0.20626703,  0.02829678, -0.08230017, -0.31993204,  0.2524889 ,
#         -0.06692054, -0.11391248, -0.41331062,  0.54060984, -0.05749387,
#          0.02917456, -0.13528934,  0.48896503,  0.47096816,  0.22522736,
#          0.58376133,  0.25749817,  0.05018426,  0.2272733 ,  0.5841033 ,
#          0.40705466,  0.21783705, -0.42706156,  0.1442761 , -0.0821398 ],
#        dtype=float32)
#  ...
#  array([-0.05552269,  0.16166201,  0.03591287,  0.01356329,  0.02207286,
#         -0.19313702,  0.06385811,  0.30554765, -0.11584522, -0.09625076,
#         -0.11990505, -0.20436871, -0.00448155,  0.06314115,  0.03473741,
#         -0.12419969, -0.0122303 , -0.16935048,  0.00430444, -0.29907957,
#          0.05516896,  0.06184252,  0.07405461, -0.07555801, -0.05072185,
#          0.03399616, -0.09603965, -0.08385868, -0.13918427,  0.03900159,
#          0.17640296,  0.02537039,  0.07187341, -0.1056417 , -0.08645479,
#          0.20127718, -0.00844204, -0.09858344, -0.06366743, -0.22125046,
#         -0.00852706, -0.14707215, -0.03547122,  0.0490053 ,  0.1370529 ,
#         -0.08274273, -0.11798032, -0.01208389,  0.08275799,  0.12043716,
#          0.06170547, -0.1379132 , -0.05371585, -0.01586566, -0.09270046,
#          0.0973108 ,  0.06466614, -0.00441613, -0.18758589,  0.03223964,
#          0.05165968,  0.06656022, -0.05716197,  0.0143222 , -0.1668044 ,
#          0.12653174,  0.07679288,  0.09433831, -0.20451646,  0.2248964 ,
#         -0.10116687,  0.0898668 ,  0.17403683, -0.03775023,  0.13639173,
#          0.08036463,  0.01574326, -0.03160815, -0.11776905,  0.09774558,
#         -0.0292855 , -0.04418845, -0.15706638,  0.20292048, -0.02288581,
#          0.01212236, -0.0531018 ,  0.18795255,  0.18201813,  0.08961976,
#          0.21891546,  0.09483008,  0.02644743,  0.08823656,  0.2211036 ,
#          0.15494828,  0.08532665, -0.16401757,  0.05443539, -0.02909806],
#        dtype=float32)
#  array([-0.05798753,  0.17731498,  0.04048159,  0.01140795,  0.02030213,
#         -0.21209534,  0.0641645 ,  0.33400303, -0.13021617, -0.10348286,
#         -0.131067  , -0.22018132, -0.00865837,  0.0710847 ,  0.03900975,
#         -0.13695578, -0.01427647, -0.18240884,  0.00721135, -0.33046442,
#          0.0644146 ,  0.0704384 ,  0.08052622, -0.08205788, -0.0589177 ,
#          0.0337089 , -0.10977127, -0.09583579, -0.15170993,  0.04684811,
#          0.19214523,  0.02892019,  0.07895392, -0.11780737, -0.0982327 ,
#          0.2187694 , -0.00778947, -0.10429609, -0.0735653 , -0.24663253,
#         -0.01049707, -0.15864277, -0.03764274,  0.05625904,  0.14995468,
#         -0.09752192, -0.13157386, -0.01615825,  0.08928597,  0.12953816,
#          0.06425001, -0.1565675 , -0.05733208, -0.02104555, -0.10042236,
#          0.11079784,  0.06883318, -0.00305454, -0.20270684,  0.0344211 ,
#          0.05857209,  0.07299273, -0.05849807,  0.01836634, -0.18384281,
#          0.13743004,  0.08828773,  0.10382303, -0.2213916 ,  0.24727187,
#         -0.11131122,  0.09871851,  0.18642025, -0.04149821,  0.15147357,
#          0.08560459,  0.01441721, -0.03388711, -0.13128203,  0.10486598,
#         -0.02853507, -0.05175673, -0.17559953,  0.22243896, -0.02503419,
#          0.01118254, -0.06014832,  0.20586583,  0.19894275,  0.09693943,
#          0.24515358,  0.10856266,  0.02810186,  0.0961035 ,  0.2422261 ,
#          0.17148055,  0.09492617, -0.17613147,  0.06173676, -0.03539924],
#        dtype=float32)
#  array([-0.09420635,  0.30570945,  0.07581623,  0.02211615,  0.03710868,
#         -0.3611524 ,  0.11577411,  0.57304406, -0.22140315, -0.17719798,
#         -0.22350244, -0.38189557, -0.01255306,  0.1275772 ,  0.07182844,
#         -0.22628792, -0.02611182, -0.309379  ,  0.01179878, -0.5662803 ,
#          0.10383381,  0.11510762,  0.14088765, -0.14447841, -0.09957961,
#          0.06350493, -0.1854921 , -0.16275176, -0.26607648,  0.07662739,
#          0.32976374,  0.04904   ,  0.13215157, -0.20004351, -0.16398785,
#          0.37599573, -0.01845703, -0.1804683 , -0.12636802, -0.42154637,
#         -0.01181255, -0.27424487, -0.06754078,  0.09470016,  0.25147712,
#         -0.16041048, -0.23070917, -0.02381893,  0.15557587,  0.22094174,
#          0.11015059, -0.26946115, -0.10467819, -0.03021595, -0.17276007,
#          0.19011196,  0.1256193 , -0.00653145, -0.34617102,  0.06027926,
#          0.09645181,  0.12324057, -0.10343288,  0.03515136, -0.3213708 ,
#          0.23833533,  0.14742228,  0.1753684 , -0.3785457 ,  0.42179045,
#         -0.19150947,  0.1718037 ,  0.3159986 , -0.07025015,  0.26155865,
#          0.14424999,  0.02863741, -0.05713363, -0.23387411,  0.1844568 ,
#         -0.04809105, -0.08811957, -0.29755324,  0.39334196, -0.04215335,
#          0.01852869, -0.09693482,  0.3516497 ,  0.34606808,  0.16568276,
#          0.41948342,  0.18345003,  0.0417457 ,  0.16437925,  0.42258483,
#          0.29432306,  0.16136757, -0.30777213,  0.10550495, -0.05522019],
#        dtype=float32)                                                    ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
